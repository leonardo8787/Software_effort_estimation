# %% [markdown]
# # SelectKbest 25%

# %%
import os
import pandas as pd
import math
from sklearn.feature_selection import SelectKBest, f_classif, f_regression
from sklearn.preprocessing import LabelEncoder

def apply_selectkbest(data, target_column, k):
    """
    Aplica SelectKBest para selecionar as melhores variáveis em relação à coluna alvo.

    Args:
        data (pd.DataFrame): Dataset original.
        target_column (str): Nome da coluna alvo.
        k (float or int): Porcentagem (0-1) ou número de variáveis a selecionar.

    Returns:
        pd.DataFrame: Dataset com as variáveis selecionadas e a coluna alvo.
    """
    # Se a coluna alvo for categórica, usa f_classif; caso contrário, usa f_regression
    if data[target_column].dtype == 'object':
        data[target_column] = LabelEncoder().fit_transform(data[target_column])
        score_func = f_classif
    else:
        score_func = f_regression

    # Separar variáveis independentes e dependente
    X = data.drop(columns=[target_column])
    y = data[target_column]

    # Calcular o valor de k com base na porcentagem
    if isinstance(k, float) and 0 < k <= 1:
        k = max(1, math.floor(k * X.shape[1]))  # Arredonda para baixo e garante pelo menos 1

    print(f"Selecionando as top {k} variáveis...")

    # Aplicar SelectKBest
    selector = SelectKBest(score_func=score_func, k=k)
    X_new = selector.fit_transform(X, y)

    # Identificar colunas selecionadas
    selected_columns = X.columns[selector.get_support()]

    print(f"Variáveis selecionadas: {list(selected_columns)}")

    # Reconstruir o DataFrame com as variáveis selecionadas e a coluna alvo
    new_data = pd.DataFrame(X_new, columns=selected_columns)
    new_data[target_column] = y.values

    return new_data

def get_next_folder_number(output_root):
    """
    Determina o próximo número de pasta disponível no diretório de saída.

    Args:
        output_root (str): Diretório raiz para salvar as pastas processadas.

    Returns:
        int: O próximo número disponível para a pasta de saída.
    """
    existing_folders = [
        folder for folder in os.listdir(output_root) if os.path.isdir(os.path.join(output_root, folder))
    ]
    numbered_folders = [
        int(folder.split("-")[0]) for folder in existing_folders if folder.split("-")[0].isdigit()
    ]
    return max(numbered_folders, default=0) + 1

def process_dataset_in_folder(input_dir, output_dir, k):
    """
    Processa os datasets em uma pasta e salva os resultados em outra pasta correspondente.

    Args:
        input_dir (str): Caminho do diretório de entrada.
        output_dir (str): Caminho do diretório de saída.
        k (float or int): Porcentagem (0-1) ou número de variáveis a selecionar.
    """
    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith(".txt"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            print(f"Processando arquivo: {input_path}")
            try:
                data = pd.read_csv(input_path, delimiter=",", skipinitialspace=True)
                target_column = data.columns[-1]  # Assume que a última coluna é a coluna alvo

                # Aplicar SelectKBest
                new_data = apply_selectkbest(data, target_column, k)

                # Salvar o novo dataset
                new_data.to_csv(output_path, sep=",", index=False)
                print(f"Arquivo processado e salvo em: {output_path}")

            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

def process_multiple_folders(input_root, output_root, k):
    """
    Processa múltiplas pastas dentro do diretório de entrada e salva os resultados diretamente
    no diretório de saída com nomes incrementados.

    Args:
        input_root (str): Diretório raiz contendo as pastas de entrada.
        output_root (str): Diretório raiz para salvar as pastas processadas.
        k (float or int): Porcentagem (0-1) ou número de variáveis a selecionar.
    """
    next_folder_number = get_next_folder_number(output_root)

    for folder_name in os.listdir(input_root):
        input_folder_path = os.path.join(input_root, folder_name)
        output_folder_name = f"{next_folder_number}-saida"
        output_folder_path = os.path.join(output_root, output_folder_name)

        if os.path.isdir(input_folder_path):
            print(f"\nProcessando pasta {folder_name} para {output_folder_name}...")
            process_dataset_in_folder(input_folder_path, output_folder_path, k=k)
            next_folder_number += 1

# Diretórios de entrada e saída
input_root_directory = r"C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output"
output_root_directory = r"C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3"

# Processar arquivos usando SelectKBest para selecionar 25% das variáveis
top_percentage = 0.25  # 25% das variáveis
process_multiple_folders(input_root_directory, output_root_directory, k=top_percentage)
# Out:
# Processando pasta 0-saida para 1-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\0-saida\cocomo81.txt
# Selecionando as top 4 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'modp', 'loc']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\1-saida\cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\0-saida\encoded_china.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'File', 'Added', 'N_effort']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\1-saida\encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\0-saida\encoded_desharnais.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'Language_3']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\1-saida\encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\0-saida\encoded_maxwell.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't07', 't10', 't11', 't14', 't15', 'app_InfServ']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\1-saida\encoded_maxwell.txt
#
# Processando pasta 1-saida para 2-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\1-saida\2-saida_cocomo81.txt
# Selecionando as top 4 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'modp', 'loc']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\2-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\1-saida\2-saida_encoded_china.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'File', 'Added', 'N_effort']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\2-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\1-saida\2-saida_encoded_desharnais.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'Language_3']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\2-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\1-saida\2-saida_encoded_maxwell.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't07', 't10', 't11', 't14', 't15', 'app_InfServ']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\2-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 10-saida para 3-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\10-saida\cocomo81.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn', 'MI_loc_rely', 'MI_loc_virt']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\3-saida\cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\10-saida\encoded_china.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['AFP', 'Added', 'N_effort', 'MI_N_effort_PDR_AFP', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Enquiry', 'MI_N_effort_Duration', 'MI_N_effort_Output', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\3-saida\encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\10-saida\encoded_desharnais.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_Language_1', 'MI_PointsAdjust_YearEnd', 'MI_Entities_Envergure']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\3-saida\encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\10-saida\encoded_maxwell.txt
# Selecionando as top 16 variáveis...
# Variáveis selecionadas: ['size_D', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t11', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_size_D_t08', 'MI_size_D_t03', 'MI_size_D_t10', 'MI_size_D_t15', 'MI_size_D_t12', 'MI_size_D_ifc_TextUI', 'MI_size_D_t01', 'MI_size_D_t04', 'MI_size_D_t06', 'MI_size_D_t13']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\3-saida\encoded_maxwell.txt
#
# Processando pasta 11-saida para 4-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\11-saida\2-saida_cocomo81.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['data', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\4-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\11-saida\2-saida_encoded_china.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['AFP', 'Added', 'N_effort', 'MI_N_effort_PDR_AFP', 'MI_N_effort_NPDU_UFP', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\4-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\11-saida\2-saida_encoded_desharnais.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['Transactions', 'PointsAdjust', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_Entities_Envergure']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\4-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\11-saida\2-saida_encoded_maxwell.txt
# Selecionando as top 11 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 't07', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t11', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\4-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 12-saida para 5-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\12-saida\2-saida_cocomo81.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\5-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\12-saida\2-saida_encoded_china.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['AFP', 'Added', 'N_effort', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Enquiry', 'MI_N_effort_Duration', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\5-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\12-saida\2-saida_encoded_desharnais.txt
# Selecionando as top 8 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_Language_1', 'MI_Entities_Envergure']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\5-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\12-saida\2-saida_encoded_maxwell.txt
# Selecionando as top 13 variáveis...
# Variáveis selecionadas: ['size_D', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t11', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_size_D_har_Mainfrm', 'MI_size_D_t10', 'MI_size_D_t15', 'MI_size_D_t12', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\5-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 13-saida para 6-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\13-saida\2-saida_cocomo81.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn', 'MI_loc_rely', 'MI_loc_vexp']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\6-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\13-saida\2-saida_encoded_china.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['AFP', 'Added', 'N_effort', 'MI_N_effort_PDR_AFP', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Enquiry', 'MI_N_effort_Duration', 'MI_N_effort_Output', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\6-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\13-saida\2-saida_encoded_desharnais.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_Language_1', 'MI_PointsAdjust_YearEnd', 'MI_Entities_Envergure']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\6-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\13-saida\2-saida_encoded_maxwell.txt
# Selecionando as top 16 variáveis...
# Variáveis selecionadas: ['size_D', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t11', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_size_D_t08', 'MI_size_D_har_Mainfrm', 'MI_size_D_t10', 'MI_size_D_t15', 'MI_size_D_t12', 'MI_size_D_ifc_TextUI', 'MI_size_D_t01', 'MI_size_D_t04', 'MI_size_D_t06', 'MI_size_D_t13']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\6-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 2-saida para 7-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\2-saida\2-saida_cocomo81.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['data', 'loc', 'Generated_Var_1', 'Generated_Var_3', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\7-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\2-saida\2-saida_encoded_china.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'File', 'Added', 'N_effort']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\7-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\2-saida\2-saida_encoded_desharnais.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_?', 'Language_3']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\7-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\2-saida\2-saida_encoded_maxwell.txt
# Selecionando as top 11 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't07', 't11', 't14', 'Generated_Var_2', 'Generated_Var_4', 'Generated_Var_6', 'Generated_Var_8', 'Generated_Var_9']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\7-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 3-saida para 8-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\3-saida\2-saida_cocomo81.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['data', 'modp', 'loc', 'Generated_Var_1', 'Generated_Var_4', 'Generated_Var_7']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\8-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\3-saida\2-saida_encoded_china.txt
# Selecionando as top 8 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Added', 'N_effort', 'Generated_Var_2']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\8-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\3-saida\2-saida_encoded_desharnais.txt
# Selecionando as top 8 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_1', 'TeamExp_?', 'ManagerExp_2', 'Language_3']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\8-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\3-saida\2-saida_encoded_maxwell.txt
# Selecionando as top 14 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't07', 't11', 't14', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12', 'Generated_Var_16', 'Generated_Var_18', 'Generated_Var_19']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\8-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 4-saida para 9-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\4-saida\2-saida_cocomo81.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['loc', 'Generated_Var_1', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_9', 'Generated_Var_11']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\9-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\4-saida\2-saida_encoded_china.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'Duration', 'N_effort']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\9-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\4-saida\2-saida_encoded_desharnais.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Generated_Var_2', 'Generated_Var_4', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_12', 'Generated_Var_16']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\9-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\4-saida\2-saida_encoded_maxwell.txt
# Selecionando as top 16 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'Generated_Var_3', 'Generated_Var_5', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_11', 'Generated_Var_12', 'Generated_Var_16', 'Generated_Var_18', 'Generated_Var_19', 'Generated_Var_20', 'Generated_Var_23', 'Generated_Var_25', 'Generated_Var_26', 'Generated_Var_28']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\9-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 5-saida para 10-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\5-saida\cocomo81.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\10-saida\cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\5-saida\encoded_china.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['N_effort', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\10-saida\encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\5-saida\encoded_desharnais.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['PointsAdjust', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\10-saida\encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\5-saida\encoded_maxwell.txt
# Selecionando as top 11 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\10-saida\encoded_maxwell.txt
#
# Processando pasta 6-saida para 11-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\6-saida\cocomo81.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['Generated_Var_1', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_8']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\11-saida\cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\6-saida\encoded_china.txt
# Selecionando as top 8 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Added', 'Duration', 'N_effort']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\11-saida\encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\6-saida\encoded_desharnais.txt
# Selecionando as top 8 variáveis...
# Variáveis selecionadas: ['Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_7', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\11-saida\encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\6-saida\encoded_maxwell.txt
# Selecionando as top 14 variáveis...
# Variáveis selecionadas: ['Generated_Var_1', 'Generated_Var_3', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_12', 'Generated_Var_13', 'Generated_Var_14', 'Generated_Var_16', 'Generated_Var_18', 'Generated_Var_19']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\11-saida\encoded_maxwell.txt
#
# Processando pasta 7-saida para 12-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\7-saida\cocomo81.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['Generated_Var_1', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_12']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\12-saida\cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\7-saida\encoded_china.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'Duration', 'N_effort']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\12-saida\encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\7-saida\encoded_desharnais.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['Generated_Var_1', 'Generated_Var_3', 'Generated_Var_5', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_13', 'Generated_Var_14', 'Generated_Var_15']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\12-saida\encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\7-saida\encoded_maxwell.txt
# Selecionando as top 16 variáveis...
# Variáveis selecionadas: ['Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12', 'Generated_Var_13', 'Generated_Var_14', 'Generated_Var_15', 'Generated_Var_16', 'Generated_Var_17', 'Generated_Var_19', 'Generated_Var_22', 'Generated_Var_23', 'Generated_Var_24']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\12-saida\encoded_maxwell.txt
#
# Processando pasta 8-saida para 13-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\8-saida\cocomo81.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['data', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\13-saida\cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\8-saida\encoded_china.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['AFP', 'Added', 'N_effort', 'MI_N_effort_PDR_AFP', 'MI_N_effort_NPDU_UFP', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\13-saida\encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\8-saida\encoded_desharnais.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['Transactions', 'PointsAdjust', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_Entities_Envergure']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\13-saida\encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\8-saida\encoded_maxwell.txt
# Selecionando as top 11 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 't07', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t11', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\13-saida\encoded_maxwell.txt
#
# Processando pasta 9-saida para 14-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\9-saida\cocomo81.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\14-saida\cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\9-saida\encoded_china.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['Added', 'N_effort', 'MI_N_effort_PDR_AFP', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Enquiry', 'MI_N_effort_Duration', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\14-saida\encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\9-saida\encoded_desharnais.txt
# Selecionando as top 8 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_Language_1', 'MI_Entities_Envergure']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\14-saida\encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\9-saida\encoded_maxwell.txt
# Selecionando as top 13 variáveis...
# Variáveis selecionadas: ['size_D', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t11', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_size_D_har_Mainfrm', 'MI_size_D_t03', 'MI_size_D_t10', 'MI_size_D_t15', 'MI_size_D_t12']
# C:\Users\CALEO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\feature_selection\_univariate_selection.py:378: RuntimeWarning: invalid value encountered in sqrt
#   X_norms = np.sqrt(row_norms(X.T, squared=True) - n_samples * X_means**2)
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\14-saida\encoded_maxwell.txt
