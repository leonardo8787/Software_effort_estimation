# %%
import os
import pandas as pd
import math
from sklearn.feature_selection import SelectKBest, f_classif, f_regression
from sklearn.preprocessing import LabelEncoder

def apply_selectkbest(data, target_column, k):
    """
    Aplica SelectKBest para selecionar as melhores variáveis em relação à coluna alvo.

    Args:
        data (pd.DataFrame): Dataset original.
        target_column (str): Nome da coluna alvo.
        k (float or int): Porcentagem (0-1) ou número de variáveis a selecionar.

    Returns:
        pd.DataFrame: Dataset com as variáveis selecionadas e a coluna alvo.
    """
    # Se a coluna alvo for categórica, usa f_classif; caso contrário, usa f_regression
    if data[target_column].dtype == 'object':
        data[target_column] = LabelEncoder().fit_transform(data[target_column])
        score_func = f_classif
    else:
        score_func = f_regression

    # Separar variáveis independentes e dependente
    X = data.drop(columns=[target_column])
    y = data[target_column]

    # Calcular o valor de k com base na porcentagem
    if isinstance(k, float) and 0 < k <= 1:
        k = max(1, math.floor(k * X.shape[1]))  # Arredonda para baixo e garante pelo menos 1

    print(f"Selecionando as top {k} variáveis...")

    # Aplicar SelectKBest
    selector = SelectKBest(score_func=score_func, k=k)
    X_new = selector.fit_transform(X, y)

    # Identificar colunas selecionadas
    selected_columns = X.columns[selector.get_support()]

    print(f"Variáveis selecionadas: {list(selected_columns)}")

    # Reconstruir o DataFrame com as variáveis selecionadas e a coluna alvo
    new_data = pd.DataFrame(X_new, columns=selected_columns)
    new_data[target_column] = y.values

    return new_data

def get_next_folder_number(output_root):
    """
    Determina o próximo número de pasta disponível no diretório de saída.

    Args:
        output_root (str): Diretório raiz para salvar as pastas processadas.

    Returns:
        int: O próximo número disponível para a pasta de saída.
    """
    existing_folders = [
        folder for folder in os.listdir(output_root) if os.path.isdir(os.path.join(output_root, folder))
    ]
    numbered_folders = [
        int(folder.split("-")[0]) for folder in existing_folders if folder.split("-")[0].isdigit()
    ]
    return max(numbered_folders, default=0) + 1

def process_dataset_in_folder(input_dir, output_dir, k):
    """
    Processa os datasets em uma pasta e salva os resultados em outra pasta correspondente.

    Args:
        input_dir (str): Caminho do diretório de entrada.
        output_dir (str): Caminho do diretório de saída.
        k (float or int): Porcentagem (0-1) ou número de variáveis a selecionar.
    """
    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith(".txt"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            print(f"Processando arquivo: {input_path}")
            try:
                data = pd.read_csv(input_path, delimiter=",", skipinitialspace=True)
                target_column = data.columns[-1]  # Assume que a última coluna é a coluna alvo

                # Aplicar SelectKBest
                new_data = apply_selectkbest(data, target_column, k)

                # Salvar o novo dataset
                new_data.to_csv(output_path, sep=",", index=False)
                print(f"Arquivo processado e salvo em: {output_path}")

            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

def process_multiple_folders(input_root, output_root, k):
    """
    Processa múltiplas pastas dentro do diretório de entrada e salva os resultados diretamente
    no diretório de saída com nomes incrementados.

    Args:
        input_root (str): Diretório raiz contendo as pastas de entrada.
        output_root (str): Diretório raiz para salvar as pastas processadas.
        k (float or int): Porcentagem (0-1) ou número de variáveis a selecionar.
    """
    next_folder_number = get_next_folder_number(output_root)

    for folder_name in os.listdir(input_root):
        input_folder_path = os.path.join(input_root, folder_name)
        output_folder_name = f"{next_folder_number}-saida"
        output_folder_path = os.path.join(output_root, output_folder_name)

        if os.path.isdir(input_folder_path):
            print(f"\nProcessando pasta {folder_name} para {output_folder_name}...")
            process_dataset_in_folder(input_folder_path, output_folder_path, k=k)
            next_folder_number += 1

# Diretórios de entrada e saída
input_root_directory = r"C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output"
output_root_directory = r"C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3"

# Processar arquivos usando SelectKBest para selecionar 25% das variáveis
top_percentage = 0.75  # 75% das variáveis
process_multiple_folders(input_root_directory, output_root_directory, k=top_percentage)
# Out:
# Processando pasta 0-saida para 29-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\0-saida\cocomo81.txt
# Selecionando as top 12 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'aexp', 'pcap', 'vexp', 'lexp', 'modp', 'loc']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\29-saida\cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\0-saida\encoded_china.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_AFP', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Resource_1', 'Resource_4']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\29-saida\encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\0-saida\encoded_desharnais.txt
# Selecionando as top 16 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_0', 'TeamExp_1', 'TeamExp_2', 'TeamExp_4', 'TeamExp_?', 'ManagerExp_0', 'ManagerExp_2', 'ManagerExp_3', 'ManagerExp_4', 'ManagerExp_5', 'Language_1', 'Language_3']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\29-saida\encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\0-saida\encoded_maxwell.txt
# Selecionando as top 27 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't01', 't02', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'app_CustServ', 'app_InfServ', 'app_ProdCont', 'app_TransPro', 'har_Multi', 'har_Network', 'har_PC', 'dba_Other', 'ifc_GUI', 'ifc_TextUI', 'telonuse_No', 'telonuse_Yes']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\29-saida\encoded_maxwell.txt
#
# Processando pasta 1-saida para 30-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\1-saida\2-saida_cocomo81.txt
# Selecionando as top 12 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'aexp', 'pcap', 'vexp', 'lexp', 'modp', 'loc']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\30-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\1-saida\2-saida_encoded_china.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_AFP', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Resource_1', 'Resource_4']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\30-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\1-saida\2-saida_encoded_desharnais.txt
# Selecionando as top 16 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_0', 'TeamExp_1', 'TeamExp_2', 'TeamExp_4', 'TeamExp_?', 'ManagerExp_0', 'ManagerExp_2', 'ManagerExp_3', 'ManagerExp_4', 'ManagerExp_5', 'Language_1', 'Language_3']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\30-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\1-saida\2-saida_encoded_maxwell.txt
# Selecionando as top 27 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't01', 't02', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'app_CustServ', 'app_InfServ', 'app_ProdCont', 'app_TransPro', 'har_Multi', 'har_Network', 'har_PC', 'dba_Other', 'ifc_GUI', 'ifc_TextUI', 'telonuse_No', 'telonuse_Yes']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\30-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 10-saida para 31-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\10-saida\cocomo81.txt
# Selecionando as top 21 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'modp', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn', 'MI_loc_pcap', 'MI_loc_rely', 'MI_loc_virt', 'MI_loc_acap', 'MI_loc_vexp', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\31-saida\cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\10-saida\encoded_china.txt
# Selecionando as top 27 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_AFP', 'PDR_UFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Resource_4', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_Added', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Enquiry', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_Input', 'MI_N_effort_Duration', 'MI_N_effort_File', 'MI_N_effort_Output', 'MI_N_effort_Resource_1', 'MI_N_effort_Resource_2', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\31-saida\encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\10-saida\encoded_desharnais.txt
# Selecionando as top 28 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_0', 'TeamExp_1', 'TeamExp_2', 'TeamExp_4', 'TeamExp_?', 'ManagerExp_2', 'ManagerExp_3', 'ManagerExp_4', 'Language_1', 'Language_3', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_Language_3', 'MI_PointsAdjust_Language_2', 'MI_PointsAdjust_Language_1', 'MI_PointsAdjust_ManagerExp_4', 'MI_PointsAdjust_ManagerExp_2', 'MI_PointsAdjust_ManagerExp_3', 'MI_PointsAdjust_TeamExp_?', 'MI_PointsAdjust_TeamExp_0', 'MI_PointsAdjust_ManagerExp_5', 'MI_PointsAdjust_YearEnd', 'MI_Entities_Envergure']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\31-saida\encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\10-saida\encoded_maxwell.txt
# Selecionando as top 48 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't01', 't02', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'app_CustServ', 'app_InfServ', 'app_TransPro', 'har_Multi', 'har_Network', 'har_PC', 'dba_Other', 'ifc_GUI', 'ifc_TextUI', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t11', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_size_D_app_InfServ', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_size_D_har_Mainfrm', 'MI_size_D_t03', 'MI_size_D_t14', 'MI_size_D_t10', 'MI_size_D_t15', 'MI_size_D_t12', 'MI_size_D_telonuse_Yes', 'MI_size_D_ifc_TextUI', 'MI_size_D_t05', 'MI_size_D_har_Multi', 'MI_size_D_t01', 'MI_size_D_t04', 'MI_size_D_t06', 'MI_size_D_t13', 'MI_size_D_app_CustServ', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\31-saida\encoded_maxwell.txt
#
# Processando pasta 11-saida para 32-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\11-saida\2-saida_cocomo81.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'vexp', 'lexp', 'modp', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\32-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\11-saida\2-saida_encoded_china.txt
# Selecionando as top 19 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_AFP', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Resource_4', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_Added', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\32-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\11-saida\2-saida_encoded_desharnais.txt
# Selecionando as top 20 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_0', 'TeamExp_1', 'TeamExp_2', 'TeamExp_4', 'TeamExp_?', 'ManagerExp_2', 'ManagerExp_3', 'ManagerExp_4', 'ManagerExp_5', 'Language_1', 'Language_3', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_Language_3', 'MI_Entities_Envergure']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\32-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\11-saida\2-saida_encoded_maxwell.txt
# Selecionando as top 34 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't01', 't02', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'app_CustServ', 'app_InfServ', 'app_ProdCont', 'app_TransPro', 'har_Multi', 'har_Network', 'har_PC', 'dba_Other', 'ifc_GUI', 'ifc_TextUI', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t11', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_size_D_app_InfServ', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\32-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 12-saida para 33-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\12-saida\2-saida_cocomo81.txt
# Selecionando as top 18 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'lexp', 'modp', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn', 'MI_loc_pcap', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\33-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\12-saida\2-saida_encoded_china.txt
# Selecionando as top 23 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_AFP', 'PDR_UFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Resource_4', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_Added', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Enquiry', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_Input', 'MI_N_effort_Duration', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\33-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\12-saida\2-saida_encoded_desharnais.txt
# Selecionando as top 24 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_0', 'TeamExp_1', 'TeamExp_2', 'TeamExp_4', 'TeamExp_?', 'ManagerExp_2', 'ManagerExp_3', 'ManagerExp_4', 'Language_1', 'Language_3', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_Language_3', 'MI_PointsAdjust_Language_2', 'MI_PointsAdjust_Language_1', 'MI_PointsAdjust_ManagerExp_4', 'MI_PointsAdjust_ManagerExp_2', 'MI_PointsAdjust_ManagerExp_3', 'MI_Entities_Envergure']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\33-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\12-saida\2-saida_encoded_maxwell.txt
# Selecionando as top 41 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't01', 't02', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'app_CustServ', 'app_InfServ', 'app_TransPro', 'har_Multi', 'har_Network', 'har_PC', 'dba_Other', 'ifc_GUI', 'ifc_TextUI', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t11', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_size_D_app_InfServ', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_size_D_har_Mainfrm', 'MI_size_D_t03', 'MI_size_D_t14', 'MI_size_D_t10', 'MI_size_D_t15', 'MI_size_D_t12', 'MI_size_D_app_ProdCont', 'MI_size_D_telonuse_Yes', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\33-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 13-saida para 34-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\13-saida\2-saida_cocomo81.txt
# Selecionando as top 21 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'modp', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn', 'MI_loc_pcap', 'MI_loc_rely', 'MI_loc_virt', 'MI_loc_acap', 'MI_loc_vexp', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\34-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\13-saida\2-saida_encoded_china.txt
# Selecionando as top 27 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_AFP', 'PDR_UFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Resource_4', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_Added', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Enquiry', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_Input', 'MI_N_effort_Duration', 'MI_N_effort_File', 'MI_N_effort_Output', 'MI_N_effort_Resource_1', 'MI_N_effort_Resource_2', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\34-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\13-saida\2-saida_encoded_desharnais.txt
# Selecionando as top 28 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_0', 'TeamExp_1', 'TeamExp_2', 'TeamExp_4', 'TeamExp_?', 'ManagerExp_2', 'ManagerExp_3', 'ManagerExp_4', 'Language_1', 'Language_3', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_Language_3', 'MI_PointsAdjust_Language_2', 'MI_PointsAdjust_Language_1', 'MI_PointsAdjust_ManagerExp_4', 'MI_PointsAdjust_ManagerExp_2', 'MI_PointsAdjust_ManagerExp_3', 'MI_PointsAdjust_TeamExp_?', 'MI_PointsAdjust_TeamExp_0', 'MI_PointsAdjust_ManagerExp_5', 'MI_PointsAdjust_YearEnd', 'MI_Entities_Envergure']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\34-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\13-saida\2-saida_encoded_maxwell.txt
# Selecionando as top 48 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't01', 't02', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'app_CustServ', 'app_InfServ', 'app_TransPro', 'har_Multi', 'har_Network', 'har_PC', 'dba_Other', 'ifc_GUI', 'ifc_TextUI', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t11', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_size_D_app_InfServ', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_size_D_har_Mainfrm', 'MI_size_D_t03', 'MI_size_D_t14', 'MI_size_D_t10', 'MI_size_D_t15', 'MI_size_D_t12', 'MI_size_D_telonuse_Yes', 'MI_size_D_ifc_TextUI', 'MI_size_D_t05', 'MI_size_D_har_Multi', 'MI_size_D_t01', 'MI_size_D_t04', 'MI_size_D_t06', 'MI_size_D_t13', 'MI_size_D_app_CustServ', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\34-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 2-saida para 35-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\2-saida\2-saida_cocomo81.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'vexp', 'lexp', 'modp', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\35-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\2-saida\2-saida_encoded_china.txt
# Selecionando as top 19 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'Changed', 'PDR_AFP', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Resource_1', 'Resource_3', 'Resource_4', 'Generated_Var_3', 'Generated_Var_5']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\35-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\2-saida\2-saida_encoded_desharnais.txt
# Selecionando as top 20 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_0', 'TeamExp_1', 'TeamExp_2', 'TeamExp_4', 'TeamExp_?', 'ManagerExp_2', 'ManagerExp_3', 'ManagerExp_4', 'ManagerExp_5', 'Language_1', 'Language_3', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\35-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\2-saida\2-saida_encoded_maxwell.txt
# Selecionando as top 34 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't01', 't02', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'app_CustServ', 'app_InfServ', 'app_ProdCont', 'app_TransPro', 'har_Multi', 'har_Network', 'har_PC', 'dba_Other', 'ifc_GUI', 'ifc_TextUI', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\35-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 3-saida para 36-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\3-saida\2-saida_cocomo81.txt
# Selecionando as top 18 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'vexp', 'lexp', 'modp', 'loc', 'Generated_Var_1', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\36-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\3-saida\2-saida_encoded_china.txt
# Selecionando as top 24 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'Changed', 'PDR_AFP', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Resource_1', 'Resource_3', 'Resource_4', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\36-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\3-saida\2-saida_encoded_desharnais.txt
# Selecionando as top 24 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_0', 'TeamExp_1', 'TeamExp_2', 'TeamExp_4', 'TeamExp_?', 'ManagerExp_0', 'ManagerExp_1', 'ManagerExp_2', 'ManagerExp_3', 'ManagerExp_4', 'ManagerExp_5', 'Language_1', 'Language_3', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_9', 'Generated_Var_11']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\36-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\3-saida\2-saida_encoded_maxwell.txt
# Selecionando as top 42 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't01', 't02', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'app_CustServ', 'app_InfServ', 'app_ProdCont', 'app_TransPro', 'har_Multi', 'har_Network', 'har_PC', 'dba_Other', 'ifc_GUI', 'ifc_TextUI', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12', 'Generated_Var_13', 'Generated_Var_14', 'Generated_Var_15', 'Generated_Var_16', 'Generated_Var_18', 'Generated_Var_19']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\36-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 4-saida para 37-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\4-saida\2-saida_cocomo81.txt
# Selecionando as top 21 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'modp', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\37-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\4-saida\2-saida_encoded_china.txt
# Selecionando as top 27 variáveis...
# C:\Users\CALEO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\feature_selection\_univariate_selection.py:378: RuntimeWarning: invalid value encountered in sqrt
#   X_norms = np.sqrt(row_norms(X.T, squared=True) - n_samples * X_means**2)
# Variáveis selecionadas: ['ID', 'AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'Changed', 'Deleted', 'PDR_AFP', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Resource_1', 'Resource_2', 'Resource_3', 'Resource_4', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_6', 'Generated_Var_12', 'Generated_Var_14', 'Generated_Var_15', 'Generated_Var_16']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\37-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\4-saida\2-saida_encoded_desharnais.txt
# Selecionando as top 29 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_0', 'TeamExp_1', 'TeamExp_2', 'TeamExp_4', 'TeamExp_?', 'ManagerExp_2', 'ManagerExp_3', 'ManagerExp_4', 'Language_1', 'Language_3', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12', 'Generated_Var_14', 'Generated_Var_15', 'Generated_Var_16', 'Generated_Var_17']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\37-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\4-saida\2-saida_encoded_maxwell.txt
# Selecionando as top 48 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't01', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'app_CustServ', 'app_InfServ', 'app_TransPro', 'har_Multi', 'har_Network', 'har_PC', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12', 'Generated_Var_13', 'Generated_Var_14', 'Generated_Var_15', 'Generated_Var_16', 'Generated_Var_17', 'Generated_Var_18', 'Generated_Var_19', 'Generated_Var_20', 'Generated_Var_21', 'Generated_Var_22', 'Generated_Var_23', 'Generated_Var_24', 'Generated_Var_25', 'Generated_Var_26', 'Generated_Var_27', 'Generated_Var_28']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\37-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 5-saida para 38-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\5-saida\cocomo81.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'vexp', 'lexp', 'modp', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\38-saida\cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\5-saida\encoded_china.txt
# Selecionando as top 19 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_AFP', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Resource_4', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\38-saida\encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\5-saida\encoded_desharnais.txt
# Selecionando as top 20 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_0', 'TeamExp_1', 'TeamExp_2', 'TeamExp_4', 'TeamExp_?', 'ManagerExp_2', 'ManagerExp_3', 'ManagerExp_4', 'ManagerExp_5', 'Language_1', 'Language_3', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\38-saida\encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\5-saida\encoded_maxwell.txt
# Selecionando as top 34 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't01', 't02', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'app_CustServ', 'app_InfServ', 'app_ProdCont', 'app_TransPro', 'har_Multi', 'har_Network', 'har_PC', 'dba_Other', 'ifc_GUI', 'ifc_TextUI', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\38-saida\encoded_maxwell.txt
#
# Processando pasta 6-saida para 39-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\6-saida\cocomo81.txt
# Selecionando as top 18 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'lexp', 'modp', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\39-saida\cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\6-saida\encoded_china.txt
# Selecionando as top 24 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'Changed', 'PDR_AFP', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Resource_1', 'Resource_3', 'Resource_4', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_5', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\39-saida\encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\6-saida\encoded_desharnais.txt
# Selecionando as top 24 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_0', 'TeamExp_1', 'TeamExp_2', 'TeamExp_4', 'TeamExp_?', 'ManagerExp_2', 'ManagerExp_3', 'Language_1', 'Language_3', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\39-saida\encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\6-saida\encoded_maxwell.txt
# Selecionando as top 42 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't01', 't02', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'app_CustServ', 'app_InfServ', 'app_TransPro', 'har_Multi', 'har_Network', 'har_PC', 'ifc_GUI', 'ifc_TextUI', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12', 'Generated_Var_13', 'Generated_Var_14', 'Generated_Var_15', 'Generated_Var_16', 'Generated_Var_17', 'Generated_Var_18', 'Generated_Var_19']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\39-saida\encoded_maxwell.txt
#
# Processando pasta 7-saida para 40-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\7-saida\cocomo81.txt
# Selecionando as top 21 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'modp', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\40-saida\cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\7-saida\encoded_china.txt
# Selecionando as top 27 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'Changed', 'PDR_AFP', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Resource_1', 'Resource_3', 'Resource_4', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_12', 'Generated_Var_15', 'Generated_Var_16']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\40-saida\encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\7-saida\encoded_desharnais.txt
# Selecionando as top 29 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_0', 'TeamExp_1', 'TeamExp_4', 'TeamExp_?', 'ManagerExp_2', 'ManagerExp_3', 'Language_1', 'Language_3', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12', 'Generated_Var_13', 'Generated_Var_14', 'Generated_Var_15', 'Generated_Var_16', 'Generated_Var_17']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\40-saida\encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\7-saida\encoded_maxwell.txt
# Selecionando as top 48 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't01', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'app_CustServ', 'app_InfServ', 'app_TransPro', 'har_Multi', 'har_Network', 'har_PC', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12', 'Generated_Var_13', 'Generated_Var_14', 'Generated_Var_15', 'Generated_Var_16', 'Generated_Var_17', 'Generated_Var_18', 'Generated_Var_19', 'Generated_Var_20', 'Generated_Var_21', 'Generated_Var_22', 'Generated_Var_23', 'Generated_Var_24', 'Generated_Var_25', 'Generated_Var_26', 'Generated_Var_27', 'Generated_Var_28']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\40-saida\encoded_maxwell.txt
#
# Processando pasta 8-saida para 41-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\8-saida\cocomo81.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'vexp', 'lexp', 'modp', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\41-saida\cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\8-saida\encoded_china.txt
# Selecionando as top 19 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_AFP', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Resource_4', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_Added', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\41-saida\encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\8-saida\encoded_desharnais.txt
# Selecionando as top 20 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_0', 'TeamExp_1', 'TeamExp_2', 'TeamExp_4', 'TeamExp_?', 'ManagerExp_2', 'ManagerExp_3', 'ManagerExp_4', 'ManagerExp_5', 'Language_1', 'Language_3', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_Language_3', 'MI_Entities_Envergure']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\41-saida\encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\8-saida\encoded_maxwell.txt
# Selecionando as top 34 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't01', 't02', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'app_CustServ', 'app_InfServ', 'app_ProdCont', 'app_TransPro', 'har_Multi', 'har_Network', 'har_PC', 'dba_Other', 'ifc_GUI', 'ifc_TextUI', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t11', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_size_D_app_InfServ', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\41-saida\encoded_maxwell.txt
#
# Processando pasta 9-saida para 42-saida...
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\9-saida\cocomo81.txt
# Selecionando as top 18 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'lexp', 'modp', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn', 'MI_loc_pcap', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\42-saida\cocomo81.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\9-saida\encoded_china.txt
# Selecionando as top 23 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_AFP', 'PDR_UFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Resource_4', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_Added', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Enquiry', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_Input', 'MI_N_effort_Duration', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\42-saida\encoded_china.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\9-saida\encoded_desharnais.txt
# Selecionando as top 24 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'TeamExp_0', 'TeamExp_1', 'TeamExp_2', 'TeamExp_4', 'TeamExp_?', 'ManagerExp_2', 'ManagerExp_3', 'ManagerExp_4', 'Language_1', 'Language_3', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_Language_3', 'MI_PointsAdjust_Language_2', 'MI_PointsAdjust_Language_1', 'MI_PointsAdjust_ManagerExp_4', 'MI_PointsAdjust_ManagerExp_2', 'MI_PointsAdjust_ManagerExp_3', 'MI_Entities_Envergure']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\42-saida\encoded_desharnais.txt
# Processando arquivo: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output\9-saida\encoded_maxwell.txt
# Selecionando as top 41 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't01', 't02', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'app_CustServ', 'app_InfServ', 'app_TransPro', 'har_Multi', 'har_Network', 'har_PC', 'dba_Other', 'ifc_GUI', 'ifc_TextUI', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t11', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_size_D_app_InfServ', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_size_D_har_Mainfrm', 'MI_size_D_t03', 'MI_size_D_t14', 'MI_size_D_t10', 'MI_size_D_t15', 'MI_size_D_t12', 'MI_size_D_app_ProdCont', 'MI_size_D_telonuse_Yes', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\\Users\\CALEO\\OneDrive - Hexagon\\Documents\\GitHub\\Software_effort_estimation\\proposal\\algorithms\\abordagens\\output3\42-saida\encoded_maxwell.txt
