# %% [markdown]
# # Aplica correlação para excluir variáveis correlacionadas

# %%
import os
import pandas as pd
import numpy as np

def calculate_correlation_matrix(data, target_column, correlation_threshold=0.9):
    """
    Calcula a matriz de correlação e identifica variáveis altamente correlacionadas.

    Args:
        data (pd.DataFrame): Dataset contendo as variáveis.
        target_column (str): Nome da coluna alvo.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.

    Returns:
        list: Lista de variáveis a serem removidas.
    """
    correlation_matrix = data.drop(columns=[target_column]).corr()
    columns_to_remove = set()

    for i in range(len(correlation_matrix.columns)):
        for j in range(i):
            if abs(correlation_matrix.iloc[i, j]) > correlation_threshold:
                col_to_remove = correlation_matrix.columns[i]
                columns_to_remove.add(col_to_remove)
    
    return list(columns_to_remove)

def remove_highly_correlated_features(data, target_column, correlation_threshold=0.9):
    """
    Remove variáveis altamente correlacionadas com base em um limite.

    Args:
        data (pd.DataFrame): Dataset original.
        target_column (str): Nome da coluna alvo.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.

    Returns:
        pd.DataFrame: Dataset com variáveis correlacionadas removidas.
    """
    columns_to_remove = calculate_correlation_matrix(data, target_column, correlation_threshold)
    print(f"Variáveis removidas devido à alta correlação: {columns_to_remove}")
    return data.drop(columns=columns_to_remove)

def get_next_folder_name(output_root):
    """
    Calcula o próximo nome de pasta numerado com base nas pastas existentes no diretório de saída.

    Args:
        output_root (str): Diretório raiz para as pastas de saída.

    Returns:
        int: Próximo número disponível para a pasta.
    """
    existing_folders = [
        folder for folder in os.listdir(output_root) if os.path.isdir(os.path.join(output_root, folder))
    ]
    numbered_folders = [
        int(folder.split("-")[0]) for folder in existing_folders if folder.split("-")[0].isdigit()
    ]
    return max(numbered_folders, default=0) + 1

def process_dataset_in_folder(input_dir, output_dir, correlation_threshold=0.9):
    """
    Processa os datasets em uma pasta, remove variáveis correlacionadas e salva os resultados.

    Args:
        input_dir (str): Caminho do diretório de entrada.
        output_dir (str): Caminho do diretório de saída.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.
    """
    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith(".txt"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            print(f"Processando arquivo: {input_path}")
            try:
                data = pd.read_csv(input_path, delimiter=",", skipinitialspace=True)
                target_column = data.columns[-1]

                # Remover variáveis altamente correlacionadas
                data_cleaned = remove_highly_correlated_features(data, target_column, correlation_threshold)

                # Reorganizar as colunas para manter a coluna alvo no final
                columns = [col for col in data_cleaned.columns if col != target_column] + [target_column]
                data_cleaned = data_cleaned[columns]

                data_cleaned.to_csv(output_path, sep=",", index=False)
                print(f"Arquivo processado e salvo em: {output_path}")

            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

def process_multiple_folders(input_root, output_root, correlation_threshold=0.9):
    """
    Processa múltiplas pastas dentro do diretório de entrada e salva os resultados diretamente
    no diretório de saída com nomes incrementados.

    Args:
        input_root (str): Diretório raiz contendo as pastas de entrada.
        output_root (str): Diretório raiz para salvar as pastas processadas.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.
    """
    next_folder_number = get_next_folder_name(output_root)

    for folder_name in os.listdir(input_root):
        input_folder_path = os.path.join(input_root, folder_name)

        if os.path.isdir(input_folder_path):  # Verifica se é uma pasta
            output_folder_name = f"{next_folder_number}-saida"
            output_folder_path = os.path.join(output_root, output_folder_name)

            print(f"\nProcessando pasta {folder_name} e salvando em: {output_folder_path}")
            process_dataset_in_folder(input_folder_path, output_folder_path, correlation_threshold)

            next_folder_number += 1

# Diretórios de entrada e saída
input_root_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output"
output_root_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2"

# Processar arquivos removendo variáveis correlacionadas
process_multiple_folders(input_root_directory, output_root_directory, correlation_threshold=0.8)
# Out:
# Processando pasta 0-saida e salvando em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\14-saida
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\0-saida\cocomo81.txt
# Variáveis removidas devido à alta correlação: []
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\14-saida\cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\0-saida\encoded_china.txt
# Variáveis removidas devido à alta correlação: ['NPDR_AFP', 'PDR_UFP', 'File', 'NPDU_UFP', 'Added', 'Input']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\14-saida\encoded_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\0-saida\encoded_desharnais.txt
# Variáveis removidas devido à alta correlação: ['PointsAdjust']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\14-saida\encoded_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\0-saida\encoded_maxwell.txt
# Variáveis removidas devido à alta correlação: ['source_Outsrced', 'ifc_TextUI', 'telonuse_Yes', 'dba_Sequential']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\14-saida\encoded_maxwell.txt
#
# Processando pasta 1-saida e salvando em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\15-saida
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\1-saida\2-saida_cocomo81.txt
# Variáveis removidas devido à alta correlação: []
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\15-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\1-saida\2-saida_encoded_china.txt
# Variáveis removidas devido à alta correlação: ['NPDR_AFP', 'PDR_UFP', 'File', 'NPDU_UFP', 'Added', 'Input']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\15-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\1-saida\2-saida_encoded_desharnais.txt
# Variáveis removidas devido à alta correlação: ['PointsAdjust']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\15-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\1-saida\2-saida_encoded_maxwell.txt
# Variáveis removidas devido à alta correlação: ['source_Outsrced', 'ifc_TextUI', 'telonuse_Yes', 'dba_Sequential']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\15-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 10-saida e salvando em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\16-saida
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\10-saida\cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_acap', 'MI_loc_turn', 'MI_loc_virt', 'MI_loc_rely', 'MI_loc_time', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_cplx', 'MI_loc_vexp', 'MI_aexp_data', 'MI_loc_aexp', 'MI_loc_pcap']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\16-saida\cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\10-saida\encoded_china.txt
# Variáveis removidas devido à alta correlação: ['MI_N_effort_File', 'NPDR_AFP', 'MI_N_effort_Input', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_Duration', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Output', 'PDR_UFP', 'MI_AFP_PDR_AFP', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_AFP', 'File', 'NPDU_UFP', 'Added', 'MI_N_effort_Added', 'Input', 'MI_N_effort_Changed']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\16-saida\encoded_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\10-saida\encoded_desharnais.txt
# Variáveis removidas devido à alta correlação: ['MI_PointsAdjust_Language_3', 'MI_PointsAdjust_ManagerExp_0', 'MI_PointsAdjust_ManagerExp_4', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_TeamExp_?', 'MI_PointsAdjust_ManagerExp_2', 'MI_PointsAdjust_YearEnd', 'PointsAdjust', 'MI_PointsAdjust_Language_2', 'MI_PointsAdjust_ManagerExp_3', 'MI_PointsAdjust_TeamExp_3', 'MI_Entities_Envergure', 'MI_PointsAdjust_ManagerExp_5', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_TeamExp_0']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\16-saida\encoded_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\10-saida\encoded_maxwell.txt
# Variáveis removidas devido à alta correlação: ['ifc_TextUI', 'MI_size_D_har_Multi', 'MI_size_D_t06', 'MI_size_D_app_MIS', 'MI_size_D_ifc_TextUI', 'MI_size_D_app_CustServ', 'MI_size_D_t01', 'MI_duration_D_t07', 'MI_size_D_t14', 'source_Outsrced', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_size_D_t02', 'MI_size_D_t07', 'MI_size_D_t10', 'MI_size_D_t08', 'MI_size_D_t12', 'MI_size_D_app_ProdCont', 'dba_Sequential', 'MI_size_D_ifc_GUI', 'telonuse_Yes', 'MI_size_D_t11', 'MI_size_D_t04', 'MI_size_D_t13', 'MI_size_D_t15', 'MI_size_D_t05', 'MI_size_D_t03', 'MI_size_D_duration_D']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\16-saida\encoded_maxwell.txt
#
# Processando pasta 11-saida e salvando em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\17-saida
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\11-saida\2-saida_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_data', 'MI_loc_stor', 'MI_loc_aexp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\17-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\11-saida\2-saida_encoded_china.txt
# Variáveis removidas devido à alta correlação: ['NPDR_AFP', 'MI_N_effort_NPDU_UFP', 'PDR_UFP', 'MI_AFP_PDR_AFP', 'MI_N_effort_AFP', 'File', 'NPDU_UFP', 'Added', 'MI_N_effort_Added', 'Input']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\17-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\11-saida\2-saida_encoded_desharnais.txt
# Variáveis removidas devido à alta correlação: ['MI_PointsAdjust_Transactions', 'PointsAdjust', 'MI_Entities_Envergure', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\17-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\11-saida\2-saida_encoded_maxwell.txt
# Variáveis removidas devido à alta correlação: ['ifc_TextUI', 'telonuse_Yes', 'MI_size_D_t11', 'MI_size_D_t02', 'MI_size_D_t07', 'dba_Sequential', 'MI_size_D_t09', 'MI_size_D_t08', 'MI_duration_D_t07', 'source_Outsrced', 'MI_size_D_duration_D', 'MI_size_D_nlan']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\17-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 12-saida e salvando em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\18-saida
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\12-saida\2-saida_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_turn', 'MI_loc_time', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_cplx', 'MI_loc_aexp', 'MI_loc_pcap']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\18-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\12-saida\2-saida_encoded_china.txt
# Variáveis removidas devido à alta correlação: ['NPDR_AFP', 'MI_N_effort_Input', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_Duration', 'MI_N_effort_PDR_UFP', 'PDR_UFP', 'MI_AFP_PDR_AFP', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_AFP', 'File', 'NPDU_UFP', 'Added', 'MI_N_effort_Added', 'Input']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\18-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\12-saida\2-saida_encoded_desharnais.txt
# Variáveis removidas devido à alta correlação: ['MI_PointsAdjust_Transactions', 'MI_PointsAdjust_ManagerExp_2', 'PointsAdjust', 'MI_PointsAdjust_TeamExp_3', 'MI_Entities_Envergure', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\18-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\12-saida\2-saida_encoded_maxwell.txt
# Variáveis removidas devido à alta correlação: ['ifc_TextUI', 'telonuse_Yes', 'MI_size_D_t11', 'MI_size_D_t02', 'MI_size_D_t12', 'MI_size_D_t07', 'MI_size_D_app_ProdCont', 'MI_size_D_t15', 'dba_Sequential', 'MI_size_D_app_MIS', 'MI_size_D_t10', 'MI_size_D_t09', 'MI_size_D_t08', 'MI_duration_D_t07', 'MI_size_D_t14', 'source_Outsrced', 'MI_size_D_duration_D', 'MI_size_D_nlan']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\18-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 2-saida e salvando em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\19-saida
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\2-saida\2-saida_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_4', 'Generated_Var_2', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\19-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\2-saida\2-saida_encoded_china.txt
# Variáveis removidas devido à alta correlação: ['NPDR_AFP', 'Generated_Var_5', 'PDR_UFP', 'Generated_Var_4', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'File', 'NPDU_UFP', 'Added', 'Input']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\19-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\2-saida\2-saida_encoded_desharnais.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_5', 'PointsAdjust', 'Generated_Var_4', 'Generated_Var_2', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\19-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\2-saida\2-saida_encoded_maxwell.txt
# Variáveis removidas devido à alta correlação: ['ifc_TextUI', 'telonuse_Yes', 'Generated_Var_5', 'Generated_Var_6', 'dba_Sequential', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_8', 'Generated_Var_7', 'source_Outsrced', 'Generated_Var_9']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\19-saida\2-saida_encoded_maxwell.txt
#
# Processando pasta 3-saida e salvando em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\20-saida
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\3-saida\2-saida_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_5', 'Generated_Var_6', 'Generated_Var_4', 'Generated_Var_3', 'Generated_Var_7']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\20-saida\2-saida_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\3-saida\2-saida_encoded_china.txt
# Variáveis removidas devido à alta correlação: ['NPDR_AFP', 'Generated_Var_10', 'PDR_UFP', 'Generated_Var_6', 'Generated_Var_11', 'Generated_Var_3', 'Generated_Var_8', 'File', 'NPDU_UFP', 'Added', 'Input', 'Generated_Var_9']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\20-saida\2-saida_encoded_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\3-saida\2-saida_encoded_desharnais.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_10', 'Generated_Var_5', 'Generated_Var_6', 'PointsAdjust', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_8', 'Generated_Var_11', 'Generated_Var_7', 'Generated_Var_9']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\20-saida\2-saida_encoded_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output
: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\25-saida
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\8-saida\cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_data', 'MI_loc_stor', 'MI_aexp_data', 'MI_loc_aexp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\25-saida\cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\8-saida\encoded_china.txt
# Variáveis removidas devido à alta correlação: ['NPDR_AFP', 'MI_N_effort_NPDU_UFP', 'PDR_UFP', 'MI_AFP_PDR_AFP', 'MI_N_effort_AFP', 'File', 'NPDU_UFP', 'Added', 'MI_N_effort_Added', 'Input']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\25-saida\encoded_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\8-saida\encoded_desharnais.txt
# Variáveis removidas devido à alta correlação: ['MI_PointsAdjust_Language_3', 'MI_PointsAdjust_Transactions', 'PointsAdjust', 'MI_Entities_Envergure', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\25-saida\encoded_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\8-saida\encoded_maxwell.txt
# Variáveis removidas devido à alta correlação: ['ifc_TextUI', 'telonuse_Yes', 'MI_size_D_t11', 'MI_size_D_t02', 'MI_size_D_t07', 'dba_Sequential', 'MI_size_D_t09', 'MI_size_D_t08', 'MI_duration_D_t07', 'source_Outsrced', 'MI_size_D_duration_D', 'MI_size_D_nlan']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\25-saida\encoded_maxwell.txt
#
# Processando pasta 9-saida e salvando em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\26-saida
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\9-saida\cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_turn', 'MI_loc_time', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_cplx', 'MI_aexp_data', 'MI_loc_aexp', 'MI_loc_pcap']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\26-saida\cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\9-saida\encoded_china.txt
# Variáveis removidas devido à alta correlação: ['NPDR_AFP', 'MI_N_effort_Input', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_Duration', 'MI_N_effort_PDR_UFP', 'PDR_UFP', 'MI_AFP_PDR_AFP', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_AFP', 'File', 'NPDU_UFP', 'Added', 'MI_N_effort_Added', 'Input']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\26-saida\encoded_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\9-saida\encoded_desharnais.txt
# Variáveis removidas devido à alta correlação: ['MI_PointsAdjust_Language_3', 'MI_PointsAdjust_ManagerExp_4', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_ManagerExp_2', 'PointsAdjust', 'MI_PointsAdjust_Language_2', 'MI_PointsAdjust_ManagerExp_3', 'MI_PointsAdjust_TeamExp_3', 'MI_Entities_Envergure', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\26-saida\encoded_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output\9-saida\encoded_maxwell.txt
# Variáveis removidas devido à alta correlação: ['ifc_TextUI', 'MI_size_D_app_MIS', 'MI_duration_D_t07', 'MI_size_D_t14', 'source_Outsrced', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_size_D_t02', 'MI_size_D_t07', 'MI_size_D_t10', 'MI_size_D_t08', 'MI_size_D_t12', 'MI_size_D_app_ProdCont', 'dba_Sequential', 'telonuse_Yes', 'MI_size_D_t11', 'MI_size_D_t15', 'MI_size_D_t03', 'MI_size_D_duration_D']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output2\26-saida\encoded_maxwell.txt
