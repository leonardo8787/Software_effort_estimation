# %% [markdown]
# # Optuna

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna) (24.2)
# Collecting sqlalchemy>=1.4.2 (from optuna)
#   Downloading SQLAlchemy-2.0.36-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Collecting tqdm (from optuna)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ----------------------------------- ---- 51.2/57.7 kB 2.7 MB/s eta 0:00:01
#      ---------------------------------------- 57.7/57.7 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.4.2->optuna)
#   Downloading greenlet-3.1.1-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: colorama in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
#    ---------------------------------------- 0.0/364.4 kB ? eta -:--:--
#    --------------------------------------  358.4/364.4 kB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 364.4/364.4 kB 5.6 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ---------------------------------------- 0.0/233.5 kB ? eta -:--:--
#    --------------------------------------- 233.5/233.5 kB 14.0 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.36-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------------------------- ---------- 1.5/2.1 MB 32.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 26.7 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.5 kB ? eta -:--:--
#    ---------------------------------------- 78.5/78.5 kB 4.3 MB/s eta 0:00:00
# Downloading greenlet-3.1.1-cp311-cp311-win_amd64.whl (298 kB)
#    ---------------------------------------- 0.0/298.9 kB ? eta -:--:--
#    --------------------------------------- 298.9/298.9 kB 19.2 MB/s eta 0:00:00
# Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.6 kB ? eta -:--:--
#    ---------------------------------------- 78.6/78.6 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: tqdm, Mako, greenlet, colorlog, sqlalchemy, alembic, optuna
# Successfully installed Mako-1.3.8 alembic-1.14.0 colorlog-6.9.0 greenlet-3.1.1 optuna-4.1.0 sqlalchemy-2.0.36 tqdm-4.67.1
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\CALEO\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install optuna-dashboard
# Out:
# Collecting optuna-dashboard
#   Downloading optuna_dashboard-0.17.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting bottle>=0.13.0 (from optuna-dashboard)
#   Downloading bottle-0.13.2-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: optuna>=3.1.0 in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna-dashboard) (4.1.0)
# Requirement already satisfied: packaging in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna-dashboard) (24.2)
# Requirement already satisfied: scikit-learn in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna-dashboard) (1.6.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna>=3.1.0->optuna-dashboard) (1.14.0)
# Requirement already satisfied: colorlog in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna>=3.1.0->optuna-dashboard) (6.9.0)
# Requirement already satisfied: numpy in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna>=3.1.0->optuna-dashboard) (2.0.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna>=3.1.0->optuna-dashboard) (2.0.36)
# Requirement already satisfied: tqdm in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna>=3.1.0->optuna-dashboard) (4.67.1)
# Requirement already satisfied: PyYAML in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optuna>=3.1.0->optuna-dashboard) (6.0.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn->optuna-dashboard) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn->optuna-dashboard) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn->optuna-dashboard) (3.5.0)
# Requirement already satisfied: Mako in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from alembic>=1.5.0->optuna>=3.1.0->optuna-dashboard) (1.3.8)
# Requirement already satisfied: typing-extensions>=4 in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from alembic>=1.5.0->optuna>=3.1.0->optuna-dashboard) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy>=1.4.2->optuna>=3.1.0->optuna-dashboard) (3.1.1)
# Requirement already satisfied: colorama in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from colorlog->optuna>=3.1.0->optuna-dashboard) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\caleo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from Mako->alembic>=1.5.0->optuna>=3.1.0->optuna-dashboard) (3.0.2)
# Downloading optuna_dashboard-0.17.0-py3-none-any.whl (8.4 MB)
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB 445.2 kB/s eta 0:00:19
#    ---------------------------------------- 0.1/8.4 MB 845.5 kB/s eta 0:00:10
#    - -------------------------------------- 0.2/8.4 MB 1.5 MB/s eta 0:00:06
#    -- ------------------------------------- 0.5/8.4 MB 2.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.1/8.4 MB 4.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.4 MB 8.4 MB/s eta 0:00:01
#    -------------- ------------------------- 3.1/8.4 MB 10.6 MB/s eta 0:00:01
#    -------------- ------------------------- 3.1/8.4 MB 10.6 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.4 MB 10.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.1/8.4 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.3/8.4 MB 15.6 MB/s eta 0:00:01
#    ------------------------------------- -- 7.8/8.4 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  8.4/8.4 MB 15.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.4/8.4 MB 14.9 MB/s eta 0:00:00
# Downloading bottle-0.13.2-py2.py3-none-any.whl (104 kB)
#    ---------------------------------------- 0.0/104.1 kB ? eta -:--:--
#    ---------------------------------------- 104.1/104.1 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: bottle, optuna-dashboard
# Successfully installed bottle-0.13.2 optuna-dashboard-0.17.0
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\CALEO\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os
import numpy as np
import pandas as pd

def load_txt_files_from_folders(root_directory):
    """
    Percorre todas as pastas dentro do diretório raiz e carrega arquivos .txt de cada pasta.

    Args:
        root_directory (str): Caminho para o diretório raiz.

    Returns:
        dict: Um dicionário com as informações carregadas.
              Chave = 'nome_da_pasta/nome_do_arquivo'
              Valor = (cabeçalho, np.array com os dados)
    """
    relevant_features_data = {}

    # Percorre todas as subpastas dentro do diretório raiz
    for folder_name in os.listdir(root_directory):
        folder_path = os.path.join(root_directory, folder_name)

        # Verifica se é uma pasta
        if os.path.isdir(folder_path):
            for filename in os.listdir(folder_path):
                if filename.endswith('.txt'):
                    file_path = os.path.join(folder_path, filename)
                    try:
                        # Lendo os dados do arquivo
                        with open(file_path, 'r') as file:
                            lines = file.readlines()
                            header = lines[0].strip()  # Mantém o cabeçalho
                            data = [line.strip().split(',') for line in lines[1:] if line.strip()]  # Supondo CSV-like

                            # Adiciona ao dicionário com chave como 'pasta/arquivo'
                            key = f"{folder_name}/{filename}"
                            relevant_features_data[key] = (header, np.array(data, dtype=float))

                    except Exception as e:
                        print(f"Erro ao processar o arquivo {file_path}: {e}")
    
    return relevant_features_data


# Exemplo de uso:
root_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\algorithms\abordagens\output3"
datasets = load_txt_files_from_folders(root_directory)

# Exibindo o resumo dos arquivos carregados
for key, (header, data) in datasets.items():
    print(f"Arquivo processado: {key}")
    print(f"Header: {header}")
    print(f"Shape dos dados: {data.shape}")
    print("-" * 50)
# Out:
# Arquivo processado: 1-saida/cocomo81.txt
# Header: rely,data,modp,loc,actual
# Shape dos dados: (63, 5)
# --------------------------------------------------
# Arquivo processado: 1-saida/encoded_china.txt
# Header: AFP,Input,File,Added,N_effort,Effort
# Shape dos dados: (499, 6)
# --------------------------------------------------
# Arquivo processado: 1-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,Language_3,Effort
# Shape dos dados: (81, 6)
# --------------------------------------------------
# Arquivo processado: 1-saida/encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t07,t10,t11,t14,t15,app_InfServ,effort_D
# Shape dos dados: (63, 10)
# --------------------------------------------------
# Arquivo processado: 10-saida/cocomo81.txt
# Header: loc,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,actual
# Shape dos dados: (63, 6)
# --------------------------------------------------
# Arquivo processado: 10-saida/encoded_china.txt
# Header: N_effort,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Effort
# Shape dos dados: (499, 7)
# --------------------------------------------------
# Arquivo processado: 10-saida/encoded_desharnais.txt
# Header: PointsAdjust,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Effort
# Shape dos dados: (81, 7)
# --------------------------------------------------
# Arquivo processado: 10-saida/encoded_maxwell.txt
# Header: size_D,duration_D,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,effort_D
# Shape dos dados: (63, 12)
# --------------------------------------------------
# Arquivo processado: 11-saida/cocomo81.txt
# Header: Generated_Var_1,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_8,actual
# Shape dos dados: (63, 7)
# --------------------------------------------------
# Arquivo processado: 11-saida/encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Added,Duration,N_effort,Effort
# Shape dos dados: (499, 9)
# --------------------------------------------------
# Arquivo processado: 11-saida/encoded_desharnais.txt
# Header: Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_7,Generated_Var_9,Generated_Var_10,Generated_Var_11,Effort
# Shape dos dados: (81, 9)
# --------------------------------------------------
# Arquivo processado: 11-saida/encoded_maxwell.txt
# Header: Generated_Var_1,Generated_Var_3,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_10,Generated_Var_12,Generated_Var_13,Generated_Var_14,Generated_Var_16,Generated_Var_18,Generated_Var_19,effort_D
# Shape dos dados: (63, 15)
# --------------------------------------------------
# Arquivo processado: 12-saida/cocomo81.txt
# Header: Generated_Var_1,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_9,Generated_Var_10,Generated_Var_12,actual
# Shape dos dados: (63, 8)
# --------------------------------------------------
# Arquivo processado: 12-saida/encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,Duration,N_effort,Effort
# Shape dos dados: (499, 10)
# --------------------------------------------------
# Arquivo processado: 12-saida/encoded_desharnais.txt
# Header: Generated_Var_1,Generated_Var_3,Generated_Var_5,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_13,Generated_Var_14,Generated_Var_15,Effort
# Shape dos dados: (81, 10)
# --------------------------------------------------
# Arquivo processado: 12-saida/encoded_maxwell.txt
# Header: Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_9,Generated_Var_10,Generated_Var_11,Generated_Var_12,Generated_Var_13,Generated_Var_14,Generated_Var_15,Generated_Var_16,Generated_Var_17,Generated_Var_19,Generated_Var_22,Generated_Var_23,Generated_Var_24,effort_D
# Shape dos dados: (63, 17)
# --------------------------------------------------
# Arquivo processado: 13-saida/cocomo81.txt
# Header: data,loc,MI_loc_aexp,MI_loc_data,MI_loc_stor,actual
# Shape dos dados: (63, 6)
# --------------------------------------------------
# Arquivo processado: 13-saida/encoded_china.txt
# Header: AFP,Added,N_effort,MI_N_effort_PDR_AFP,MI_N_effort_NPDU_UFP,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 7)
# --------------------------------------------------
# Arquivo processado: 13-saida/encoded_desharnais.txt
# Header: Transactions,PointsAdjust,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 7)
# --------------------------------------------------
# Arquivo processado: 13-saida/encoded_maxwell.txt
# Header: size_D,duration_D,t07,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_t02,MI_size_D_t08,MI_duration_D_t07,effort_D
# Shape dos dados: (63, 12)
# --------------------------------------------------
# Arquivo processado: 14-saida/cocomo81.txt
# Header: MI_loc_aexp,MI_loc_data,MI_loc_stor,MI_loc_time,MI_loc_cplx,MI_loc_turn,actual
# Shape dos dados: (63, 7)
# --------------------------------------------------
# Arquivo processado: 14-saida/encoded_china.txt
# Header: Added,N_effort,MI_N_effort_PDR_AFP,MI_N_effort_PDR_UFP,MI_N_effort_Enquiry,MI_N_effort_Duration,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 8)
# --------------------------------------------------
# Arquivo processado: 14-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_PointsAdjust_Language_1,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 9)
# --------------------------------------------------
# Arquivo processado: 14-saida/encoded_maxwell.txt
# Header: size_D,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_t02,MI_size_D_t08,MI_size_D_har_Mainfrm,MI_size_D_t03,MI_size_D_t10,MI_size_D_t15,MI_size_D_t12,effort_D
# Shape dos dados: (63, 14)
# --------------------------------------------------
# Arquivo processado: 15-saida/cocomo81.txt
# Header: rely,data,time,turn,acap,pcap,modp,loc,actual
# Shape dos dados: (63, 9)
# --------------------------------------------------
# Arquivo processado: 15-saida/encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,PDR_UFP,Duration,N_effort,Effort
# Shape dos dados: (499, 11)
# --------------------------------------------------
# Arquivo processado: 15-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_4,TeamExp_?,ManagerExp_2,Language_1,Language_3,Effort
# Shape dos dados: (81, 12)
# --------------------------------------------------
# Arquivo processado: 15-saida/encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_InfServ,app_TransPro,har_Network,har_PC,effort_D
# Shape dos dados: (63, 19)
# --------------------------------------------------
# Arquivo processado: 16-saida/2-saida_cocomo81.txt
# Header: rely,data,time,turn,acap,pcap,modp,loc,actual
# Shape dos dados: (63, 9)
# --------------------------------------------------
# Arquivo processado: 16-saida/2-saida_encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,PDR_UFP,Duration,N_effort,Effort
# Shape dos dados: (499, 11)
# --------------------------------------------------
# Arquivo processado: 16-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_4,TeamExp_?,ManagerExp_2,Language_1,Language_3,Effort
# Shape dos dados: (81, 12)
# --------------------------------------------------
# Arquivo processado: 16-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_InfServ,app_TransPro,har_Network,har_PC,effort_D
# Shape dos dados: (63, 19)
# --------------------------------------------------
# Arquivo processado: 17-saida/cocomo81.txt
# Header: data,modp,loc,MI_loc_aexp,MI_loc_data,MI_loc_stor,MI_loc_time,MI_loc_cplx,MI_loc_turn,MI_loc_pcap,MI_loc_rely,MI_loc_virt,MI_loc_acap,MI_loc_vexp,actual
# Shape dos dados: (63, 15)
# --------------------------------------------------
# Arquivo processado: 17-saida/encoded_china.txt
# Header: AFP,Input,Output,File,Added,N_effort,MI_N_effort_AFP,MI_N_effort_PDR_AFP,MI_N_effort_NPDU_UFP,MI_N_effort_Added,MI_N_effort_PDR_UFP,MI_N_effort_Enquiry,MI_N_effort_NPDR_AFP,MI_N_effort_Duration,MI_N_effort_File,MI_N_effort_Output,MI_N_effort_Resource_1,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 19)
# --------------------------------------------------
# Arquivo processado: 17-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_1,TeamExp_?,ManagerExp_2,Language_3,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_PointsAdjust_Language_2,MI_PointsAdjust_Language_1,MI_PointsAdjust_ManagerExp_4,MI_PointsAdjust_ManagerExp_2,MI_PointsAdjust_ManagerExp_3,MI_PointsAdjust_TeamExp_?,MI_PointsAdjust_YearEnd,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 20)
# --------------------------------------------------
# Arquivo processado: 17-saida/encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t07,t10,t11,t14,t15,app_InfServ,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_t02,MI_size_D_t08,MI_size_D_har_Mainfrm,MI_size_D_t03,MI_size_D_t14,MI_size_D_t10,MI_size_D_t15,MI_size_D_t12,MI_size_D_telonuse_Yes,MI_size_D_ifc_TextUI,MI_size_D_t05,MI_size_D_har_Multi,MI_size_D_t01,MI_size_D_t04,MI_size_D_t06,MI_size_D_t13,MI_size_D_app_CustServ,MI_duration_D_t07,effort_D
# Shape dos dados: (63, 33)
# --------------------------------------------------
# Arquivo processado: 18-saida/2-saida_cocomo81.txt
# Header: rely,data,turn,pcap,modp,loc,MI_loc_aexp,MI_loc_data,MI_loc_stor,MI_aexp_data,actual
# Shape dos dados: (63, 11)
# --------------------------------------------------
# Arquivo processado: 18-saida/2-saida_encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Added,Duration,N_effort,MI_N_effort_AFP,MI_N_effort_PDR_AFP,MI_N_effort_NPDU_UFP,MI_N_effort_Added,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 14)
# --------------------------------------------------
# Arquivo processado: 18-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_1,TeamExp_?,ManagerExp_2,Language_1,Language_3,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 14)
# --------------------------------------------------
# Arquivo processado: 18-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t07,t08,t09,t10,t11,t13,t14,t15,app_InfServ,app_TransPro,har_Network,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_t02,MI_size_D_t08,MI_duration_D_t07,effort_D
# Shape dos dados: (63, 24)
# --------------------------------------------------
# Arquivo processado: 19-saida/2-saida_cocomo81.txt
# Header: rely,data,modp,loc,MI_loc_aexp,MI_loc_data,MI_loc_stor,MI_loc_time,MI_loc_cplx,MI_loc_turn,MI_loc_pcap,MI_aexp_data,actual
# Shape dos dados: (63, 13)
# --------------------------------------------------
# Arquivo processado: 19-saida/2-saida_encoded_china.txt
# Header: AFP,Input,Output,File,Added,N_effort,MI_N_effort_AFP,MI_N_effort_PDR_AFP,MI_N_effort_NPDU_UFP,MI_N_effort_Added,MI_N_effort_PDR_UFP,MI_N_effort_Enquiry,MI_N_effort_NPDR_AFP,MI_N_effort_Duration,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 16)
# --------------------------------------------------
# Arquivo processado: 19-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_1,TeamExp_?,ManagerExp_2,Language_3,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_PointsAdjust_Language_2,MI_PointsAdjust_Language_1,MI_PointsAdjust_ManagerExp_4,MI_PointsAdjust_ManagerExp_3,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 17)
# --------------------------------------------------
# Arquivo processado: 19-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t07,t08,t09,t10,t11,t14,t15,app_InfServ,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_t02,MI_size_D_t08,MI_size_D_har_Mainfrm,MI_size_D_t03,MI_size_D_t14,MI_size_D_t10,MI_size_D_t15,MI_size_D_t12,MI_size_D_telonuse_Yes,MI_duration_D_t07,effort_D
# Shape dos dados: (63, 28)
# --------------------------------------------------
# Arquivo processado: 2-saida/2-saida_cocomo81.txt
# Header: rely,data,modp,loc,actual
# Shape dos dados: (63, 5)
# --------------------------------------------------
# Arquivo processado: 2-saida/2-saida_encoded_china.txt
# Header: AFP,Input,File,Added,N_effort,Effort
# Shape dos dados: (499, 6)
# --------------------------------------------------
# Arquivo processado: 2-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,Language_3,Effort
# Shape dos dados: (81, 6)
# --------------------------------------------------
# Arquivo processado: 2-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t07,t10,t11,t14,t15,app_InfServ,effort_D
# Shape dos dados: (63, 10)
# --------------------------------------------------
# Arquivo processado: 20-saida/2-saida_cocomo81.txt
# Header: data,modp,loc,MI_loc_aexp,MI_loc_data,MI_loc_stor,MI_loc_time,MI_loc_cplx,MI_loc_turn,MI_loc_pcap,MI_loc_rely,MI_loc_virt,MI_loc_vexp,MI_aexp_data,actual
# Shape dos dados: (63, 15)
# --------------------------------------------------
# Arquivo processado: 20-saida/2-saida_encoded_china.txt
# Header: AFP,Input,Output,File,Added,N_effort,MI_N_effort_AFP,MI_N_effort_PDR_AFP,MI_N_effort_NPDU_UFP,MI_N_effort_Added,MI_N_effort_PDR_UFP,MI_N_effort_Enquiry,MI_N_effort_NPDR_AFP,MI_N_effort_Duration,MI_N_effort_File,MI_N_effort_Output,MI_N_effort_Resource_1,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 19)
# --------------------------------------------------
# Arquivo processado: 20-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_1,TeamExp_?,ManagerExp_2,Language_3,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_PointsAdjust_Language_2,MI_PointsAdjust_Language_1,MI_PointsAdjust_ManagerExp_4,MI_PointsAdjust_ManagerExp_2,MI_PointsAdjust_ManagerExp_3,MI_PointsAdjust_TeamExp_?,MI_PointsAdjust_YearEnd,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 20)
# --------------------------------------------------
# Arquivo processado: 20-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t07,t10,t11,t14,t15,app_InfServ,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_t02,MI_size_D_t08,MI_size_D_har_Mainfrm,MI_size_D_t03,MI_size_D_t14,MI_size_D_t10,MI_size_D_t15,MI_size_D_t12,MI_size_D_telonuse_Yes,MI_size_D_ifc_TextUI,MI_size_D_t05,MI_size_D_har_Multi,MI_size_D_t01,MI_size_D_t04,MI_size_D_t06,MI_size_D_t13,MI_size_D_app_CustServ,MI_duration_D_t07,effort_D
# Shape dos dados: (63, 33)
# --------------------------------------------------
# Arquivo processado: 21-saida/2-saida_cocomo81.txt
# Header: rely,data,turn,pcap,modp,loc,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,actual
# Shape dos dados: (63, 11)
# --------------------------------------------------
# Arquivo processado: 21-saida/2-saida_encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,PDR_AFP,PDR_UFP,NPDU_UFP,Duration,N_effort,Resource_4,Effort
# Shape dos dados: (499, 14)
# --------------------------------------------------
# Arquivo processado: 21-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_1,TeamExp_4,TeamExp_?,ManagerExp_2,Language_1,Language_3,Generated_Var_1,Generated_Var_4,Generated_Var_5,Effort
# Shape dos dados: (81, 14)
# --------------------------------------------------
# Arquivo processado: 21-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t07,t08,t09,t10,t11,t13,t14,t15,app_InfServ,app_TransPro,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,effort_D
# Shape dos dados: (63, 24)
# --------------------------------------------------
# Arquivo processado: 22-saida/2-saida_cocomo81.txt
# Header: rely,data,turn,pcap,modp,loc,Generated_Var_1,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,actual
# Shape dos dados: (63, 13)
# --------------------------------------------------
# Arquivo processado: 22-saida/2-saida_encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,PDR_AFP,PDR_UFP,NPDU_UFP,Duration,N_effort,Resource_4,Generated_Var_2,Generated_Var_4,Generated_Var_10,Effort
# Shape dos dados: (499, 17)
# --------------------------------------------------
# Arquivo processado: 22-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_2,TeamExp_4,TeamExp_?,ManagerExp_2,ManagerExp_3,ManagerExp_4,ManagerExp_5,Language_1,Language_3,Generated_Var_7,Effort
# Shape dos dados: (81, 17)
# --------------------------------------------------
# Arquivo processado: 22-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t07,t08,t09,t10,t11,t14,t15,app_InfServ,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_9,Generated_Var_10,Generated_Var_11,Generated_Var_12,Generated_Var_13,Generated_Var_14,Generated_Var_15,Generated_Var_16,Generated_Var_18,Generated_Var_19,effort_D
# Shape dos dados: (63, 29)
# --------------------------------------------------
# Arquivo processado: 23-saida/2-saida_cocomo81.txt
# Header: data,modp,loc,Generated_Var_1,Generated_Var_2,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_10,Generated_Var_11,Generated_Var_12,actual
# Shape dos dados: (63, 15)
# --------------------------------------------------
# Arquivo processado: 23-saida/2-saida_encoded_china.txt
# Header: ID,AFP,Input,Output,Enquiry,File,Interface,Added,Changed,PDR_AFP,PDR_UFP,NPDR_AFP,NPDU_UFP,Duration,N_effort,Resource_1,Resource_3,Resource_4,Effort
# Shape dos dados: (499, 19)
# --------------------------------------------------
# Arquivo processado: 23-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,Language_3,Generated_Var_1,Generated_Var_2,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_10,Generated_Var_11,Generated_Var_12,Generated_Var_14,Generated_Var_15,Generated_Var_16,Generated_Var_17,Effort
# Shape dos dados: (81, 20)
# --------------------------------------------------
# Arquivo processado: 23-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,t07,t11,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_10,Generated_Var_11,Generated_Var_12,Generated_Var_13,Generated_Var_14,Generated_Var_15,Generated_Var_16,Generated_Var_17,Generated_Var_18,Generated_Var_19,Generated_Var_20,Generated_Var_21,Generated_Var_22,Generated_Var_23,Generated_Var_24,Generated_Var_25,Generated_Var_26,Generated_Var_27,Generated_Var_28,effort_D
# Shape dos dados: (63, 33)
# --------------------------------------------------
# Arquivo processado: 24-saida/cocomo81.txt
# Header: rely,data,turn,pcap,modp,loc,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,actual
# Shape dos dados: (63, 11)
# --------------------------------------------------
# Arquivo processado: 24-saida/encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Added,Duration,N_effort,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Effort
# Shape dos dados: (499, 14)
# --------------------------------------------------
# Arquivo processado: 24-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_1,TeamExp_?,ManagerExp_2,Language_3,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Effort
# Shape dos dados: (81, 14)
# --------------------------------------------------
# Arquivo processado: 24-saida/encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t07,t08,t09,t10,t11,t13,t14,t15,app_InfServ,app_TransPro,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,effort_D
# Shape dos dados: (63, 24)
# --------------------------------------------------
# Arquivo processado: 25-saida/cocomo81.txt
# Header: rely,data,modp,loc,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,actual
# Shape dos dados: (63, 13)
# --------------------------------------------------
# Arquivo processado: 25-saida/encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,PDR_AFP,PDR_UFP,NPDR_AFP,NPDU_UFP,Duration,N_effort,Resource_4,Generated_Var_2,Generated_Var_11,Effort
# Shape dos dados: (499, 17)
# --------------------------------------------------
# Arquivo processado: 25-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,Language_3,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_10,Generated_Var_11,Effort
# Shape dos dados: (81, 17)
# --------------------------------------------------
# Arquivo processado: 25-saida/encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t07,t10,t11,t14,t15,app_InfServ,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_10,Generated_Var_11,Generated_Var_12,Generated_Var_13,Generated_Var_14,Generated_Var_15,Generated_Var_16,Generated_Var_17,Generated_Var_18,Generated_Var_19,effort_D
# Shape dos dados: (63, 29)
# --------------------------------------------------
# Arquivo processado: 26-saida/cocomo81.txt
# Header: data,loc,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_10,Generated_Var_11,Generated_Var_12,actual
# Shape dos dados: (63, 15)
# --------------------------------------------------
# Arquivo processado: 26-saida/encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,PDR_AFP,PDR_UFP,NPDR_AFP,NPDU_UFP,Duration,N_effort,Resource_4,Generated_Var_1,Generated_Var_7,Generated_Var_9,Generated_Var_16,Effort
# Shape dos dados: (499, 19)
# --------------------------------------------------
# Arquivo processado: 26-saida/encoded_desharnais.txt
# Header: Transactions,PointsAdjust,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_10,Generated_Var_11,Generated_Var_12,Generated_Var_13,Generated_Var_14,Generated_Var_15,Generated_Var_16,Generated_Var_17,Effort
# Shape dos dados: (81, 20)
# --------------------------------------------------
# Arquivo processado: 26-saida/encoded_maxwell.txt
# Header: size_D,duration_D,t07,t11,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_10,Generated_Var_11,Generated_Var_12,Generated_Var_13,Generated_Var_14,Generated_Var_15,Generated_Var_16,Generated_Var_17,Generated_Var_18,Generated_Var_19,Generated_Var_20,Generated_Var_21,Generated_Var_22,Generated_Var_23,Generated_Var_24,Generated_Var_25,Generated_Var_26,Generated_Var_27,Generated_Var_28,effort_D
# Shape dos dados: (63, 33)
# --------------------------------------------------
# Arquivo processado: 27-saida/cocomo81.txt
# Header: rely,data,turn,pcap,modp,loc,MI_loc_aexp,MI_loc_data,MI_loc_stor,MI_aexp_data,actual
# Shape dos dados: (63, 11)
# --------------------------------------------------
# Arquivo processado: 27-saida/encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Added,Duration,N_effort,MI_N_effort_AFP,MI_N_effort_PDR_AFP,MI_N_effort_NPDU_UFP,MI_N_effort_Added,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 14)
# --------------------------------------------------
# Arquivo processado: 27-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_1,TeamExp_?,ManagerExp_2,Language_3,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_PointsAdjust_Language_3,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 14)
# --------------------------------------------------
# Arquivo processado: 27-saida/encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t07,t08,t09,t10,t11,t13,t14,t15,app_InfServ,app_TransPro,har_Network,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_t02,MI_size_D_t08,MI_duration_D_t07,effort_D
# Shape dos dados: (63, 24)
# --------------------------------------------------
# Arquivo processado: 28-saida/cocomo81.txt
# Header: rely,data,turn,modp,loc,MI_loc_aexp,MI_loc_data,MI_loc_stor,MI_loc_time,MI_loc_cplx,MI_loc_turn,MI_loc_pcap,actual
# Shape dos dados: (63, 13)
# --------------------------------------------------
# Arquivo processado: 28-saida/encoded_china.txt
# Header: AFP,Input,Output,File,Added,N_effort,MI_N_effort_AFP,MI_N_effort_PDR_AFP,MI_N_effort_NPDU_UFP,MI_N_effort_Added,MI_N_effort_PDR_UFP,MI_N_effort_Enquiry,MI_N_effort_NPDR_AFP,MI_N_effort_Duration,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 16)
# --------------------------------------------------
# Arquivo processado: 28-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_1,TeamExp_?,ManagerExp_2,Language_3,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_PointsAdjust_Language_2,MI_PointsAdjust_Language_1,MI_PointsAdjust_ManagerExp_4,MI_PointsAdjust_ManagerExp_3,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 17)
# --------------------------------------------------
# Arquivo processado: 28-saida/encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t07,t08,t09,t10,t11,t14,t15,app_InfServ,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_t02,MI_size_D_t08,MI_size_D_har_Mainfrm,MI_size_D_t03,MI_size_D_t14,MI_size_D_t10,MI_size_D_t15,MI_size_D_t12,MI_size_D_telonuse_Yes,MI_duration_D_t07,effort_D
# Shape dos dados: (63, 28)
# --------------------------------------------------
# Arquivo processado: 29-saida/cocomo81.txt
# Header: rely,data,time,stor,turn,acap,aexp,pcap,vexp,lexp,modp,loc,actual
# Shape dos dados: (63, 13)
# --------------------------------------------------
# Arquivo processado: 29-saida/encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,PDR_AFP,PDR_UFP,NPDR_AFP,NPDU_UFP,Duration,N_effort,Resource_1,Resource_4,Effort
# Shape dos dados: (499, 16)
# --------------------------------------------------
# Arquivo processado: 29-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_2,TeamExp_4,TeamExp_?,ManagerExp_0,ManagerExp_2,ManagerExp_3,ManagerExp_4,ManagerExp_5,Language_1,Language_3,Effort
# Shape dos dados: (81, 17)
# --------------------------------------------------
# Arquivo processado: 29-saida/encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t02,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_CustServ,app_InfServ,app_ProdCont,app_TransPro,har_Multi,har_Network,har_PC,dba_Other,ifc_GUI,ifc_TextUI,telonuse_No,telonuse_Yes,effort_D
# Shape dos dados: (63, 28)
# --------------------------------------------------
# Arquivo processado: 3-saida/cocomo81.txt
# Header: MI_loc_data,MI_loc_stor,MI_loc_time,MI_loc_cplx,MI_loc_turn,MI_loc_rely,MI_loc_virt,actual
# Shape dos dados: (63, 8)
# --------------------------------------------------
# Arquivo processado: 3-saida/encoded_china.txt
# Header: AFP,Added,N_effort,MI_N_effort_PDR_AFP,MI_N_effort_PDR_UFP,MI_N_effort_Enquiry,MI_N_effort_Duration,MI_N_effort_Output,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 10)
# --------------------------------------------------
# Arquivo processado: 3-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_PointsAdjust_Language_1,MI_PointsAdjust_YearEnd,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 10)
# --------------------------------------------------
# Arquivo processado: 3-saida/encoded_maxwell.txt
# Header: size_D,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_t08,MI_size_D_t03,MI_size_D_t10,MI_size_D_t15,MI_size_D_t12,MI_size_D_ifc_TextUI,MI_size_D_t01,MI_size_D_t04,MI_size_D_t06,MI_size_D_t13,effort_D
# Shape dos dados: (63, 17)
# --------------------------------------------------
# Arquivo processado: 30-saida/2-saida_cocomo81.txt
# Header: rely,data,time,stor,turn,acap,aexp,pcap,vexp,lexp,modp,loc,actual
# Shape dos dados: (63, 13)
# --------------------------------------------------
# Arquivo processado: 30-saida/2-saida_encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,PDR_AFP,PDR_UFP,NPDR_AFP,NPDU_UFP,Duration,N_effort,Resource_1,Resource_4,Effort
# Shape dos dados: (499, 16)
# --------------------------------------------------
# Arquivo processado: 30-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_2,TeamExp_4,TeamExp_?,ManagerExp_0,ManagerExp_2,ManagerExp_3,ManagerExp_4,ManagerExp_5,Language_1,Language_3,Effort
# Shape dos dados: (81, 17)
# --------------------------------------------------
# Arquivo processado: 30-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t02,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_CustServ,app_InfServ,app_ProdCont,app_TransPro,har_Multi,har_Network,har_PC,dba_Other,ifc_GUI,ifc_TextUI,telonuse_No,telonuse_Yes,effort_D
# Shape dos dados: (63, 28)
# --------------------------------------------------
# Arquivo processado: 31-saida/cocomo81.txt
# Header: rely,data,time,stor,turn,acap,pcap,modp,loc,MI_loc_aexp,MI_loc_data,MI_loc_stor,MI_loc_time,MI_loc_cplx,MI_loc_turn,MI_loc_pcap,MI_loc_rely,MI_loc_virt,MI_loc_acap,MI_loc_vexp,MI_aexp_data,actual
# Shape dos dados: (63, 22)
# --------------------------------------------------
# Arquivo processado: 31-saida/encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,PDR_AFP,PDR_UFP,NPDU_UFP,Duration,N_effort,Resource_4,MI_N_effort_AFP,MI_N_effort_PDR_AFP,MI_N_effort_NPDU_UFP,MI_N_effort_Added,MI_N_effort_PDR_UFP,MI_N_effort_Enquiry,MI_N_effort_NPDR_AFP,MI_N_effort_Input,MI_N_effort_Duration,MI_N_effort_File,MI_N_effort_Output,MI_N_effort_Resource_1,MI_N_effort_Resource_2,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 28)
# --------------------------------------------------
# Arquivo processado: 31-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_2,TeamExp_4,TeamExp_?,ManagerExp_2,ManagerExp_3,ManagerExp_4,Language_1,Language_3,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_PointsAdjust_Language_3,MI_PointsAdjust_Language_2,MI_PointsAdjust_Language_1,MI_PointsAdjust_ManagerExp_4,MI_PointsAdjust_ManagerExp_2,MI_PointsAdjust_ManagerExp_3,MI_PointsAdjust_TeamExp_?,MI_PointsAdjust_TeamExp_0,MI_PointsAdjust_ManagerExp_5,MI_PointsAdjust_YearEnd,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 29)
# --------------------------------------------------
# Arquivo processado: 31-saida/encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t02,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_CustServ,app_InfServ,app_TransPro,har_Multi,har_Network,har_PC,dba_Other,ifc_GUI,ifc_TextUI,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_app_InfServ,MI_size_D_t02,MI_size_D_t08,MI_size_D_har_Mainfrm,MI_size_D_t03,MI_size_D_t14,MI_size_D_t10,MI_size_D_t15,MI_size_D_t12,MI_size_D_telonuse_Yes,MI_size_D_ifc_TextUI,MI_size_D_t05,MI_size_D_har_Multi,MI_size_D_t01,MI_size_D_t04,MI_size_D_t06,MI_size_D_t13,MI_size_D_app_CustServ,MI_duration_D_t07,effort_D
# Shape dos dados: (63, 49)
# --------------------------------------------------
# Arquivo processado: 32-saida/2-saida_cocomo81.txt
# Header: rely,data,time,stor,turn,acap,pcap,vexp,lexp,modp,loc,MI_loc_aexp,MI_loc_data,MI_loc_stor,MI_aexp_data,actual
# Shape dos dados: (63, 16)
# --------------------------------------------------
# Arquivo processado: 32-saida/2-saida_encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,PDR_AFP,PDR_UFP,NPDR_AFP,NPDU_UFP,Duration,N_effort,Resource_4,MI_N_effort_AFP,MI_N_effort_PDR_AFP,MI_N_effort_NPDU_UFP,MI_N_effort_Added,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 20)
# --------------------------------------------------
# Arquivo processado: 32-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_2,TeamExp_4,TeamExp_?,ManagerExp_2,ManagerExp_3,ManagerExp_4,ManagerExp_5,Language_1,Language_3,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_PointsAdjust_Language_3,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 21)
# --------------------------------------------------
# Arquivo processado: 32-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t02,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_CustServ,app_InfServ,app_ProdCont,app_TransPro,har_Multi,har_Network,har_PC,dba_Other,ifc_GUI,ifc_TextUI,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_app_InfServ,MI_size_D_t02,MI_size_D_t08,MI_duration_D_t07,effort_D
# Shape dos dados: (63, 35)
# --------------------------------------------------
# Arquivo processado: 33-saida/2-saida_cocomo81.txt
# Header: rely,data,time,stor,turn,acap,pcap,lexp,modp,loc,MI_loc_aexp,MI_loc_data,MI_loc_stor,MI_loc_time,MI_loc_cplx,MI_loc_turn,MI_loc_pcap,MI_aexp_data,actual
# Shape dos dados: (63, 19)
# --------------------------------------------------
# Arquivo processado: 33-saida/2-saida_encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,PDR_AFP,PDR_UFP,NPDU_UFP,Duration,N_effort,Resource_4,MI_N_effort_AFP,MI_N_effort_PDR_AFP,MI_N_effort_NPDU_UFP,MI_N_effort_Added,MI_N_effort_PDR_UFP,MI_N_effort_Enquiry,MI_N_effort_NPDR_AFP,MI_N_effort_Input,MI_N_effort_Duration,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 24)
# --------------------------------------------------
# Arquivo processado: 33-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_2,TeamExp_4,TeamExp_?,ManagerExp_2,ManagerExp_3,ManagerExp_4,Language_1,Language_3,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_PointsAdjust_Language_3,MI_PointsAdjust_Language_2,MI_PointsAdjust_Language_1,MI_PointsAdjust_ManagerExp_4,MI_PointsAdjust_ManagerExp_2,MI_PointsAdjust_ManagerExp_3,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 25)
# --------------------------------------------------
# Arquivo processado: 33-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t02,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_CustServ,app_InfServ,app_TransPro,har_Multi,har_Network,har_PC,dba_Other,ifc_GUI,ifc_TextUI,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_app_InfServ,MI_size_D_t02,MI_size_D_t08,MI_size_D_har_Mainfrm,MI_size_D_t03,MI_size_D_t14,MI_size_D_t10,MI_size_D_t15,MI_size_D_t12,MI_size_D_app_ProdCont,MI_size_D_telonuse_Yes,MI_duration_D_t07,effort_D
# Shape dos dados: (63, 42)
# --------------------------------------------------
# Arquivo processado: 34-saida/2-saida_cocomo81.txt
# Header: rely,data,time,stor,turn,acap,pcap,modp,loc,MI_loc_aexp,MI_loc_data,MI_loc_stor,MI_loc_time,MI_loc_cplx,MI_loc_turn,MI_loc_pcap,MI_loc_rely,MI_loc_virt,MI_loc_acap,MI_loc_vexp,MI_aexp_data,actual
# Shape dos dados: (63, 22)
# --------------------------------------------------
# Arquivo processado: 34-saida/2-saida_encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,PDR_AFP,PDR_UFP,NPDU_UFP,Duration,N_effort,Resource_4,MI_N_effort_AFP,MI_N_effort_PDR_AFP,MI_N_effort_NPDU_UFP,MI_N_effort_Added,MI_N_effort_PDR_UFP,MI_N_effort_Enquiry,MI_N_effort_NPDR_AFP,MI_N_effort_Input,MI_N_effort_Duration,MI_N_effort_File,MI_N_effort_Output,MI_N_effort_Resource_1,MI_N_effort_Resource_2,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 28)
# --------------------------------------------------
# Arquivo processado: 34-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_2,TeamExp_4,TeamExp_?,ManagerExp_2,ManagerExp_3,ManagerExp_4,Language_1,Language_3,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_PointsAdjust_Language_3,MI_PointsAdjust_Language_2,MI_PointsAdjust_Language_1,MI_PointsAdjust_ManagerExp_4,MI_PointsAdjust_ManagerExp_2,MI_PointsAdjust_ManagerExp_3,MI_PointsAdjust_TeamExp_?,MI_PointsAdjust_TeamExp_0,MI_PointsAdjust_ManagerExp_5,MI_PointsAdjust_YearEnd,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 29)
# --------------------------------------------------
# Arquivo processado: 34-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t02,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_CustServ,app_InfServ,app_TransPro,har_Multi,har_Network,har_PC,dba_Other,ifc_GUI,ifc_TextUI,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_app_InfServ,MI_size_D_t02,MI_size_D_t08,MI_size_D_har_Mainfrm,MI_size_D_t03,MI_size_D_t14,MI_size_D_t10,MI_size_D_t15,MI_size_D_t12,MI_size_D_telonuse_Yes,MI_size_D_ifc_TextUI,MI_size_D_t05,MI_size_D_har_Multi,MI_size_D_t01,MI_size_D_t04,MI_size_D_t06,MI_size_D_t13,MI_size_D_app_CustServ,MI_duration_D_t07,effort_D
# Shape dos dados: (63, 49)
# --------------------------------------------------
# Arquivo processado: 35-saida/2-saida_cocomo81.txt
# Header: rely,data,time,stor,turn,acap,pcap,vexp,lexp,modp,loc,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,actual
# Shape dos dados: (63, 16)
# --------------------------------------------------
# Arquivo processado: 35-saida/2-saida_encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,Changed,PDR_AFP,PDR_UFP,NPDR_AFP,NPDU_UFP,Duration,N_effort,Resource_1,Resource_3,Resource_4,Generated_Var_3,Generated_Var_5,Effort
# Shape dos dados: (499, 20)
# --------------------------------------------------
# Arquivo processado: 35-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_2,TeamExp_4,TeamExp_?,ManagerExp_2,ManagerExp_3,ManagerExp_4,ManagerExp_5,Language_1,Language_3,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Effort
# Shape dos dados: (81, 21)
# --------------------------------------------------
# Arquivo processado: 35-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t02,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_CustServ,app_InfServ,app_ProdCont,app_TransPro,har_Multi,har_Network,har_PC,dba_Other,ifc_GUI,ifc_TextUI,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,effort_D
# Shape dos dados: (63, 35)
# --------------------------------------------------
# Arquivo processado: 36-saida/2-saida_cocomo81.txt
# Header: rely,data,time,stor,turn,acap,pcap,vexp,lexp,modp,loc,Generated_Var_1,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,actual
# Shape dos dados: (63, 19)
# --------------------------------------------------
# Arquivo processado: 36-saida/2-saida_encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,Changed,PDR_AFP,PDR_UFP,NPDR_AFP,NPDU_UFP,Duration,N_effort,Resource_1,Resource_3,Resource_4,Generated_Var_1,Generated_Var_2,Generated_Var_4,Generated_Var_5,Generated_Var_9,Generated_Var_10,Generated_Var_11,Effort
# Shape dos dados: (499, 25)
# --------------------------------------------------
# Arquivo processado: 36-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_2,TeamExp_4,TeamExp_?,ManagerExp_0,ManagerExp_1,ManagerExp_2,ManagerExp_3,ManagerExp_4,ManagerExp_5,Language_1,Language_3,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_6,Generated_Var_7,Generated_Var_9,Generated_Var_11,Effort
# Shape dos dados: (81, 25)
# --------------------------------------------------
# Arquivo processado: 36-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t02,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_CustServ,app_InfServ,app_ProdCont,app_TransPro,har_Multi,har_Network,har_PC,dba_Other,ifc_GUI,ifc_TextUI,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_9,Generated_Var_10,Generated_Var_11,Generated_Var_12,Generated_Var_13,Generated_Var_14,Generated_Var_15,Generated_Var_16,Generated_Var_18,Generated_Var_19,effort_D
# Shape dos dados: (63, 43)
# --------------------------------------------------
# Arquivo processado: 37-saida/2-saida_cocomo81.txt
# Header: rely,data,time,stor,turn,acap,pcap,modp,loc,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_10,Generated_Var_11,Generated_Var_12,actual
# Shape dos dados: (63, 22)
# --------------------------------------------------
# Arquivo processado: 37-saida/2-saida_encoded_china.txt
# Header: ID,AFP,Input,Output,Enquiry,File,Interface,Added,Changed,Deleted,PDR_AFP,PDR_UFP,NPDR_AFP,NPDU_UFP,Duration,N_effort,Resource_1,Resource_2,Resource_3,Resource_4,Generated_Var_3,Generated_Var_4,Generated_Var_6,Generated_Var_12,Generated_Var_14,Generated_Var_15,Generated_Var_16,Effort
# Shape dos dados: (499, 28)
# --------------------------------------------------
# Arquivo processado: 37-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_2,TeamExp_4,TeamExp_?,ManagerExp_2,ManagerExp_3,ManagerExp_4,Language_1,Language_3,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_10,Generated_Var_11,Generated_Var_12,Generated_Var_14,Generated_Var_15,Generated_Var_16,Generated_Var_17,Effort
# Shape dos dados: (81, 30)
# --------------------------------------------------
# Arquivo processado: 37-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_CustServ,app_InfServ,app_TransPro,har_Multi,har_Network,har_PC,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_10,Generated_Var_11,Generated_Var_12,Generated_Var_13,Generated_Var_14,Generated_Var_15,Generated_Var_16,Generated_Var_17,Generated_Var_18,Generated_Var_19,Generated_Var_20,Generated_Var_21,Generated_Var_22,Generated_Var_23,Generated_Var_24,Generated_Var_25,Generated_Var_26,Generated_Var_27,Generated_Var_28,effort_D
# Shape dos dados: (63, 49)
# --------------------------------------------------
# Arquivo processado: 38-saida/cocomo81.txt
# Header: rely,data,time,stor,turn,acap,pcap,vexp,lexp,modp,loc,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,actual
# Shape dos dados: (63, 16)
# --------------------------------------------------
# Arquivo processado: 38-saida/encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,PDR_AFP,PDR_UFP,NPDR_AFP,NPDU_UFP,Duration,N_effort,Resource_4,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Effort
# Shape dos dados: (499, 20)
# --------------------------------------------------
# Arquivo processado: 38-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_2,TeamExp_4,TeamExp_?,ManagerExp_2,ManagerExp_3,ManagerExp_4,ManagerExp_5,Language_1,Language_3,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Effort
# Shape dos dados: (81, 21)
# --------------------------------------------------
# Arquivo processado: 38-saida/encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t02,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_CustServ,app_InfServ,app_ProdCont,app_TransPro,har_Multi,har_Network,har_PC,dba_Other,ifc_GUI,ifc_TextUI,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,effort_D
# Shape dos dados: (63, 35)
# --------------------------------------------------
# Arquivo processado: 39-saida/cocomo81.txt
# Header: rely,data,time,stor,turn,acap,pcap,lexp,modp,loc,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,actual
# Shape dos dados: (63, 19)
# --------------------------------------------------
# Arquivo processado: 39-saida/encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,Changed,PDR_AFP,PDR_UFP,NPDR_AFP,NPDU_UFP,Duration,N_effort,Resource_1,Resource_3,Resource_4,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_5,Generated_Var_9,Generated_Var_10,Generated_Var_11,Effort
# Shape dos dados: (499, 25)
# --------------------------------------------------
# Arquivo processado: 39-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_2,TeamExp_4,TeamExp_?,ManagerExp_2,ManagerExp_3,Language_1,Language_3,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_10,Generated_Var_11,Effort
# Shape dos dados: (81, 25)
# --------------------------------------------------
# Arquivo processado: 39-saida/encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t02,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_CustServ,app_InfServ,app_TransPro,har_Multi,har_Network,har_PC,ifc_GUI,ifc_TextUI,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_10,Generated_Var_11,Generated_Var_12,Generated_Var_13,Generated_Var_14,Generated_Var_15,Generated_Var_16,Generated_Var_17,Generated_Var_18,Generated_Var_19,effort_D
# Shape dos dados: (63, 43)
# --------------------------------------------------
# Arquivo processado: 4-saida/2-saida_cocomo81.txt
# Header: data,loc,MI_loc_aexp,MI_loc_data,MI_loc_stor,actual
# Shape dos dados: (63, 6)
# --------------------------------------------------
# Arquivo processado: 4-saida/2-saida_encoded_china.txt
# Header: AFP,Added,N_effort,MI_N_effort_PDR_AFP,MI_N_effort_NPDU_UFP,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 7)
# --------------------------------------------------
# Arquivo processado: 4-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,PointsAdjust,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 7)
# --------------------------------------------------
# Arquivo processado: 4-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,t07,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_t02,MI_size_D_t08,MI_duration_D_t07,effort_D
# Shape dos dados: (63, 12)
# --------------------------------------------------
# Arquivo processado: 40-saida/cocomo81.txt
# Header: rely,data,time,stor,turn,acap,pcap,modp,loc,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_10,Generated_Var_11,Generated_Var_12,actual
# Shape dos dados: (63, 22)
# --------------------------------------------------
# Arquivo processado: 40-saida/encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,Changed,PDR_AFP,PDR_UFP,NPDR_AFP,NPDU_UFP,Duration,N_effort,Resource_1,Resource_3,Resource_4,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_12,Generated_Var_15,Generated_Var_16,Effort
# Shape dos dados: (499, 28)
# --------------------------------------------------
# Arquivo processado: 40-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_4,TeamExp_?,ManagerExp_2,ManagerExp_3,Language_1,Language_3,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_10,Generated_Var_11,Generated_Var_12,Generated_Var_13,Generated_Var_14,Generated_Var_15,Generated_Var_16,Generated_Var_17,Effort
# Shape dos dados: (81, 30)
# --------------------------------------------------
# Arquivo processado: 40-saida/encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_CustServ,app_InfServ,app_TransPro,har_Multi,har_Network,har_PC,Generated_Var_1,Generated_Var_2,Generated_Var_3,Generated_Var_4,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_8,Generated_Var_9,Generated_Var_10,Generated_Var_11,Generated_Var_12,Generated_Var_13,Generated_Var_14,Generated_Var_15,Generated_Var_16,Generated_Var_17,Generated_Var_18,Generated_Var_19,Generated_Var_20,Generated_Var_21,Generated_Var_22,Generated_Var_23,Generated_Var_24,Generated_Var_25,Generated_Var_26,Generated_Var_27,Generated_Var_28,effort_D
# Shape dos dados: (63, 49)
# --------------------------------------------------
# Arquivo processado: 41-saida/cocomo81.txt
# Header: rely,data,time,stor,turn,acap,pcap,vexp,lexp,modp,loc,MI_loc_aexp,MI_loc_data,MI_loc_stor,MI_aexp_data,actual
# Shape dos dados: (63, 16)
# --------------------------------------------------
# Arquivo processado: 41-saida/encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,PDR_AFP,PDR_UFP,NPDR_AFP,NPDU_UFP,Duration,N_effort,Resource_4,MI_N_effort_AFP,MI_N_effort_PDR_AFP,MI_N_effort_NPDU_UFP,MI_N_effort_Added,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 20)
# --------------------------------------------------
# Arquivo processado: 41-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_2,TeamExp_4,TeamExp_?,ManagerExp_2,ManagerExp_3,ManagerExp_4,ManagerExp_5,Language_1,Language_3,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_PointsAdjust_Language_3,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 21)
# --------------------------------------------------
# Arquivo processado: 41-saida/encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t02,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_CustServ,app_InfServ,app_ProdCont,app_TransPro,har_Multi,har_Network,har_PC,dba_Other,ifc_GUI,ifc_TextUI,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_app_InfServ,MI_size_D_t02,MI_size_D_t08,MI_duration_D_t07,effort_D
# Shape dos dados: (63, 35)
# --------------------------------------------------
# Arquivo processado: 42-saida/cocomo81.txt
# Header: rely,data,time,stor,turn,acap,pcap,lexp,modp,loc,MI_loc_aexp,MI_loc_data,MI_loc_stor,MI_loc_time,MI_loc_cplx,MI_loc_turn,MI_loc_pcap,MI_aexp_data,actual
# Shape dos dados: (63, 19)
# --------------------------------------------------
# Arquivo processado: 42-saida/encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,PDR_AFP,PDR_UFP,NPDU_UFP,Duration,N_effort,Resource_4,MI_N_effort_AFP,MI_N_effort_PDR_AFP,MI_N_effort_NPDU_UFP,MI_N_effort_Added,MI_N_effort_PDR_UFP,MI_N_effort_Enquiry,MI_N_effort_NPDR_AFP,MI_N_effort_Input,MI_N_effort_Duration,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 24)
# --------------------------------------------------
# Arquivo processado: 42-saida/encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_0,TeamExp_1,TeamExp_2,TeamExp_4,TeamExp_?,ManagerExp_2,ManagerExp_3,ManagerExp_4,Language_1,Language_3,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_PointsAdjust_Language_3,MI_PointsAdjust_Language_2,MI_PointsAdjust_Language_1,MI_PointsAdjust_ManagerExp_4,MI_PointsAdjust_ManagerExp_2,MI_PointsAdjust_ManagerExp_3,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 25)
# --------------------------------------------------
# Arquivo processado: 42-saida/encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t01,t02,t03,t07,t08,t09,t10,t11,t12,t13,t14,t15,app_CustServ,app_InfServ,app_TransPro,har_Multi,har_Network,har_PC,dba_Other,ifc_GUI,ifc_TextUI,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_app_InfServ,MI_size_D_t02,MI_size_D_t08,MI_size_D_har_Mainfrm,MI_size_D_t03,MI_size_D_t14,MI_size_D_t10,MI_size_D_t15,MI_size_D_t12,MI_size_D_app_ProdCont,MI_size_D_telonuse_Yes,MI_duration_D_t07,effort_D
# Shape dos dados: (63, 42)
# --------------------------------------------------
# Arquivo processado: 5-saida/2-saida_cocomo81.txt
# Header: MI_loc_aexp,MI_loc_data,MI_loc_stor,MI_loc_time,MI_loc_cplx,MI_loc_turn,actual
# Shape dos dados: (63, 7)
# --------------------------------------------------
# Arquivo processado: 5-saida/2-saida_encoded_china.txt
# Header: AFP,Added,N_effort,MI_N_effort_PDR_UFP,MI_N_effort_Enquiry,MI_N_effort_Duration,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 8)
# --------------------------------------------------
# Arquivo processado: 5-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_PointsAdjust_Language_1,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 9)
# --------------------------------------------------
# Arquivo processado: 5-saida/2-saida_encoded_maxwell.txt
# Header: size_D,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_t02,MI_size_D_t08,MI_size_D_har_Mainfrm,MI_size_D_t10,MI_size_D_t15,MI_size_D_t12,MI_duration_D_t07,effort_D
# Shape dos dados: (63, 14)
# --------------------------------------------------
# Arquivo processado: 6-saida/2-saida_cocomo81.txt
# Header: MI_loc_data,MI_loc_stor,MI_loc_time,MI_loc_cplx,MI_loc_turn,MI_loc_rely,MI_loc_vexp,actual
# Shape dos dados: (63, 8)
# --------------------------------------------------
# Arquivo processado: 6-saida/2-saida_encoded_china.txt
# Header: AFP,Added,N_effort,MI_N_effort_PDR_AFP,MI_N_effort_PDR_UFP,MI_N_effort_Enquiry,MI_N_effort_Duration,MI_N_effort_Output,MI_AFP_PDR_AFP,Effort
# Shape dos dados: (499, 10)
# --------------------------------------------------
# Arquivo processado: 6-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,MI_PointsAdjust_Entities,MI_PointsAdjust_Envergure,MI_PointsAdjust_Transactions,MI_PointsAdjust_Language_1,MI_PointsAdjust_YearEnd,MI_Entities_Envergure,Effort
# Shape dos dados: (81, 10)
# --------------------------------------------------
# Arquivo processado: 6-saida/2-saida_encoded_maxwell.txt
# Header: size_D,MI_size_D_duration_D,MI_size_D_t07,MI_size_D_t11,MI_size_D_t09,MI_size_D_nlan,MI_size_D_t08,MI_size_D_har_Mainfrm,MI_size_D_t10,MI_size_D_t15,MI_size_D_t12,MI_size_D_ifc_TextUI,MI_size_D_t01,MI_size_D_t04,MI_size_D_t06,MI_size_D_t13,effort_D
# Shape dos dados: (63, 17)
# --------------------------------------------------
# Arquivo processado: 7-saida/2-saida_cocomo81.txt
# Header: data,loc,Generated_Var_1,Generated_Var_3,Generated_Var_4,actual
# Shape dos dados: (63, 6)
# --------------------------------------------------
# Arquivo processado: 7-saida/2-saida_encoded_china.txt
# Header: AFP,Input,Output,File,Added,N_effort,Effort
# Shape dos dados: (499, 7)
# --------------------------------------------------
# Arquivo processado: 7-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_?,Language_3,Effort
# Shape dos dados: (81, 7)
# --------------------------------------------------
# Arquivo processado: 7-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t07,t11,t14,Generated_Var_2,Generated_Var_4,Generated_Var_6,Generated_Var_8,Generated_Var_9,effort_D
# Shape dos dados: (63, 12)
# --------------------------------------------------
# Arquivo processado: 8-saida/2-saida_cocomo81.txt
# Header: data,modp,loc,Generated_Var_1,Generated_Var_4,Generated_Var_7,actual
# Shape dos dados: (63, 7)
# --------------------------------------------------
# Arquivo processado: 8-saida/2-saida_encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Added,N_effort,Generated_Var_2,Effort
# Shape dos dados: (499, 9)
# --------------------------------------------------
# Arquivo processado: 8-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Envergure,TeamExp_1,TeamExp_?,ManagerExp_2,Language_3,Effort
# Shape dos dados: (81, 9)
# --------------------------------------------------
# Arquivo processado: 8-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,nlan,t07,t11,t14,Generated_Var_2,Generated_Var_3,Generated_Var_10,Generated_Var_11,Generated_Var_12,Generated_Var_16,Generated_Var_18,Generated_Var_19,effort_D
# Shape dos dados: (63, 15)
# --------------------------------------------------
# Arquivo processado: 9-saida/2-saida_cocomo81.txt
# Header: loc,Generated_Var_1,Generated_Var_5,Generated_Var_6,Generated_Var_7,Generated_Var_9,Generated_Var_11,actual
# Shape dos dados: (63, 8)
# --------------------------------------------------
# Arquivo processado: 9-saida/2-saida_encoded_china.txt
# Header: AFP,Input,Output,Enquiry,File,Interface,Added,Duration,N_effort,Effort
# Shape dos dados: (499, 10)
# --------------------------------------------------
# Arquivo processado: 9-saida/2-saida_encoded_desharnais.txt
# Header: Transactions,Entities,PointsAdjust,Generated_Var_2,Generated_Var_4,Generated_Var_7,Generated_Var_8,Generated_Var_12,Generated_Var_16,Effort
# Shape dos dados: (81, 10)
# --------------------------------------------------
# Arquivo processado: 9-saida/2-saida_encoded_maxwell.txt
# Header: size_D,duration_D,Generated_Var_3,Generated_Var_5,Generated_Var_7,Generated_Var_8,Generated_Var_11,Generated_Var_12,Generated_Var_16,Generated_Var_18,Generated_Var_19,Generated_Var_20,Generated_Var_23,Generated_Var_25,Generated_Var_26,Generated_Var_28,effort_D
# Shape dos dados: (63, 17)
# --------------------------------------------------

# %%
import optuna
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error, r2_score

# Função para encontrar os melhores hiperparâmetros usando Optuna
def objective(trial, X, y):
    """
    Função objetivo para o Optuna.

    Args:
        trial (optuna.trial.Trial): Objeto de tentativa do Optuna.
        X (np.ndarray): Variáveis independentes.
        y (np.ndarray): Variável dependente.

    Returns:
        float: Métrica a ser minimizada ou maximizada.
    """
    # Hiperparâmetros a serem otimizados
    fit_intercept = trial.suggest_categorical("fit_intercept", [True, False])
    positive = trial.suggest_categorical("positive", [True, False])

    # Configurar validação cruzada
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    r2_scores = []

    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        # Criar o modelo
        model = LinearRegression(fit_intercept=fit_intercept, positive=positive)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # Calcular R²
        r2_scores.append(r2_score(y_test, y_pred))

    return -np.mean(r2_scores)  # Negativo porque Optuna minimiza a função objetivo

# Criar um estudo Optuna para cada dataset
best_params_summary = []

for key, (header, data) in datasets.items():
    print(f"Otimizando hiperparâmetros para o dataset: {key}")

    X = data[:, :-1]
    y = data[:, -1]

    study = optuna.create_study(direction="minimize")
    study.optimize(lambda trial: objective(trial, X, y), n_trials=50)

    # Salvar os melhores hiperparâmetros e o melhor valor objetivo
    best_params_summary.append({
        "Dataset": key,
        "Best Params": study.best_params,
        "Best R²": -study.best_value  # Tornar positivo novamente
    })

    print(f"Melhores hiperparâmetros para {key}: {study.best_params}")
    print(f"Melhor R² para {key}: {-study.best_value}")
    print("-" * 50)

# Converter o resumo para DataFrame e salvar
results_df = pd.DataFrame(best_params_summary)
results_df.to_excel("optuna_hyperparameter_tuning_results.xlsx", index=False)
print("Resultados salvos em optuna_hyperparameter_tuning_results.xlsx")
# Out:
# [I 2024-12-19 07:22:41,791] A new study created in memory with name: no-name-fdafa410-5279-497f-a747-a99cb67583ec
# [I 2024-12-19 07:22:41,812] Trial 0 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,820] Trial 1 finished with value: 1.2313568505187893 and parameters: {'fit_intercept': False, 'positive': False}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,829] Trial 2 finished with value: 2.4875991132493422 and parameters: {'fit_intercept': True, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,833] Trial 3 finished with value: 1.2313568505187893 and parameters: {'fit_intercept': False, 'positive': False}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,837] Trial 4 finished with value: 1.2313568505187893 and parameters: {'fit_intercept': False, 'positive': False}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,843] Trial 5 finished with value: 2.4875991132493422 and parameters: {'fit_intercept': True, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,848] Trial 6 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,853] Trial 7 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,856] Trial 8 finished with value: 1.2313568505187893 and parameters: {'fit_intercept': False, 'positive': False}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,861] Trial 9 finished with value: 1.2313568505187893 and parameters: {'fit_intercept': False, 'positive': False}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,864] Trial 10 finished with value: 2.4875991132493422 and parameters: {'fit_intercept': True, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,874] Trial 11 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,880] Trial 12 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,885] Trial 13 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,892] Trial 14 finished with value: 2.4875991132493422 and parameters: {'fit_intercept': True, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,898] Trial 15 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,904] Trial 16 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,909] Trial 17 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,914] Trial 18 finished with value: 2.4875991132493422 and parameters: {'fit_intercept': True, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,920] Trial 19 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,927] Trial 20 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,933] Trial 21 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,934] Trial 22 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,944] Trial 23 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,949] Trial 24 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,955] Trial 25 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,960] Trial 26 finished with value: 2.4875991132471045 and parameters: {'fit_intercept': True, 'positive': False}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,966] Trial 27 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,969] Trial 28 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,977] Trial 29 finished with value: 1.2313568505187893 and parameters: {'fit_intercept': False, 'positive': False}. Best is trial 0 with value: 1.0978008294111463.
# Otimizando hiperparâmetros para o dataset: 1-saida/cocomo81.txt
# [I 2024-12-19 07:22:41,983] Trial 30 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,989] Trial 31 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:41,995] Trial 32 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,002] Trial 33 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,004] Trial 34 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,013] Trial 35 finished with value: 2.4875991132471045 and parameters: {'fit_intercept': True, 'positive': False}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,018] Trial 36 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,026] Trial 37 finished with value: 1.2313568505187893 and parameters: {'fit_intercept': False, 'positive': False}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,031] Trial 38 finished with value: 2.4875991132493422 and parameters: {'fit_intercept': True, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,039] Trial 39 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,045] Trial 40 finished with value: 1.2313568505187893 and parameters: {'fit_intercept': False, 'positive': False}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,051] Trial 41 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,056] Trial 42 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,063] Trial 43 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,066] Trial 44 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,076] Trial 45 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,080] Trial 46 finished with value: 2.4875991132493422 and parameters: {'fit_intercept': True, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,089] Trial 47 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,093] Trial 48 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,100] Trial 49 finished with value: 1.0978008294111463 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 0 with value: 1.0978008294111463.
# [I 2024-12-19 07:22:42,101] A new study created in memory with name: no-name-244117db-1181-432a-a49d-f2aef422d2c6
# [I 2024-12-19 07:22:42,107] Trial 0 finished with value: -0.9735634364574629 and parameters: {'fit_intercept': True, 'positive': True}. Best is trial 0 with value: -0.9735634364574629.
# [I 2024-12-19 07:22:42,113] Trial 1 finished with value: -0.9735634364574629 and parameters: {'fit_intercept': True, 'positive': True}. Best is trial 0 with value: -0.9735634364574629.
# [I 2024-12-19 07:22:42,115] Trial 2 finished with value: -0.9737555800230497 and parameters: {'fit_intercept': True, 'positive': False}. Best is trial 2 with value: -0.9737555800230497.
# [I 2024-12-19 07:22:42,125] Trial 3 finished with value: -0.9735634364574629 and parameters: {'fit_intercept': True, 'positive': True}. Best is trial 2 with value: -0.9737555800230497.
# [I 2024-12-19 07:22:42,130] Trial 4 finished with value: -0.9737555800230497 and parameters: {'fit_intercept': True, 'positive': False}. Best is trial 2 with value: -0.9737555800230497.
# [I 2024-12-19 07:22:42,135] Trial 5 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,140] Trial 6 finished with value: -0.9741396062782017 and parameters: {'fit_intercept': False, 'positive': False}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,145] Trial 7 finished with value: -0.9741396062782017 and parameters: {'fit_intercept': False, 'positive': False}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,152] Trial 8 finished with value: -0.9735634364574629 and parameters: {'fit_intercept': True, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,157] Trial 9 finished with value: -0.9737555800230497 and parameters: {'fit_intercept': True, 'positive': False}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,163] Trial 10 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,168] Trial 11 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,174] Trial 12 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,177] Trial 13 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,186] Trial 14 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,193] Trial 15 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,198] Trial 16 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,204] Trial 17 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,210] Trial 18 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,216] Trial 19 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,219] Trial 20 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,227] Trial 21 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,233] Trial 22 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,245] Trial 23 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,252] Trial 24 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,269] Trial 25 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,279] Trial 26 finished with value: -0.9741396062782017 and parameters: {'fit_intercept': False, 'positive': False}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,280] Trial 27 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# Melhores hiperparâmetros para 1-saida/cocomo81.txt: {'fit_intercept': False, 'positive': True}
# Melhor R² para 1-saida/cocomo81.txt: -1.0978008294111463
# --------------------------------------------------
# Otimizando hiperparâmetros para o dataset: 1-saida/encoded_china.txt
# [I 2024-12-19 07:22:42,290] Trial 28 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,296] Trial 29 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,302] Trial 30 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,308] Trial 31 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,314] Trial 32 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,321] Trial 33 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,327] Trial 34 finished with value: -0.9735634364574629 and parameters: {'fit_intercept': True, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,334] Trial 35 finished with value: -0.9735634364574629 and parameters: {'fit_intercept': True, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,337] Trial 36 finished with value: -0.9741396062782017 and parameters: {'fit_intercept': False, 'positive': False}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,346] Trial 37 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,351] Trial 38 finished with value: -0.9737555800230497 and parameters: {'fit_intercept': True, 'positive': False}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,359] Trial 39 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,364] Trial 40 finished with value: -0.9737555800230497 and parameters: {'fit_intercept': True, 'positive': False}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,371] Trial 41 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,377] Trial 42 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,383] Trial 43 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,390] Trial 44 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,396] Trial 45 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,399] Trial 46 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,409] Trial 47 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,413] Trial 48 finished with value: -0.9737555800230497 and parameters: {'fit_intercept': True, 'positive': False}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,421] Trial 49 finished with value: -0.9743264932186891 and parameters: {'fit_intercept': False, 'positive': True}. Best is trial 5 with value: -0.9743264932186891.
# [I 2024-12-19 07:22:42,422] A new study created in memory with name: no-name-3ff021c9-b9bf-468c-823e-0928b32649cf
# [W 2024-12-19 07:22:42,428] Trial 0 failed with parameters: {'fit_intercept': True, 'positive': True} because of the following error: RuntimeError('Maximum number of iterations reached.').
# Traceback (most recent call last):
#   File "C:\Users\CALEO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\optuna\study\_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\CALEO\AppData\Local\Temp\ipykernel_5044\1225915622.py", line 51, in <lambda>
#     study.optimize(lambda trial: objective(trial, X, y), n_trials=50)
#                                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\CALEO\AppData\Local\Temp\ipykernel_5044\1225915622.py", line 33, in objective
#     model.fit(X_train, y_train)
#   File "C:\Users\CALEO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\CALEO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_base.py", line 640, in fit
#     self.coef_ = optimize.nnls(X, y)[0]
#                  ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\CALEO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\_nnls.py", line 93, in nnls
#     raise RuntimeError("Maximum number of iterations reached.")
# RuntimeError: Maximum number of iterations reached.
# [W 2024-12-19 07:22:42,462] Trial 0 failed with value None.
# Melhores hiperparâmetros para 1-saida/encoded_china.txt: {'fit_intercept': False, 'positive': True}
# Melhor R² para 1-saida/encoded_china.txt: 0.9743264932186891
# --------------------------------------------------
# Otimizando hiperparâmetros para o dataset: 1-saida/encoded_desharnais.txt
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 51
#      48 y = data[:, -1]
#      50 study = optuna.create_study(direction="minimize")
# ---> 51 study.optimize(lambda trial: objective(trial, X, y), n_trials=50)
#      53 # Salvar os melhores hiperparâmetros e o melhor valor objetivo
#      54 best_params_summary.append({
#      55     "Dataset": key,
#      56     "Best Params": study.best_params,
#      57     "Best R²": -study.best_value  # Tornar positivo novamente
#      58 })
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\optuna\study\study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\optuna\study\_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\optuna\study\_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\optuna\study\_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\optuna\study\_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[2], line 51, in <lambda>(trial)
#      48 y = data[:, -1]
#      50 study = optuna.create_study(direction="minimize")
# ---> 51 study.optimize(lambda trial: objective(trial, X, y), n_trials=50)
#      53 # Salvar os melhores hiperparâmetros e o melhor valor objetivo
#      54 best_params_summary.append({
#      55     "Dataset": key,
#      56     "Best Params": study.best_params,
#      57     "Best R²": -study.best_value  # Tornar positivo novamente
#      58 })
#
# Cell In[2], line 33, in objective(trial, X, y)
#      31 # Criar o modelo
#      32 model = LinearRegression(fit_intercept=fit_intercept, positive=positive)
# ---> 33 model.fit(X_train, y_train)
#      34 y_pred = model.predict(X_test)
#      36 # Calcular R²
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_base.py:640, in LinearRegression.fit(self, X, y, sample_weight)
#     638 if self.positive:
#     639     if y.ndim < 2:
# --> 640         self.coef_ = optimize.nnls(X, y)[0]
#     641     else:
#     642         # scipy.optimize.nnls cannot handle y with shape (M, K)
#     643         outs = Parallel(n_jobs=n_jobs_)(
#     644             delayed(optimize.nnls)(X, y[:, j]) for j in range(y.shape[1])
#     645         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\_nnls.py:93, in nnls(A, b, maxiter, atol)
#      91 x, rnorm, mode = _nnls(A, b, maxiter, tol=atol)
#      92 if mode != 1:
# ---> 93     raise RuntimeError("Maximum number of iterations reached.")
#      95 return x, rnorm
#
# RuntimeError: Maximum number of iterations reached.
