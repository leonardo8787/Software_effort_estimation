# %% [markdown]
# # Aplica correlação para excluir variáveis correlacionadas (90%)
#
#
# Aplica correlação na saída de tratamento de variáveis com target encoding.

# %%
import os
import pandas as pd
import numpy as np

def calculate_correlation_matrix(data, target_column, correlation_threshold=0.9):
    """
    Calcula a matriz de correlação e identifica variáveis altamente correlacionadas.

    Args:
        data (pd.DataFrame): Dataset contendo as variáveis.
        target_column (str): Nome da coluna alvo.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.

    Returns:
        list: Lista de variáveis a serem removidas.
    """
    correlation_matrix = data.drop(columns=[target_column]).corr()
    columns_to_remove = set()

    for i in range(len(correlation_matrix.columns)):
        for j in range(i):
            if abs(correlation_matrix.iloc[i, j]) > correlation_threshold:
                col_to_remove = correlation_matrix.columns[i]
                columns_to_remove.add(col_to_remove)
    
    return list(columns_to_remove)

def remove_highly_correlated_features(data, target_column, correlation_threshold=0.9):
    """
    Remove variáveis altamente correlacionadas com base em um limite.

    Args:
        data (pd.DataFrame): Dataset original.
        target_column (str): Nome da coluna alvo.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.

    Returns:
        pd.DataFrame: Dataset com variáveis correlacionadas removidas.
    """
    columns_to_remove = calculate_correlation_matrix(data, target_column, correlation_threshold)
    print(f"Variáveis removidas devido à alta correlação: {columns_to_remove}")
    return data.drop(columns=columns_to_remove)

def process_datasets(input_dir, output_dir, correlation_threshold=0.9):
    """
    Processa os datasets em uma pasta, remove variáveis correlacionadas e salva os resultados.

    Args:
        input_dir (str): Caminho do diretório de entrada.
        output_dir (str): Caminho do diretório de saída.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.
    """
    # Garante que o diretório de saída existe
    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith(".txt"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)

            print(f"Processando arquivo: {input_path}")
            try:
                data = pd.read_csv(input_path, delimiter=",", skipinitialspace=True)
                target_column = data.columns[-1]

                # Remover variáveis altamente correlacionadas
                data_cleaned = remove_highly_correlated_features(data, target_column, correlation_threshold)

                # Reorganizar as colunas para manter a coluna alvo no final
                columns = [col for col in data_cleaned.columns if col != target_column] + [target_column]
                data_cleaned = data_cleaned[columns]

                data_cleaned.to_csv(output_path, sep=",", index=False)
                print(f"Arquivo processado e salvo em: {output_path}")

            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

# Diretórios de entrada e saída
input_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado"
output_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\correlacao\1-tratamento"

# Processar arquivos removendo variáveis correlacionadas
process_datasets(input_directory, output_directory, correlation_threshold=0.9)
# Out:
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['Input', 'PDR_UFP', 'NPDR_AFP', 'Added', 'File', 'NPDU_UFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\correlacao\1-tratamento\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: []
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\correlacao\1-tratamento\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: []
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\correlacao\1-tratamento\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: []
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\correlacao\1-tratamento\tratamento_maxwell.txt

# %% [markdown]
# # Aplica correlação em todas as pastas em "2-geracao-variaveis"

# %%
import os
import pandas as pd
import numpy as np

def calculate_correlation_matrix(data, target_column, correlation_threshold=0.9):
    """
    Calcula a matriz de correlação e identifica variáveis altamente correlacionadas.

    Args:
        data (pd.DataFrame): Dataset contendo as variáveis.
        target_column (str): Nome da coluna alvo.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.

    Returns:
        list: Lista de variáveis a serem removidas.
    """
    correlation_matrix = data.drop(columns=[target_column]).corr()
    columns_to_remove = set()

    for i in range(len(correlation_matrix.columns)):
        for j in range(i):
            if abs(correlation_matrix.iloc[i, j]) > correlation_threshold:
                col_to_remove = correlation_matrix.columns[i]
                columns_to_remove.add(col_to_remove)
    
    return list(columns_to_remove)

def remove_highly_correlated_features(data, target_column, correlation_threshold=0.9):
    """
    Remove variáveis altamente correlacionadas com base em um limite.

    Args:
        data (pd.DataFrame): Dataset original.
        target_column (str): Nome da coluna alvo.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.

    Returns:
        pd.DataFrame: Dataset com variáveis correlacionadas removidas.
    """
    columns_to_remove = calculate_correlation_matrix(data, target_column, correlation_threshold)
    print(f"Variáveis removidas devido à alta correlação: {columns_to_remove}")
    return data.drop(columns=columns_to_remove)

def process_datasets(input_dir, output_dir, correlation_threshold=0.9):
    """
    Processa os datasets em uma pasta, remove variáveis correlacionadas e salva os resultados.

    Args:
        input_dir (str): Caminho do diretório de entrada.
        output_dir (str): Caminho do diretório de saída.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.
    """
    # Percorre todas as subpastas
    for root, dirs, files in os.walk(input_dir):
        for filename in files:
            if filename.endswith(".txt"):
                input_path = os.path.join(root, filename)
                
                # Recria a estrutura de subpastas na saída
                relative_path = os.path.relpath(input_path, input_dir)
                output_path = os.path.join(output_dir, relative_path)

                # Cria a pasta de saída, se necessário
                os.makedirs(os.path.dirname(output_path), exist_ok=True)

                print(f"Processando arquivo: {input_path}")
                try:
                    data = pd.read_csv(input_path, delimiter=",", skipinitialspace=True)
                    target_column = data.columns[-1]

                    # Remover variáveis altamente correlacionadas
                    data_cleaned = remove_highly_correlated_features(data, target_column, correlation_threshold)

                    # Reorganizar as colunas para manter a coluna alvo no final
                    columns = [col for col in data_cleaned.columns if col != target_column] + [target_column]
                    data_cleaned = data_cleaned[columns]

                    data_cleaned.to_csv(output_path, sep=",", index=False)
                    print(f"Arquivo processado e salvo em: {output_path}")

                except Exception as e:
                    print(f"Erro ao processar {filename}: {e}")

# Diretórios de entrada e saída
input_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis"
output_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\correlacao\2-geracao"

# Processar arquivos removendo variáveis correlacionadas
process_datasets(input_directory, output_directory, correlation_threshold=0.9)
# Out:
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['Input', 'PDR_UFP', 'NPDR_AFP', 'Added', 'File', 'Generated_Var_4', 'NPDU_UFP', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\correlacao\2-geracao\2-GAN-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_2', 'Generated_Var_4', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\correlacao\2-geracao\2-GAN-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_2']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\correlacao\2-geracao\2-GAN-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_4']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\correlacao\2-geracao\2-GAN-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis
tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['MI_N_effort_AFP', 'Input', 'PDR_UFP', 'MI_N_effort_NPDR_AFP', 'MI_AFP_PDR_AFP', 'NPDR_AFP', 'Added', 'File', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Added', 'NPDU_UFP', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_Input', 'MI_N_effort_File']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\correlacao\2-geracao\7-MIMIC-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_data', 'MI_loc_cplx', 'MI_loc_rely', 'MI_loc_vexp', 'MI_loc_time', 'MI_loc_pcap']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\correlacao\2-geracao\7-MIMIC-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['MI_PointsAdjust_Envergure', 'MI_PointsAdjust_ManagerExp', 'MI_PointsAdjust_Transactions']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\correlacao\2-geracao\7-MIMIC-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['MI_size_D_t11', 'MI_size_D_t12', 'MI_size_D_t10', 'MI_size_D_har', 'MI_size_D_t15', 'MI_size_D_dba', 'MI_size_D_t07', 'MI_size_D_ifc', 'MI_size_D_t09', 'MI_size_D_app', 'MI_size_D_nlan', 'MI_size_D_t02', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\correlacao\2-geracao\7-MIMIC-75\tratamento_maxwell.txt

# %% [markdown]
# # Aplica a correlação na simulação

# %%
import os
import pandas as pd
import numpy as np

def calculate_correlation_matrix(data, target_column, correlation_threshold=0.9):
    """
    Calcula a matriz de correlação e identifica variáveis altamente correlacionadas.

    Args:
        data (pd.DataFrame): Dataset contendo as variáveis.
        target_column (str): Nome da coluna alvo.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.

    Returns:
        list: Lista de variáveis a serem removidas.
    """
    correlation_matrix = data.drop(columns=[target_column]).corr()
    columns_to_remove = set()

    for i in range(len(correlation_matrix.columns)):
        for j in range(i):
            if abs(correlation_matrix.iloc[i, j]) > correlation_threshold:
                col_to_remove = correlation_matrix.columns[i]
                columns_to_remove.add(col_to_remove)
    
    return list(columns_to_remove)

def remove_highly_correlated_features(data, target_column, correlation_threshold=0.9):
    """
    Remove variáveis altamente correlacionadas com base em um limite.

    Args:
        data (pd.DataFrame): Dataset original.
        target_column (str): Nome da coluna alvo.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.

    Returns:
        pd.DataFrame: Dataset com variáveis correlacionadas removidas.
    """
    columns_to_remove = calculate_correlation_matrix(data, target_column, correlation_threshold)
    print(f"Variáveis removidas devido à alta correlação: {columns_to_remove}")
    return data.drop(columns=columns_to_remove)

def process_all_datasets(input_root_dir, output_root_dir, correlation_threshold=0.9):
    """
    Processa todos os datasets dentro de um diretório raiz, removendo variáveis correlacionadas.

    Args:
        input_root_dir (str): Diretório raiz de entrada contendo subpastas e arquivos.
        output_root_dir (str): Diretório raiz de saída para salvar os arquivos processados.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.
    """
    excluded_path = os.path.join(input_root_dir, "4-escolha")
    
    for root, dirs, files in os.walk(input_root_dir):
        # Pular o diretório excluído
        if excluded_path in root:
            continue
        
        for filename in files:
            if filename.endswith(".txt"):
                input_path = os.path.join(root, filename)
                
                # Recria a estrutura de subpastas na saída
                relative_path = os.path.relpath(input_path, input_root_dir)
                output_path = os.path.join(output_root_dir, relative_path)

                # Cria a pasta de saída, se necessário
                os.makedirs(os.path.dirname(output_path), exist_ok=True)

                print(f"Processando arquivo: {input_path}")
                try:
                    data = pd.read_csv(input_path, delimiter=",", skipinitialspace=True)
                    target_column = data.columns[-1]

                    # Remover variáveis altamente correlacionadas
                    data_cleaned = remove_highly_correlated_features(data, target_column, correlation_threshold)

                    # Reorganizar as colunas para manter a coluna alvo no final
                    columns = [col for col in data_cleaned.columns if col != target_column] + [target_column]
                    data_cleaned = data_cleaned[columns]

                    data_cleaned.to_csv(output_path, sep=",", index=False)
                    print(f"Arquivo processado e salvo em: {output_path}")

                except Exception as e:
                    print(f"Erro ao processar {filename}: {e}")

# Caminhos de entrada e saída
input_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida"
output_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao"

# Processar arquivos removendo variáveis correlacionadas
process_all_datasets(input_directory, output_directory, correlation_threshold=0.9)
# Out:
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['Input', 'Added', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'File']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\1-tratamento-target-encoding-normalizado\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: []
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\1-tratamento-target-encoding-normalizado\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: []
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\1-tratamento-target-encoding-normalizado\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: []
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\1-tratamento-target-encoding-normalizado\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\2-GAN-25\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['Input', 'Added', 'Generated_Var_4', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Generated_Var_3', 'File']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\2-GAN-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\2-GAN-25\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_2', 'Generated_Var_4', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\2-GAN-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\2-GAN-25\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_2']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\2-GAN-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\2-GAN-25\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_4']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\2-GAN-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\3-GAN-50\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['Input', 'Added', 'Generated_Var_7', 'Generated_Var_2', 'Generated_Var_4', 'PDR_UFP', 'NPDR_AFP', 'Generated_Var_6', 'NPDU_UFP', 'Generated_Var_5', 'Generated_Var_9', 'File']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\3-GAN-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\3-GAN-50\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_8', 'Generated_Var_4', 'Generated_Var_6', 'Generated_Var_7']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\3-GAN-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\3-GAN-50\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_4', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\3-GAN-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\3-GAN-50\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_7', 'Generated_Var_2', 'Generated_Var_4', 'Generated_Var_10', 'Generated_Var_9', 'Generated_Var_8', 'Generated_Var_11']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\3-GAN-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\4-GAN-75\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_13', 'Input', 'Added', 'Generated_Var_7', 'Generated_Var_12', 'Generated_Var_10', 'PDR_UFP', 'NPDR_AFP', 'Generated_Var_6', 'Generated_Var_14', 'NPDU_UFP', 'Generated_Var_5', 'Generated_Var_9', 'Generated_Var_8', 'File', 'Generated_Var_11']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\4-GAN-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\4-GAN-75\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_7', 'Generated_Var_2', 'Generated_Var_4', 'Generated_Var_10', 'Generated_Var_12', 'Generated_Var_6', 'Generated_Var_5', 'Generated_Var_3', 'Generated_Var_9', 'Generated_Var_8', 'Generated_Var_11']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\4-GAN-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\4-GAN-75\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_2', 'Generated_Var_4', 'Generated_Var_6', 'Generated_Var_5', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\4-GAN-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\4-GAN-75\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_13', 'Generated_Var_7', 'Generated_Var_12', 'Generated_Var_4', 'Generated_Var_10', 'Generated_Var_18', 'Generated_Var_6', 'Generated_Var_14', 'Generated_Var_16', 'Generated_Var_5', 'Generated_Var_17', 'Generated_Var_9', 'Generated_Var_8', 'Generated_Var_15', 'Generated_Var_11']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\4-GAN-75\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['MI_N_effort_Added', 'Input', 'Added', 'MI_N_effort_AFP', 'PDR_UFP', 'NPDR_AFP', 'MI_AFP_PDR_AFP', 'NPDU_UFP', 'File']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\5-MIMIC-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_data']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\5-MIMIC-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: []
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\5-MIMIC-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['MI_size_D_t11', 'MI_size_D_nlan', 'MI_duration_D_t07', 'MI_size_D_t09', 'MI_size_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\5-MIMIC-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['MI_N_effort_Added', 'Input', 'MI_N_effort_Input', 'MI_N_effort_NPDR_AFP', 'Added', 'MI_N_effort_AFP', 'MI_N_effort_NPDU_UFP', 'PDR_UFP', 'NPDR_AFP', 'MI_AFP_PDR_AFP', 'NPDU_UFP', 'File', 'MI_N_effort_PDR_UFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\6-MIMIC-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_data', 'MI_loc_cplx', 'MI_loc_pcap', 'MI_loc_time']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\6-MIMIC-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['MI_PointsAdjust_Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\6-MIMIC-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['MI_size_D_t11', 'MI_size_D_t02', 'MI_size_D_nlan', 'MI_size_D_app', 'MI_duration_D_t07', 'MI_size_D_t09', 'MI_size_D_t10', 'MI_size_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\6-MIMIC-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['MI_N_effort_Added', 'Input', 'MI_N_effort_Input', 'MI_N_effort_NPDR_AFP', 'Added', 'MI_N_effort_AFP', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_File', 'PDR_UFP', 'NPDR_AFP', 'MI_AFP_PDR_AFP', 'NPDU_UFP', 'File', 'MI_N_effort_PDR_UFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\7-MIMIC-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_pcap', 'MI_loc_time', 'MI_loc_data', 'MI_loc_vexp', 'MI_loc_cplx', 'MI_loc_rely']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\7-MIMIC-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['MI_PointsAdjust_Envergure', 'MI_PointsAdjust_ManagerExp', 'MI_PointsAdjust_Transactions']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\7-MIMIC-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['MI_size_D_t12', 'MI_size_D_dba', 'MI_size_D_t11', 'MI_size_D_t02', 'MI_size_D_har', 'MI_size_D_nlan', 'MI_size_D_ifc', 'MI_size_D_app', 'MI_duration_D_t07', 'MI_size_D_t09', 'MI_size_D_t10', 'MI_size_D_t15', 'MI_size_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao-variaveis\7-MIMIC-75\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\1-tratamento\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['Input', 'Added', 'PDR_UFP', 'NPDR_AFP', 'Effort', 'NPDU_UFP', 'File']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\1-tratamento\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\1-tratamento\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['lexp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\1-tratamento\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao

# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\5-MIMIC-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\5-MIMIC-25\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['stor', 'modp', 'time', 'data', 'lexp', 'MI_loc_stor', 'acap', 'aexp', 'MI_aexp_data', 'MI_loc_aexp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\5-MIMIC-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\5-MIMIC-25\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['PointsAdjust', 'MI_PointsAdjust_Entities']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\5-MIMIC-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\5-MIMIC-25\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['t01', 'MI_size_D_t09', 't13', 'MI_size_D_t11', 't08', 't02', 't06', 't10', 't11', 't15', 'MI_size_D_nlan', 't05', 'MI_size_D_duration_D', 'MI_duration_D_t07', 't09', 't07', 't12', 'MI_size_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\5-MIMIC-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\6-MIMIC-50\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['MI_N_effort_Input', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_NPDU_UFP', 'NPDR_AFP', 'MI_AFP_PDR_AFP', 'NPDU_UFP', 'PDR_UFP', 'MI_N_effort_PDR_UFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\6-MIMIC-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\6-MIMIC-50\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_aexp', 'MI_loc_pcap', 'stor', 'sced', 'modp', 'time', 'MI_loc_time', 'lexp', 'MI_loc_data', 'loc', 'MI_loc_stor', 'acap', 'MI_loc_cplx', 'pcap', 'MI_loc_turn', 'aexp', 'virt']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\6-MIMIC-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\6-MIMIC-50\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['MI_PointsAdjust_Envergure', 'MI_Entities_Language']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\6-MIMIC-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\6-MIMIC-50\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['t01', 't08', 't15', 't05', 't13', 't09', 't12', 'MI_size_D_t07', 't11', 'telonuse', 'MI_size_D_app', 'MI_size_D_t09', 't07', 'MI_size_D_t14', 'MI_size_D_t11', 'MI_size_D_t03', 'MI_size_D_duration_D', 'source', 't04', 'MI_size_D_t08', 't10', 'nlan', 'MI_size_D_nlan', 'MI_duration_D_t07', 'MI_size_D_t10']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\6-MIMIC-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\7-MIMIC-75\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['MI_N_effort_NPDR_AFP', 'MI_N_effort_NPDU_UFP', 'NPDR_AFP', 'MI_AFP_PDR_AFP', 'NPDU_UFP', 'PDR_UFP', 'MI_N_effort_PDR_UFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\7-MIMIC-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\7-MIMIC-75\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_pcap', 'vexp', 'time', 'MI_loc_time', 'tool', 'MI_loc_virt', 'lexp', 'MI_loc_stor', 'MI_loc_acap', 'MI_loc_vexp', 'MI_loc_cplx', 'pcap', 'MI_loc_turn', 'MI_aexp_data', 'MI_loc_aexp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\7-MIMIC-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\7-MIMIC-75\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['MI_PointsAdjust_Language', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Envergure', 'MI_Entities_Language']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\7-MIMIC-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\7-MIMIC-75\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['t06', 't15', 't09', 'MI_size_D_t15', 'MI_size_D_har', 't12', 'MI_size_D_t07', 't14', 't11', 'MI_size_D_app', 'MI_size_D_telonuse', 'MI_size_D_t09', 'MI_size_D_t14', 'MI_size_D_t11', 'MI_size_D_t03', 'MI_size_D_ifc', 'MI_size_D_t12', 'MI_size_D_t08', 'MI_size_D_dba', 't10', 'MI_size_D_nlan', 'MI_duration_D_t07', 'MI_size_D_t10']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\7-MIMIC-75\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao