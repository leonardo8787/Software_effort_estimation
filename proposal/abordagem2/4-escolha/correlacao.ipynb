# %% [markdown]
# # Aplica correlação para excluir variáveis correlacionadas (90%)
#
#
# Aplica correlação na saída de tratamento de variáveis com target encoding.

# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

def calculate_correlation_matrix(data, target_column, correlation_threshold=0.9):
    """
    Calcula a matriz de correlação e identifica variáveis altamente correlacionadas.

    Args:
        data (pd.DataFrame): Dataset contendo as variáveis.
        target_column (str): Nome da coluna alvo.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.

    Returns:
        list: Lista de variáveis a serem removidas.
    """
    correlation_matrix = data.drop(columns=[target_column]).corr()
    columns_to_remove = set()

    for i in range(len(correlation_matrix.columns)):
        for j in range(i):
            if abs(correlation_matrix.iloc[i, j]) > correlation_threshold:
                col_to_remove = correlation_matrix.columns[i]
                columns_to_remove.add(col_to_remove)
    
    return list(columns_to_remove)

def remove_highly_correlated_features(data, target_column, correlation_threshold=0.9):
    """
    Remove variáveis altamente correlacionadas com base em um limite.

    Args:
        data (pd.DataFrame): Dataset original.
        target_column (str): Nome da coluna alvo.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.

    Returns:
        pd.DataFrame: Dataset com variáveis correlacionadas removidas.
    """
    columns_to_remove = calculate_correlation_matrix(data, target_column, correlation_threshold)
    print(f"Variáveis removidas devido à alta correlação: {columns_to_remove}")
    return data.drop(columns=columns_to_remove)

def process_all_datasets(input_root_dir, output_root_dir, correlation_threshold=0.9):
    """
    Processa todos os datasets dentro de um diretório raiz, removendo variáveis correlacionadas e normalizando os dados.

    Args:
        input_root_dir (str): Diretório raiz de entrada contendo subpastas e arquivos.
        output_root_dir (str): Diretório raiz de saída para salvar os arquivos processados.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.
    """
    excluded_path = os.path.join(input_root_dir, "4-escolha")
    
    for root, dirs, files in os.walk(input_root_dir):
        # Pular o diretório excluído
        if excluded_path in root:
            continue
        
        for filename in files:
            if filename.endswith(".txt"):
                input_path = os.path.join(root, filename)
                
                # Recria a estrutura de subpastas na saída
                relative_path = os.path.relpath(input_path, input_root_dir)
                output_path = os.path.join(output_root_dir, relative_path)

                # Cria a pasta de saída, se necessário
                os.makedirs(os.path.dirname(output_path), exist_ok=True)

                print(f"Processando arquivo: {input_path}")
                try:
                    data = pd.read_csv(input_path, delimiter=",", skipinitialspace=True)
                    target_column = data.columns[-1]

                    # Remover variáveis altamente correlacionadas
                    data_cleaned = remove_highly_correlated_features(data, target_column, correlation_threshold)

                    # Reorganizar as colunas para manter a coluna alvo no final
                    columns = [col for col in data_cleaned.columns if col != target_column] + [target_column]
                    data_cleaned = data_cleaned[columns]

                    # Normalizar os dados para o intervalo [0, 1]
                    scaler = MinMaxScaler(feature_range=(0, 1))
                    data_scaled = pd.DataFrame(
                        scaler.fit_transform(data_cleaned),
                        columns=data_cleaned.columns
                    )

                    # Salvar o arquivo normalizado
                    data_scaled.to_csv(output_path, sep=",", index=False)
                    print(f"Arquivo processado e salvo em: {output_path}")

                except Exception as e:
                    print(f"Erro ao processar {filename}: {e}")

# Diretórios de entrada e saída
input_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado"
output_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\1-tratamento"

# Processar arquivos removendo variáveis correlacionadas
process_all_datasets(input_directory, output_directory, correlation_threshold=0.9)
# Out:
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['PDR_UFP', 'Input', 'Added', 'File', 'NPDU_UFP', 'NPDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\1-tratamento\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: []
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\1-tratamento\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: []
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\1-tratamento\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: []
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\1-tratamento\tratamento_maxwell.txt

# %% [markdown]
# # Aplica correlação em todas as pastas em "2-geracao-variaveis"

# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

def calculate_correlation_matrix(data, target_column, correlation_threshold=0.9):
    """
    Calcula a matriz de correlação e identifica variáveis altamente correlacionadas.

    Args:
        data (pd.DataFrame): Dataset contendo as variáveis.
        target_column (str): Nome da coluna alvo.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.

    Returns:
        list: Lista de variáveis a serem removidas.
    """
    correlation_matrix = data.drop(columns=[target_column]).corr()
    columns_to_remove = set()

    for i in range(len(correlation_matrix.columns)):
        for j in range(i):
            if abs(correlation_matrix.iloc[i, j]) > correlation_threshold:
                col_to_remove = correlation_matrix.columns[i]
                columns_to_remove.add(col_to_remove)
    
    return list(columns_to_remove)

def remove_highly_correlated_features(data, target_column, correlation_threshold=0.9):
    """
    Remove variáveis altamente correlacionadas com base em um limite.

    Args:
        data (pd.DataFrame): Dataset original.
        target_column (str): Nome da coluna alvo.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.

    Returns:
        pd.DataFrame: Dataset com variáveis correlacionadas removidas.
    """
    columns_to_remove = calculate_correlation_matrix(data, target_column, correlation_threshold)
    print(f"Variáveis removidas devido à alta correlação: {columns_to_remove}")
    return data.drop(columns=columns_to_remove)

def process_all_datasets(input_root_dir, output_root_dir, correlation_threshold=0.9):
    """
    Processa todos os datasets dentro de um diretório raiz, removendo variáveis correlacionadas e normalizando os dados.

    Args:
        input_root_dir (str): Diretório raiz de entrada contendo subpastas e arquivos.
        output_root_dir (str): Diretório raiz de saída para salvar os arquivos processados.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.
    """
    excluded_path = os.path.join(input_root_dir, "4-escolha")
    
    for root, dirs, files in os.walk(input_root_dir):
        # Pular o diretório excluído
        if excluded_path in root:
            continue
        
        for filename in files:
            if filename.endswith(".txt"):
                input_path = os.path.join(root, filename)
                
                # Recria a estrutura de subpastas na saída
                relative_path = os.path.relpath(input_path, input_root_dir)
                output_path = os.path.join(output_root_dir, relative_path)

                # Cria a pasta de saída, se necessário
                os.makedirs(os.path.dirname(output_path), exist_ok=True)

                print(f"Processando arquivo: {input_path}")
                try:
                    data = pd.read_csv(input_path, delimiter=",", skipinitialspace=True)
                    target_column = data.columns[-1]

                    # Remover variáveis altamente correlacionadas
                    data_cleaned = remove_highly_correlated_features(data, target_column, correlation_threshold)

                    # Reorganizar as colunas para manter a coluna alvo no final
                    columns = [col for col in data_cleaned.columns if col != target_column] + [target_column]
                    data_cleaned = data_cleaned[columns]

                    # Normalizar os dados para o intervalo [0, 1]
                    scaler = MinMaxScaler(feature_range=(0, 1))
                    data_scaled = pd.DataFrame(
                        scaler.fit_transform(data_cleaned),
                        columns=data_cleaned.columns
                    )

                    # Salvar o arquivo normalizado
                    data_scaled.to_csv(output_path, sep=",", index=False)
                    print(f"Arquivo processado e salvo em: {output_path}")

                except Exception as e:
                    print(f"Erro ao processar {filename}: {e}")

# Diretórios de entrada e saída
input_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis"
output_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao"

# Processar arquivos removendo variáveis correlacionadas
process_all_datasets(input_directory, output_directory, correlation_threshold=0.9)
# Out:
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\GAN-25\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['PDR_UFP', 'Input', 'Added', 'File', 'NPDU_UFP', 'NPDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\GAN-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\GAN-25\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_3', 'Generated_Var_2', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\GAN-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\GAN-25\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: []
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\GAN-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\GAN-25\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_3', 'Generated_Var_2', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\GAN-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\GAN-50\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['PDR_UFP', 'Input', 'Added', 'Generated_Var_7', 'File', 'Generated_Var_2', 'NPDU_UFP', 'Generated_Var_4', 'Generated_Var_9', 'Generated_Var_6', 'NPDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\GAN-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\GAN-50\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_7', 'Generated_Var_5', 'Generated_Var_2', 'Generated_Var_8', 'Generated_Var_3', 'Generated_Var_6']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\GAN-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\GAN-50\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_3', 'Generated_Var_2']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\GAN-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\GAN-50\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_10', 'Generated_Var_7', 'Generated_Var_5', 'Generated_Var_2', 'Generated_Var_8', 'Generated_Var_11', 'Generated_Var_4', 'Generated_Var_9', 'Generated_Var_12', 'Generated_Var_3', 'Generated_Var_6']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\GAN-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\GAN-75\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_14', 'PDR_UFP', 'Input', 'Added', 'Generated_Var_7', 'File', 'Generated_Var_5', 'Generated_Var_8', 'Generated_Var_10', 'NPDU_UFP', 'Generated_Var_4', 'Generated_Var_11', 'Generated_Var_9', 'Generated_Var_12', 'Generated_Var_13', 'Generated_Var_6', 'Generated_Var_3', 'NPDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\GAN-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\GAN-75\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_10', 'Generated_Var_5', 'Generated_Var_8', 'Generated_Var_2', 'Generated_Var_11', 'Generated_Var_9', 'Generated_Var_12', 'Generated_Var_6']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\GAN-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\GAN-75\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_3', 'Generated_Var_5', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\GAN-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\GAN-75\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_14', 'Generated_Var_10', 'Generated_Var_15', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_5', 'Generated_Var_4', 'Generated_Var_9', 'Generated_Var_12', 'Generated_Var_13', 'Generated_Var_18', 'Generated_Var_16', 'Generated_Var_6', 'Generated_Var_17']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\GAN-75\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\MIMIC-25\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['PDR_UFP', 'Input', 'Added', 'File', 'NPDU_UFP', 'MI_N_effort_Added', 'MI_AFP_PDR_AFP', 'MI_N_effort_AFP', 'NPDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\MIMIC-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\MIMIC-25\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_data']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\MIMIC-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\MIMIC-25\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: []
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\MIMIC-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\MIMIC-25\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['MI_size_D_t09', 'MI_size_D_t07', 'MI_duration_D_t07', 'MI_size_D_t11', 'MI_size_D_nlan']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\MIMIC-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\MIMIC-50\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['PDR_UFP', 'Input', 'Added', 'File', 'NPDU_UFP', 'MI_N_effort_Input', 'MI_N_effort_Added', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_PDR_UFP', 'MI_AFP_PDR_AFP', 'MI_N_effort_AFP', 'NPDR_AFP', 'MI_N_effort_NPDU_UFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\MIMIC-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\MIMIC-50\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_time', 'MI_loc_data', 'MI_loc_pcap', 'MI_loc_cplx']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\MIMIC-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\MIMIC-50\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['MI_PointsAdjust_Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\MIMIC-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\MIMIC-50\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['MI_size_D_t09', 'MI_size_D_t07', 'MI_size_D_t10', 'MI_size_D_app', 'MI_size_D_t02', 'MI_duration_D_t07', 'MI_size_D_t11', 'MI_size_D_nlan']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\MIMIC-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\MIMIC-75\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['PDR_UFP', 'Input', 'Added', 'File', 'NPDU_UFP', 'MI_N_effort_Input', 'MI_N_effort_Added', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_PDR_UFP', 'MI_AFP_PDR_AFP', 'MI_N_effort_File', 'MI_N_effort_AFP', 'NPDR_AFP', 'MI_N_effort_NPDU_UFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\MIMIC-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\MIMIC-75\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_rely', 'MI_loc_cplx', 'MI_loc_data', 'MI_loc_vexp', 'MI_loc_time', 'MI_loc_pcap']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\MIMIC-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\MIMIC-75\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_ManagerExp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\MIMIC-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\MIMIC-75\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['MI_size_D_ifc', 'MI_size_D_t09', 'MI_size_D_t12', 'MI_size_D_t07', 'MI_size_D_t10', 'MI_size_D_app', 'MI_size_D_t02', 'MI_size_D_dba', 'MI_size_D_t15', 'MI_duration_D_t07', 'MI_size_D_har', 'MI_size_D_t11', 'MI_size_D_nlan']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\2-geracao\MIMIC-75\tratamento_maxwell.txt

# %% [markdown]
# # Aplica a correlação na simulação

# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

def calculate_correlation_matrix(data, target_column, correlation_threshold=0.9):
    """
    Calcula a matriz de correlação e identifica variáveis altamente correlacionadas.

    Args:
        data (pd.DataFrame): Dataset contendo as variáveis.
        target_column (str): Nome da coluna alvo.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.

    Returns:
        list: Lista de variáveis a serem removidas.
    """
    correlation_matrix = data.drop(columns=[target_column]).corr()
    columns_to_remove = set()

    for i in range(len(correlation_matrix.columns)):
        for j in range(i):
            if abs(correlation_matrix.iloc[i, j]) > correlation_threshold:
                col_to_remove = correlation_matrix.columns[i]
                columns_to_remove.add(col_to_remove)
    
    return list(columns_to_remove)

def remove_highly_correlated_features(data, target_column, correlation_threshold=0.9):
    """
    Remove variáveis altamente correlacionadas com base em um limite.

    Args:
        data (pd.DataFrame): Dataset original.
        target_column (str): Nome da coluna alvo.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.

    Returns:
        pd.DataFrame: Dataset com variáveis correlacionadas removidas.
    """
    columns_to_remove = calculate_correlation_matrix(data, target_column, correlation_threshold)
    print(f"Variáveis removidas devido à alta correlação: {columns_to_remove}")
    return data.drop(columns=columns_to_remove)

def process_all_datasets(input_root_dir, output_root_dir, correlation_threshold=0.9):
    """
    Processa todos os datasets dentro de um diretório raiz, removendo variáveis correlacionadas e normalizando os dados.

    Args:
        input_root_dir (str): Diretório raiz de entrada contendo subpastas e arquivos.
        output_root_dir (str): Diretório raiz de saída para salvar os arquivos processados.
        correlation_threshold (float): Limite de correlação para exclusão de variáveis.
    """
    excluded_path = os.path.join(input_root_dir, "4-escolha")
    
    for root, dirs, files in os.walk(input_root_dir):
        # Pular o diretório excluído
        if excluded_path in root:
            continue
        
        for filename in files:
            if filename.endswith(".txt"):
                input_path = os.path.join(root, filename)
                
                # Recria a estrutura de subpastas na saída
                relative_path = os.path.relpath(input_path, input_root_dir)
                output_path = os.path.join(output_root_dir, relative_path)

                # Cria a pasta de saída, se necessário
                os.makedirs(os.path.dirname(output_path), exist_ok=True)

                print(f"Processando arquivo: {input_path}")
                try:
                    data = pd.read_csv(input_path, delimiter=",", skipinitialspace=True)
                    target_column = data.columns[-1]

                    # Remover variáveis altamente correlacionadas
                    data_cleaned = remove_highly_correlated_features(data, target_column, correlation_threshold)

                    # Reorganizar as colunas para manter a coluna alvo no final
                    columns = [col for col in data_cleaned.columns if col != target_column] + [target_column]
                    data_cleaned = data_cleaned[columns]

                    # Normalizar os dados para o intervalo [0, 1]
                    scaler = MinMaxScaler(feature_range=(0, 1))
                    data_scaled = pd.DataFrame(
                        scaler.fit_transform(data_cleaned),
                        columns=data_cleaned.columns
                    )

                    # Salvar o arquivo normalizado
                    data_scaled.to_csv(output_path, sep=",", index=False)
                    print(f"Arquivo processado e salvo em: {output_path}")

                except Exception as e:
                    print(f"Erro ao processar {filename}: {e}")

# Diretórios de entrada e saída
input_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao"
output_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao"

# Processar arquivos removendo variáveis correlacionadas e normalizando
process_all_datasets(input_directory, output_directory, correlation_threshold=0.9)
# Out:
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\1-tratamento\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['NPDR_AFP', 'PDR_UFP', 'NPDU_UFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\1-tratamento\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\1-tratamento\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['sced', 'loc', 'stor', 'vexp', 'cplx', 'aexp', 'tool', 'turn', 'time', 'lexp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\1-tratamento\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\1-tratamento\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['PointsAdjust']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\1-tratamento\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\1-tratamento\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['app', 't04', 't12', 't10', 'source', 't15', 't09', 't07', 't01', 't08', 't11']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\1-tratamento\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\GAN-25\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['NPDR_AFP', 'PDR_UFP', 'NPDU_UFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\GAN-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\GAN-25\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['sced', 'loc', 'Generated_Var_4', 'turn', 'stor', 'Generated_Var_1', 'acap', 'pcap', 'cplx', 'vexp', 'Generated_Var_3', 'Generated_Var_2', 'aexp', 'virt', 'time', 'lexp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\GAN-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\GAN-25\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: []
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\GAN-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\GAN-25\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['t03', 'telonuse', 'Generated_Var_6', 'ifc', 'har', 't11', 't04', 't12', 't10', 'source', 'Generated_Var_5', 'Generated_Var_1', 't06', 'Generated_Var_3', 'Generated_Var_2', 't07', 't13', 'Generated_Var_4', 't05', 't15', 't09', 't14', 't01', 'dba']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\GAN-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\GAN-50\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_8', 'Generated_Var_9', 'NPDR_AFP', 'Generated_Var_2', 'NPDU_UFP', 'Generated_Var_7', 'PDR_UFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\GAN-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\GAN-50\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['stor', 'Generated_Var_6', 'tool', 'Generated_Var_8', 'pcap', 'lexp', 'loc', 'Generated_Var_1', 'vexp', 'Generated_Var_3', 'Generated_Var_2', 'virt', 'modp', 'acap', 'cplx', 'data', 'aexp', 'Generated_Var_7', 'time']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\GAN-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\GAN-50\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_3', 'PointsAdjust', 'Generated_Var_2']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\GAN-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\GAN-50\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_9', 't03', 'Generated_Var_6', 't11', 'Generated_Var_8', 't04', 't12', 't10', 'Generated_Var_10', 'source', 'Generated_Var_5', 'Generated_Var_3', 'Generated_Var_2', 'Generated_Var_11', 't07', 't08', 't13', 'duration_D', 'Generated_Var_4', 't05', 'Generated_Var_12', 't15', 't09', 'Generated_Var_7', 't14', 't01']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\GAN-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\GAN-75\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['NPDR_AFP', 'Output', 'Input', 'NPDU_UFP', 'PDR_UFP', 'Added']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\GAN-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\GAN-75\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_8', 'Generated_Var_9', 'Generated_Var_5', 'loc', 'turn', 'pcap', 'Generated_Var_10', 'modp', 'Generated_Var_3', 'Generated_Var_6', 'Generated_Var_2', 'tool', 'Generated_Var_11', 'Generated_Var_12', 'virt', 'time', 'Generated_Var_7', 'lexp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\GAN-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\GAN-75\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_3', 'PointsAdjust', 'Generated_Var_5', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\GAN-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\GAN-75\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['Generated_Var_9', 't03', 'Generated_Var_6', 'ifc', 'Generated_Var_14', 't11', 'Generated_Var_8', 't04', 'nlan', 't12', 'Generated_Var_13', 't10', 'Generated_Var_18', 'Generated_Var_10', 'Generated_Var_16', 't02', 'Generated_Var_1', 't06', 'Generated_Var_3', 'Generated_Var_2', 'Generated_Var_11', 't07', 't13', 'duration_D', 'Generated_Var_4', 'app', 't05', 'Generated_Var_17', 'Generated_Var_12', 't15', 't09', 'Generated_Var_7', 't14', 'Generated_Var_15']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\GAN-75\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\MIMIC-25\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['MI_AFP_PDR_AFP', 'NPDR_AFP', 'PDR_UFP', 'NPDU_UFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\MIMIC-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\MIMIC-25\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['sced', 'MI_loc_aexp', 'stor', 'acap', 'pcap', 'cplx', 'modp', 'MI_aexp_data', 'aexp', 'time', 'tool']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\MIMIC-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\MIMIC-25\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['PointsAdjust', 'MI_PointsAdjust_Entities']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\MIMIC-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\MIMIC-25\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['duration_D', 't03', 'ifc', 't04', 't12', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_duration_D_t07', 'MI_size_D_t07', 'MI_size_D_t11', 'telonuse', 't15', 't09', 't02', 't07', 't06', 'har', 't11']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\MIMIC-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\MIMIC-50\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['MI_AFP_PDR_AFP', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_NPDU_UFP', 'NPDR_AFP', 'MI_N_effort_PDR_UFP', 'NPDU_UFP', 'PDR_UFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\MIMIC-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\MIMIC-50\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_aexp', 'vexp', 'MI_loc_turn', 'modp', 'MI_aexp_data', 'MI_loc_stor', 'aexp', 'tool', 'MI_loc_pcap', 'virt', 'time', 'MI_loc_data', 'lexp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\MIMIC-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\MIMIC-50\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['MI_PointsAdjust_Envergure', 'MI_Entities_Language']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\MIMIC-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\MIMIC-50\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['MI_size_D_t07', 'telonuse', 'MI_size_D_t08', 'ifc', 't04', 't12', 'MI_size_D_t09', 'MI_size_D_nlan', 'MI_size_D_t02', 't10', 'source', 'MI_size_D_t10', 'MI_size_D_duration_D', 't07', 't08', 'MI_size_D_t03', 'MI_size_D_app', 't15', 't09', 't14', 't01']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\MIMIC-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\MIMIC-75\tratamento_china.txt
# Variáveis removidas devido à alta correlação: ['MI_AFP_PDR_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_Duration', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_NPDU_UFP', 'NPDR_AFP', 'MI_N_effort_Input', 'MI_N_effort_PDR_UFP', 'NPDU_UFP', 'PDR_UFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\MIMIC-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\MIMIC-75\tratamento_cocomo81.txt
# Variáveis removidas devido à alta correlação: ['MI_loc_acap', 'vexp', 'pcap', 'modp', 'tool', 'MI_loc_pcap', 'virt', 'time', 'MI_loc_data', 'lexp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\MIMIC-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\MIMIC-75\tratamento_desharnais.txt
# Variáveis removidas devido à alta correlação: ['MI_PointsAdjust_Envergure', 'MI_PointsAdjust_ManagerExp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\MIMIC-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\MIMIC-75\tratamento_maxwell.txt
# Variáveis removidas devido à alta correlação: ['MI_size_D_t07', 'MI_size_D_t08', 'MI_size_D_t14', 't04', 'nlan', 't12', 'MI_size_D_t09', 'MI_size_D_nlan', 't10', 'MI_size_D_t02', 'source', 't02', 'MI_size_D_t15', 'MI_size_D_t10', 'MI_size_D_dba', 'MI_duration_D_t07', 'MI_size_D_duration_D', 'MI_size_D_telonuse', 'MI_size_D_har', 't08', 't13', 'MI_size_D_t12', 't05', 'MI_size_D_t03', 'MI_size_D_t11', 'MI_size_D_app', 't15', 't09', 'MI_size_D_ifc']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\correlacao\3-simulacao\MIMIC-75\tratamento_maxwell.txt
