# %% [markdown]
# # 25

# %%
import os
import pandas as pd
import math
from sklearn.feature_selection import SelectKBest, f_classif, f_regression
from sklearn.preprocessing import LabelEncoder


def apply_selectkbest(data, target_column, k):
    """
    Aplica SelectKBest para selecionar as melhores variáveis em relação à coluna alvo.

    Args:
        data (pd.DataFrame): Dataset original.
        target_column (str): Nome da coluna alvo.
        k (float or int): Porcentagem (0-1) ou número de variáveis a selecionar.

    Returns:
        pd.DataFrame: Dataset com as variáveis selecionadas e a coluna alvo.
    """
    # Se a coluna alvo for categórica, usa f_classif; caso contrário, usa f_regression
    if data[target_column].dtype == 'object':
        data[target_column] = LabelEncoder().fit_transform(data[target_column])
        score_func = f_classif
    else:
        score_func = f_regression

    # Separar variáveis independentes e dependente
    X = data.drop(columns=[target_column])
    y = data[target_column]

    # Calcular o valor de k com base na porcentagem
    if isinstance(k, float) and 0 < k <= 1:
        k = max(1, math.floor(k * X.shape[1]))

    print(f"Selecionando as top {k} variáveis...")

    # Aplicar SelectKBest
    selector = SelectKBest(score_func=score_func, k=k)
    X_new = selector.fit_transform(X, y)

    # Identificar colunas selecionadas
    selected_columns = X.columns[selector.get_support()]

    print(f"Variáveis selecionadas: {list(selected_columns)}")

    # Reconstruir o DataFrame com as variáveis selecionadas e a coluna alvo
    new_data = pd.DataFrame(X_new, columns=selected_columns)
    new_data[target_column] = y.values

    return new_data


def process_all_subfolders(input_root, output_root, k):
    """
    Processa todas as subpastas do diretório de entrada, aplica SelectKBest nos arquivos
    e salva a saída na estrutura correspondente do diretório de saída.

    Args:
        input_root (str): Caminho do diretório raiz de entrada.
        output_root (str): Caminho do diretório raiz de saída.
        k (float or int): Porcentagem ou número de variáveis a serem selecionadas.
    """
    excluded_dir = os.path.join(input_root, "4-escolha")

    for subdir, _, files in os.walk(input_root):
        # Ignorar o diretório excluído
        if excluded_dir in subdir:
            continue

        # Mantém a mesma estrutura de subpastas
        relative_path = os.path.relpath(subdir, input_root)
        output_subdir = os.path.join(output_root, relative_path)
        os.makedirs(output_subdir, exist_ok=True)

        for filename in files:
            if filename.endswith(".txt"):
                input_path = os.path.join(subdir, filename)
                output_path = os.path.join(output_subdir, filename)

                print(f"Processando arquivo: {input_path}")
                try:
                    data = pd.read_csv(input_path, delimiter=",", skipinitialspace=True)
                    target_column = data.columns[-1]  # Assume que a última coluna é a coluna alvo

                    # Aplicar SelectKBest
                    new_data = apply_selectkbest(data, target_column, k)

                    # Salvar o novo dataset
                    new_data.to_csv(output_path, sep=",", index=False)
                    print(f"Arquivo processado e salvo em: {output_path}")
                except Exception as e:
                    print(f"Erro ao processar {filename}: {e}")


# Diretórios de entrada e saída
input_root_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida"
output_root_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25"

# Aplicar SelectKBest nos arquivos
top_percentage = 0.25  # 25% das variáveis
process_all_subfolders(input_root_directory, output_root_directory, k=top_percentage)
# Out:
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_china.txt
# Selecionando as top 4 variáveis...
# Variáveis selecionadas: ['AFP', 'File', 'Added', 'N_effort']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\1-tratamento-target-encoding-normalizado\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_cocomo81.txt
# Selecionando as top 4 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'modp', 'loc']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\1-tratamento-target-encoding-normalizado\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_desharnais.txt
# Selecionando as top 2 variáveis...
# Variáveis selecionadas: ['Transactions', 'PointsAdjust']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\1-tratamento-target-encoding-normalizado\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_maxwell.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't07', 't11', 't14']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\1-tratamento-target-encoding-normalizado\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\2-GAN-25\tratamento_china.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'File', 'Added', 'N_effort']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\2-GAN-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\2-GAN-25\tratamento_cocomo81.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['data', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\2-GAN-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\2-GAN-25\tratamento_desharnais.txt
# Selecionando as top 2 variáveis...
# Variáveis selecionadas: ['Transactions', 'PointsAdjust']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\2-GAN-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\2-GAN-25\tratamento_maxwell.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't07', 't11', 't14', 'Generated_Var_2']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\2-GAN-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\3-GAN-50\tratamento_china.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'File', 'Added', 'N_effort']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\3-GAN-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\3-GAN-50\tratamento_cocomo81.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['data', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_7']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\3-GAN-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\3-GAN-50\tratamento_desharnais.txt
# Selecionando as top 3 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\3-GAN-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\3-GAN-50\tratamento_maxwell.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_4', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_11']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\3-GAN-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\4-GAN-75\tratamento_china.txt
# Selecionando as top 8 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Added', 'Duration', 'N_effort']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\4-GAN-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\4-GAN-75\tratamento_cocomo81.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['data', 'loc', 'Generated_Var_2', 'Generated_Var_6', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_12']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\4-GAN-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\4-GAN-75\tratamento_desharnais.txt
# Selecionando as top 3 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\4-GAN-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\4-GAN-75\tratamento_maxwell.txt
# Selecionando as top 10 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_14', 'Generated_Var_17']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\4-GAN-75\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_china.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['AFP', 'Added', 'N_effort', 'MI_N_effort_PDR_AFP', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\5-MIMIC-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_cocomo81.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['data', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\5-MIMIC-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_desharnais.txt
# Selecionando as top 2 variáveis...
# Variáveis selecionadas: ['PointsAdjust', 'MI_PointsAdjust_Entities']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\5-MIMIC-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_maxwell.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['size_D', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\5-MIMIC-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_china.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['AFP', 'Added', 'N_effort', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Enquiry', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\6-MIMIC-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_cocomo81.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\6-MIMIC-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_desharnais.txt
# Selecionando as top 3 variáveis...
# Variáveis selecionadas: ['PointsAdjust', 'MI_PointsAdjust_Language', 'MI_PointsAdjust_Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\6-MIMIC-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_maxwell.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['size_D', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_size_D_t08', 'MI_size_D_t10', 'MI_size_D_app']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\6-MIMIC-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_china.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['Added', 'N_effort', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Enquiry', 'MI_N_effort_Duration', 'MI_N_effort_Output', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\7-MIMIC-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_cocomo81.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn', 'MI_loc_rely', 'MI_loc_vexp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\7-MIMIC-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_desharnais.txt
# Selecionando as top 3 variáveis...
# Variáveis selecionadas: ['PointsAdjust', 'MI_PointsAdjust_Language', 'MI_PointsAdjust_Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\7-MIMIC-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_maxwell.txt
# Selecionando as top 10 variáveis...
# Variáveis selecionadas: ['size_D', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t08', 'MI_size_D_t10', 'MI_size_D_app', 'MI_size_D_t15', 'MI_size_D_ifc', 'MI_size_D_dba']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\2-geracao-variaveis\7-MIMIC-75\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\1-tratamento\tratamento_china.txt
# Selecionando as top 4 variáveis...
# Variáveis selecionadas: ['PDR_AFP', 'NPDR_AFP', 'Duration', 'Effort']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\1-tratamento\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\1-tratamento\tratamento_cocomo81.txt
# Selecionando as top 4 variáveis...
# Variáveis selecionadas: ['rely', 'stor', 'acap', 'actual']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\1-tratamento\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\1-tratamento\tratamento_desharnais.txt
# Selecionando as top 2 variáveis...
# Variáveis selecionadas: ['Entities', 'PointsAdjust']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\1-tratamento\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\1-tratamento\tratamento_maxwell.txt
# Selecionando as top 5 variáveis...
# Erro ao processar tratamento_maxwell.txt: could not convert string to float: 'original'
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\2-GAN-25\tratamento_china.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Enquiry', 'Added', 'N_effort']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\2-GAN-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\2-GAN-25\tratamento_cocomo81.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['data', 'time', 'stor', 'Generated_Var_1', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\2-GAN-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\2-GAN-25\tratamento_desharnais.txt
# Selecionando as top 2 variáveis...
# Variáveis selecionadas: ['PointsAdjust', 'Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\2-GAN-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\2-GAN-25\tratamento_maxwell.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['size_D', 'nlan', 't07', 't09', 't10', 't12', 't15']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\2-GAN-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\3-GAN-50\tratamento_china.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Enquiry', 'File', 'Added', 'N_effort']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\3-GAN-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\3-GAN-50\tratamento_cocomo81.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'cplx', 'turn', 'Generated_Var_2', 'Generated_Var_7']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\3-GAN-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\3-GAN-50\tratamento_desharnais.txt
# Selecionando as top 3 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\3-GAN-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\3-GAN-50\tratamento_maxwell.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['duration_D', 'app', 'har', 'source', 't08', 't11', 'Generated_Var_4', 'Generated_Var_6', 'Generated_Var_9']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\3-GAN-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\4-GAN-75\tratamento_china.txt
# Selecionando as top 8 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'Added', 'PDR_UFP', 'Dev.Type', 'N_effort']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\4-GAN-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\4-GAN-75\tratamento_cocomo81.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['turn', 'aexp', 'modp', 'loc', 'Generated_Var_5', 'Generated_Var_7', 'Generated_Var_9']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\4-GAN-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\4-GAN-75\tratamento_desharnais.txt
# Selecionando as top 3 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\4-GAN-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\4-GAN-75\tratamento_maxwell.txt
# Selecionando as top 10 variáveis...
# Variáveis selecionadas: ['size_D', 't04', 't07', 'Generated_Var_3', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_13', 'Generated_Var_14']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\4-GAN-75\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\5-MIMIC-25\tratamento_china.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['AFP', 'N_effort', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\5-MIMIC-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\5-MIMIC-25\tratamento_cocomo81.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['time', 'stor', 'MI_loc_aexp', 'MI_loc_stor', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\5-MIMIC-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\5-MIMIC-25\tratamento_desharnais.txt
# Selecionando as top 2 variáveis...
# Variáveis selecionadas: ['PointsAdjust', 'MI_PointsAdjust_Entities']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\5-MIMIC-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\5-MIMIC-25\tratamento_maxwell.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['har', 't03', 't07', 't10', 't12', 't15', 'MI_size_D_t11']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\5-MIMIC-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\6-MIMIC-50\tratamento_china.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['N_effort', 'MI_N_effort_PDR_AFP', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Input', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\6-MIMIC-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\6-MIMIC-50\tratamento_cocomo81.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['pcap', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\6-MIMIC-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\6-MIMIC-50\tratamento_desharnais.txt
# Selecionando as top 3 variáveis...
# Variáveis selecionadas: ['PointsAdjust', 'MI_PointsAdjust_Language', 'MI_PointsAdjust_Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\6-MIMIC-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\6-MIMIC-50\tratamento_maxwell.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['nlan', 't11', 't13', 't15', 'MI_size_D_duration_D', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_size_D_app']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\6-MIMIC-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\7-MIMIC-75\tratamento_china.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['N_effort', 'MI_N_effort_PDR_AFP', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_PDR_UFP', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_Duration', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\7-MIMIC-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\7-MIMIC-75\tratamento_cocomo81.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['rely', 'time', 'vexp', 'lexp', 'MI_loc_aexp', 'MI_loc_stor', 'MI_loc_time']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\7-MIMIC-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\7-MIMIC-75\tratamento_desharnais.txt
# Selecionando as top 3 variáveis...
# Variáveis selecionadas: ['PointsAdjust', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_ManagerExp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\7-MIMIC-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\7-MIMIC-75\tratamento_maxwell.txt
# Selecionando as top 10 variáveis...
# Variáveis selecionadas: ['har', 'nlan', 't09', 't10', 't11', 'MI_size_D_t09', 'MI_size_D_t03', 'MI_size_D_app', 'MI_size_D_telonuse', 'MI_size_D_ifc']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\25\3-simulacao\7-MIMIC-75\tratamento_maxwell.txt

# %% [markdown]
# # 50

# %%
import os
import pandas as pd
import math
from sklearn.feature_selection import SelectKBest, f_classif, f_regression
from sklearn.preprocessing import LabelEncoder


def apply_selectkbest(data, target_column, k):
    """
    Aplica SelectKBest para selecionar as melhores variáveis em relação à coluna alvo.

    Args:
        data (pd.DataFrame): Dataset original.
        target_column (str): Nome da coluna alvo.
        k (float or int): Porcentagem (0-1) ou número de variáveis a selecionar.

    Returns:
        pd.DataFrame: Dataset com as variáveis selecionadas e a coluna alvo.
    """
    # Se a coluna alvo for categórica, usa f_classif; caso contrário, usa f_regression
    if data[target_column].dtype == 'object':
        data[target_column] = LabelEncoder().fit_transform(data[target_column])
        score_func = f_classif
    else:
        score_func = f_regression

    # Separar variáveis independentes e dependente
    X = data.drop(columns=[target_column])
    y = data[target_column]

    # Calcular o valor de k com base na porcentagem
    if isinstance(k, float) and 0 < k <= 1:
        k = max(1, math.floor(k * X.shape[1]))

    print(f"Selecionando as top {k} variáveis...")

    # Aplicar SelectKBest
    selector = SelectKBest(score_func=score_func, k=k)
    X_new = selector.fit_transform(X, y)

    # Identificar colunas selecionadas
    selected_columns = X.columns[selector.get_support()]

    print(f"Variáveis selecionadas: {list(selected_columns)}")

    # Reconstruir o DataFrame com as variáveis selecionadas e a coluna alvo
    new_data = pd.DataFrame(X_new, columns=selected_columns)
    new_data[target_column] = y.values

    return new_data


def process_all_subfolders(input_root, output_root, k):
    """
    Processa todas as subpastas do diretório de entrada, aplica SelectKBest nos arquivos
    e salva a saída na estrutura correspondente do diretório de saída.

    Args:
        input_root (str): Caminho do diretório raiz de entrada.
        output_root (str): Caminho do diretório raiz de saída.
        k (float or int): Porcentagem ou número de variáveis a serem selecionadas.
    """
    excluded_dir = os.path.join(input_root, "4-escolha")

    for subdir, _, files in os.walk(input_root):
        # Ignorar o diretório excluído
        if excluded_dir in subdir:
            continue

        # Mantém a mesma estrutura de subpastas
        relative_path = os.path.relpath(subdir, input_root)
        output_subdir = os.path.join(output_root, relative_path)
        os.makedirs(output_subdir, exist_ok=True)

        for filename in files:
            if filename.endswith(".txt"):
                input_path = os.path.join(subdir, filename)
                output_path = os.path.join(output_subdir, filename)

                print(f"Processando arquivo: {input_path}")
                try:
                    data = pd.read_csv(input_path, delimiter=",", skipinitialspace=True)
                    target_column = data.columns[-1]  # Assume que a última coluna é a coluna alvo

                    # Aplicar SelectKBest
                    new_data = apply_selectkbest(data, target_column, k)

                    # Salvar o novo dataset
                    new_data.to_csv(output_path, sep=",", index=False)
                    print(f"Arquivo processado e salvo em: {output_path}")
                except Exception as e:
                    print(f"Erro ao processar {filename}: {e}")


# Diretórios de entrada e saída
input_root_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida"
output_root_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50"

# Aplicar SelectKBest nos arquivos
top_percentage = 0.50  # 50% das variáveis
process_all_subfolders(input_root_directory, output_root_directory, k=top_percentage)
# Out:
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_china.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'Duration', 'N_effort']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\1-tratamento-target-encoding-normalizado\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_cocomo81.txt
# Selecionando as top 8 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'turn', 'acap', 'pcap', 'modp', 'loc']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\1-tratamento-target-encoding-normalizado\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_desharnais.txt
# Selecionando as top 4 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\1-tratamento-target-encoding-normalizado\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\1-tratamento-target-encoding-normalizado\tratamento_maxwell.txt
# Selecionando as top 12 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'app', 'har', 'nlan', 't07', 't08', 't09', 't10', 't11', 't14', 't15']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\1-tratamento-target-encoding-normalizado\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\2-GAN-25\tratamento_china.txt
# Selecionando as top 11 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_UFP', 'Duration', 'N_effort', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\2-GAN-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\2-GAN-25\tratamento_cocomo81.txt
# Selecionando as top 10 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'turn', 'pcap', 'modp', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\2-GAN-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\2-GAN-25\tratamento_desharnais.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['TeamExp', 'Transactions', 'Entities', 'PointsAdjust', 'Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\2-GAN-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\2-GAN-25\tratamento_maxwell.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'app', 'har', 'nlan', 't07', 't08', 't09', 't10', 't11', 't14', 't15', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\2-GAN-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\3-GAN-50\tratamento_china.txt
# Selecionando as top 13 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'Duration', 'N_effort', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_4', 'Generated_Var_6']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\3-GAN-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\3-GAN-50\tratamento_cocomo81.txt
# Selecionando as top 12 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'modp', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\3-GAN-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\3-GAN-50\tratamento_desharnais.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['TeamExp', 'Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'Generated_Var_1']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\3-GAN-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\3-GAN-50\tratamento_maxwell.txt
# Selecionando as top 18 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'app', 'nlan', 't07', 't11', 't14', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\3-GAN-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\4-GAN-75\tratamento_china.txt
# Selecionando as top 16 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'Duration', 'N_effort', 'Generated_Var_2', 'Generated_Var_5', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_12', 'Generated_Var_13']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\4-GAN-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\4-GAN-75\tratamento_cocomo81.txt
# Selecionando as top 14 variáveis...
# Variáveis selecionadas: ['data', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\4-GAN-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\4-GAN-75\tratamento_desharnais.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['TeamExp', 'Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'Generated_Var_2', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\4-GAN-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\4-GAN-75\tratamento_maxwell.txt
# Selecionando as top 21 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't07', 't11', 't14', 'Generated_Var_1', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12', 'Generated_Var_13', 'Generated_Var_14', 'Generated_Var_15', 'Generated_Var_16', 'Generated_Var_17', 'Generated_Var_18']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\4-GAN-75\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_china.txt
# Selecionando as top 11 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Added', 'N_effort', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_Added', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\5-MIMIC-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_cocomo81.txt
# Selecionando as top 10 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'turn', 'pcap', 'modp', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\5-MIMIC-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_desharnais.txt
# Selecionando as top 4 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'MI_PointsAdjust_Entities']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\5-MIMIC-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_maxwell.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'app', 'nlan', 't07', 't10', 't11', 't14', 't15', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\5-MIMIC-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_china.txt
# Selecionando as top 13 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'File', 'Added', 'N_effort', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_Added', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_PDR_UFP', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_Enquiry', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\6-MIMIC-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_cocomo81.txt
# Selecionando as top 12 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'modp', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn', 'MI_loc_pcap', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\6-MIMIC-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_desharnais.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['Transactions', 'PointsAdjust', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Language', 'MI_PointsAdjust_Envergure', 'MI_Entities_Language']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\6-MIMIC-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_maxwell.txt
# Selecionando as top 18 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't07', 't11', 't14', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_size_D_t14', 'MI_size_D_t03', 'MI_size_D_t10', 'MI_size_D_app', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\6-MIMIC-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_china.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['AFP', 'File', 'Added', 'N_effort', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_Added', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_PDR_UFP', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_Enquiry', 'MI_N_effort_Duration', 'MI_N_effort_File', 'MI_N_effort_Output', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\7-MIMIC-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_cocomo81.txt
# Selecionando as top 14 variáveis...
# Variáveis selecionadas: ['data', 'modp', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn', 'MI_loc_pcap', 'MI_loc_rely', 'MI_loc_virt', 'MI_loc_vexp', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\7-MIMIC-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_desharnais.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['Transactions', 'PointsAdjust', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Language', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_ManagerExp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\7-MIMIC-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_maxwell.txt
# Selecionando as top 21 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 't07', 't11', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_size_D_t14', 'MI_size_D_t03', 'MI_size_D_t10', 'MI_size_D_app', 'MI_size_D_t15', 'MI_size_D_t12', 'MI_size_D_har', 'MI_size_D_ifc', 'MI_size_D_dba', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\2-geracao-variaveis\7-MIMIC-75\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\1-tratamento\tratamento_china.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['Enquiry', 'Added', 'PDR_AFP', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Effort']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\1-tratamento\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\1-tratamento\tratamento_cocomo81.txt
# Selecionando as top 8 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'stor', 'turn', 'acap', 'aexp', 'tool', 'actual']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\1-tratamento\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\1-tratamento\tratamento_desharnais.txt
# Selecionando as top 4 variáveis...
# Variáveis selecionadas: ['Entities', 'PointsAdjust', 'Envergure', 'Language']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\1-tratamento\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\1-tratamento\tratamento_maxwell.txt
# Selecionando as top 11 variáveis...
# Erro ao processar tratamento_maxwell.txt: could not convert string to float: 'original'
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\2-GAN-25\tratamento_china.txt
# Selecionando as top 11 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Added', 'PDR_UFP', 'N_effort', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\2-GAN-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\2-GAN-25\tratamento_cocomo81.txt
# Selecionando as top 10 variáveis...
# Variáveis selecionadas: ['data', 'cplx', 'time', 'stor', 'virt', 'acap', 'lexp', 'loc', 'Generated_Var_1', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\2-GAN-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\2-GAN-25\tratamento_desharnais.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['TeamExp', 'Transactions', 'Entities', 'PointsAdjust', 'Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\2-GAN-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\2-GAN-25\tratamento_maxwell.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['size_D', 'har', 'nlan', 't01', 't03', 't06', 't07', 't08', 't09', 't10', 't11', 't12', 't14', 't15', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\2-GAN-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\3-GAN-50\tratamento_china.txt
# Selecionando as top 13 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Added', 'PDR_AFP', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Duration', 'N_effort', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\3-GAN-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\3-GAN-50\tratamento_cocomo81.txt
# Selecionando as top 12 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'cplx', 'time', 'stor', 'turn', 'pcap', 'modp', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_4', 'Generated_Var_7']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\3-GAN-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\3-GAN-50\tratamento_desharnais.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['TeamExp', 'Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'Generated_Var_2']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\3-GAN-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\3-GAN-50\tratamento_maxwell.txt
# Selecionando as top 18 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'app', 'har', 'ifc', 'source', 'nlan', 't04', 't05', 't07', 't08', 't10', 't11', 't12', 'Generated_Var_4', 'Generated_Var_6', 'Generated_Var_9', 'Generated_Var_12']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\3-GAN-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\4-GAN-75\tratamento_china.txt
# Selecionando as top 16 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'Changed', 'PDR_AFP', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Dev.Type', 'Duration', 'N_effort', 'Generated_Var_2']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\4-GAN-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\4-GAN-75\tratamento_cocomo81.txt
# Selecionando as top 14 variáveis...
# Variáveis selecionadas: ['data', 'turn', 'acap', 'aexp', 'pcap', 'modp', 'sced', 'loc', 'Generated_Var_2', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\4-GAN-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\4-GAN-75\tratamento_desharnais.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'Generated_Var_2', 'Generated_Var_4', 'Generated_Var_6']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\4-GAN-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\4-GAN-75\tratamento_maxwell.txt
# Selecionando as top 21 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'har', 'telonuse', 't01', 't04', 't07', 't09', 't11', 'Generated_Var_1', 'Generated_Var_3', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_13', 'Generated_Var_14', 'Generated_Var_15', 'Generated_Var_16', 'Generated_Var_17']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\4-GAN-75\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\5-MIMIC-25\tratamento_china.txt
# Selecionando as top 11 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Enquiry', 'PDR_AFP', 'PDR_UFP', 'NPDU_UFP', 'N_effort', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_Added', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\5-MIMIC-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\5-MIMIC-25\tratamento_cocomo81.txt
# Selecionando as top 10 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'cplx', 'time', 'stor', 'acap', 'pcap', 'MI_loc_aexp', 'MI_loc_stor', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\5-MIMIC-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\5-MIMIC-25\tratamento_desharnais.txt
# Selecionando as top 4 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'MI_PointsAdjust_Entities']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\5-MIMIC-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\5-MIMIC-25\tratamento_maxwell.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['har', 't02', 't03', 't05', 't07', 't09', 't10', 't11', 't12', 't13', 't15', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\5-MIMIC-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\6-MIMIC-50\tratamento_china.txt
# Selecionando as top 13 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Enquiry', 'N_effort', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_Added', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Input', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_Enquiry', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\6-MIMIC-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\6-MIMIC-50\tratamento_cocomo81.txt
# Selecionando as top 12 variáveis...
# Variáveis selecionadas: ['cplx', 'acap', 'aexp', 'pcap', 'modp', 'sced', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_turn']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\6-MIMIC-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\6-MIMIC-50\tratamento_desharnais.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['Transactions', 'PointsAdjust', 'Envergure', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Language', 'MI_PointsAdjust_Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\6-MIMIC-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\6-MIMIC-50\tratamento_maxwell.txt
# Selecionando as top 18 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'dba', 'nlan', 't05', 't07', 't11', 't12', 't13', 't15', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_size_D_t08', 'MI_size_D_app', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\6-MIMIC-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\7-MIMIC-75\tratamento_china.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['AFP', 'File', 'N_effort', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_Added', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Input', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_Enquiry', 'MI_N_effort_Duration', 'MI_N_effort_File', 'MI_N_effort_Output', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\7-MIMIC-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\7-MIMIC-75\tratamento_cocomo81.txt
# Selecionando as top 14 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'cplx', 'time', 'pcap', 'vexp', 'lexp', 'tool', 'loc', 'MI_loc_aexp', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_pcap', 'MI_loc_acap']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\7-MIMIC-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\7-MIMIC-75\tratamento_desharnais.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['Transactions', 'PointsAdjust', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Language', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_ManagerExp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\7-MIMIC-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\3-simulacao\7-MIMIC-75\tratamento_maxwell.txt
# Selecionando as top 21 variáveis...
# Variáveis selecionadas: ['har', 'nlan', 'telonuse', 't03', 't09', 't10', 't11', 't12', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_size_D_t08', 'MI_size_D_t03', 'MI_size_D_t10', 'MI_size_D_app', 'MI_size_D_t15', 'MI_size_D_telonuse', 'MI_size_D_har', 'MI_size_D_ifc']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\50\3-simulacao\7-MIMIC-75\tratamento_maxwell.txt

# %% [markdown]
# # 70

# %%
import os
import pandas as pd
import math
from sklearn.feature_selection import SelectKBest, f_classif, f_regression
from sklearn.preprocessing import LabelEncoder


def apply_selectkbest(data, target_column, k):
    """
    Aplica SelectKBest para selecionar as melhores variáveis em relação à coluna alvo.

    Args:
        data (pd.DataFrame): Dataset original.
        target_column (str): Nome da coluna alvo.
        k (float or int): Porcentagem (0-1) ou número de variáveis a selecionar.

    Returns:
        pd.DataFrame: Dataset com as variáveis selecionadas e a coluna alvo.
    """
    # Se a coluna alvo for categórica, usa f_classif; caso contrário, usa f_regression
    if data[target_column].dtype == 'object':
        data[target_column] = LabelEncoder().fit_transform(data[target_column])
        score_func = f_classif
    else:
        score_func = f_regression

    # Separar variáveis independentes e dependente
    X = data.drop(columns=[target_column])
    y = data[target_column]

    # Calcular o valor de k com base na porcentagem
    if isinstance(k, float) and 0 < k <= 1:
        k = max(1, math.floor(k * X.shape[1]))

    print(f"Selecionando as top {k} variáveis...")

    # Aplicar SelectKBest
    selector = SelectKBest(score_func=score_func, k=k)
    X_new = selector.fit_transform(X, y)

    # Identificar colunas selecionadas
    selected_columns = X.columns[selector.get_support()]

    print(f"Variáveis selecionadas: {list(selected_columns)}")

    # Reconstruir o DataFrame com as variáveis selecionadas e a coluna alvo
    new_data = pd.DataFrame(X_new, columns=selected_columns)
    new_data[target_column] = y.values

    return new_data


def process_all_subfolders(input_root, output_root, k):
    """
    Processa todas as subpastas do diretório de entrada, aplica SelectKBest nos arquivos
    e salva a saída na estrutura correspondente do diretório de saída.

    Args:
        input_root (str): Caminho do diretório raiz de entrada.
        output_root (str): Caminho do diretório raiz de saída.
        k (float or int): Porcentagem ou número de variáveis a serem selecionadas.
    """
    excluded_dir = os.path.join(input_root, "4-escolha")

    for subdir, _, files in os.walk(input_root):
        # Ignorar o diretório excluído
        if excluded_dir in subdir:
            continue

        # Mantém a mesma estrutura de subpastas
        relative_path = os.path.relpath(subdir, input_root)
        output_subdir = os.path.join(output_root, relative_path)
        os.makedirs(output_subdir, exist_ok=True)

        for filename in files:
            if filename.endswith(".txt"):
                input_path = os.path.join(subdir, filename)
                output_path = os.path.join(output_subdir, filename)

                print(f"Processando arquivo: {input_path}")
                try:
                    data = pd.read_csv(input_path, delimiter=",", skipinitialspace=True)
                    target_column = data.columns[-1]  # Assume que a última coluna é a coluna alvo

                    # Aplicar SelectKBest
                    new_data = apply_selectkbest(data, target_column, k)

                    # Salvar o novo dataset
                    new_data.to_csv(output_path, sep=",", index=False)
                    print(f"Arquivo processado e salvo em: {output_path}")
                except Exception as e:
                    print(f"Erro ao processar {filename}: {e}")


# Diretórios de entrada e saída
input_root_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida"
output_root_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem2\saida\4-escolha\selectKbest\75"

# Aplicar SelectKBest nos arquivos
top_percentage = 0.75  # 75% das variáveis
process_all_subfolders(input_root_directory, output_root_directory, k=top_percentage)

# %% [markdown]
# # -=========================================================

# %%
import os
import pandas as pd
import math
from sklearn.feature_selection import SelectKBest, f_classif, f_regression
from sklearn.preprocessing import LabelEncoder


def apply_selectkbest(data, target_column, k):
    """
    Aplica SelectKBest para selecionar as melhores variáveis em relação à coluna alvo.

    Args:
        data (pd.DataFrame): Dataset original.
        target_column (str): Nome da coluna alvo.
        k (float or int): Porcentagem (0-1) ou número de variáveis a selecionar.

    Returns:
        pd.DataFrame: Dataset com as variáveis selecionadas e a coluna alvo.
    """
    # Se a coluna alvo for categórica, usa f_classif; caso contrário, usa f_regression
    if data[target_column].dtype == 'object':
        data[target_column] = LabelEncoder().fit_transform(data[target_column])
        score_func = f_classif
    else:
        score_func = f_regression

    # Separar variáveis independentes e dependente
    X = data.drop(columns=[target_column])
    y = data[target_column]

    # Calcular o valor de k com base na porcentagem
    if isinstance(k, float) and 0 < k <= 1:
        k = max(1, math.floor(k * X.shape[1]))

    print(f"Selecionando as top {k} variáveis...")

    # Aplicar SelectKBest
    selector = SelectKBest(score_func=score_func, k=k)
    X_new = selector.fit_transform(X, y)

    # Identificar colunas selecionadas
    selected_columns = X.columns[selector.get_support()]

    print(f"Variáveis selecionadas: {list(selected_columns)}")

    # Reconstruir o DataFrame com as variáveis selecionadas e a coluna alvo
    new_data = pd.DataFrame(X_new, columns=selected_columns)
    new_data[target_column] = y.values

    return new_data


def process_all_subfolders(input_root, output_root, k):
    """
    Processa todas as subpastas do diretório de entrada, aplica SelectKBest nos arquivos
    e salva a saída na estrutura correspondente do diretório de saída.

    Args:
        input_root (str): Caminho do diretório raiz de entrada.
        output_root (str): Caminho do diretório raiz de saída.
        k (float or int): Porcentagem ou número de variáveis a serem selecionadas.
    """
    for subdir, _, files in os.walk(input_root):
        # Mantém a mesma estrutura de subpastas
        relative_path = os.path.relpath(subdir, input_root)
        output_subdir = os.path.join(output_root, relative_path)
        os.makedirs(output_subdir, exist_ok=True)

        for filename in files:
            if filename.endswith(".txt"):
                input_path = os.path.join(subdir, filename)
                output_path = os.path.join(output_subdir, filename)

                print(f"Processando arquivo: {input_path}")
                try:
                    data = pd.read_csv(input_path, delimiter=",", skipinitialspace=True)
                    target_column = data.columns[-1]  # Assume que a última coluna é a coluna alvo

                    # Aplicar SelectKBest
                    new_data = apply_selectkbest(data, target_column, k)

                    # Salvar o novo dataset
                    new_data.to_csv(output_path, sep=",", index=False)
                    print(f"Arquivo processado e salvo em: {output_path}")
                except Exception as e:
                    print(f"Erro ao processar {filename}: {e}")


# Diretórios de entrada e saída
input_root_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis"
output_root_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25"

# Aplicar SelectKBest nos arquivos
top_percentage = 0.25  # 25% das variáveis
process_all_subfolders(input_root_directory, output_root_directory, k=top_percentage)
# Out:
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_china.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'File', 'Added', 'N_effort']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\2-GAN-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_cocomo81.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['data', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\2-GAN-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_desharnais.txt
# Selecionando as top 2 variáveis...
# Variáveis selecionadas: ['Transactions', 'PointsAdjust']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\2-GAN-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_maxwell.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't07', 't11', 't14', 'Generated_Var_2']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\2-GAN-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\3-GAN-50\tratamento_china.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'File', 'Added', 'N_effort']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\3-GAN-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\3-GAN-50\tratamento_cocomo81.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['data', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_7']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\3-GAN-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\3-GAN-50\tratamento_desharnais.txt
# Selecionando as top 3 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\3-GAN-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\3-GAN-50\tratamento_maxwell.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_4', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_11']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\3-GAN-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\4-GAN-75\tratamento_china.txt
# Selecionando as top 8 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Added', 'Duration', 'N_effort']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\4-GAN-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\4-GAN-75\tratamento_cocomo81.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['data', 'loc', 'Generated_Var_2', 'Generated_Var_6', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_12']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\4-GAN-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\4-GAN-75\tratamento_desharnais.txt
# Selecionando as top 3 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\4-GAN-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\4-GAN-75\tratamento_maxwell.txt
# Selecionando as top 10 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_14', 'Generated_Var_17']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\4-GAN-75\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_china.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['AFP', 'Added', 'N_effort', 'MI_N_effort_PDR_AFP', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\5-MIMIC-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_cocomo81.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['data', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\5-MIMIC-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_desharnais.txt
# Selecionando as top 2 variáveis...
# Variáveis selecionadas: ['PointsAdjust', 'MI_PointsAdjust_Entities']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\5-MIMIC-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_maxwell.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['size_D', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\5-MIMIC-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_china.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['AFP', 'Added', 'N_effort', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Enquiry', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\6-MIMIC-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_cocomo81.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\6-MIMIC-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_desharnais.txt
# Selecionando as top 3 variáveis...
# Variáveis selecionadas: ['PointsAdjust', 'MI_PointsAdjust_Language', 'MI_PointsAdjust_Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\6-MIMIC-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_maxwell.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['size_D', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_size_D_t08', 'MI_size_D_t10', 'MI_size_D_app']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\6-MIMIC-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_china.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['Added', 'N_effort', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Enquiry', 'MI_N_effort_Duration', 'MI_N_effort_Output', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\7-MIMIC-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_cocomo81.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn', 'MI_loc_rely', 'MI_loc_vexp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\7-MIMIC-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_desharnais.txt
# Selecionando as top 3 variáveis...
# Variáveis selecionadas: ['PointsAdjust', 'MI_PointsAdjust_Language', 'MI_PointsAdjust_Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\7-MIMIC-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_maxwell.txt
# Selecionando as top 10 variáveis...
# Variáveis selecionadas: ['size_D', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t08', 'MI_size_D_t10', 'MI_size_D_app', 'MI_size_D_t15', 'MI_size_D_ifc', 'MI_size_D_dba']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\25\7-MIMIC-75\tratamento_maxwell.txt

# %%
import os
import pandas as pd
import math
from sklearn.feature_selection import SelectKBest, f_classif, f_regression
from sklearn.preprocessing import LabelEncoder


def apply_selectkbest(data, target_column, k):
    """
    Aplica SelectKBest para selecionar as melhores variáveis em relação à coluna alvo.

    Args:
        data (pd.DataFrame): Dataset original.
        target_column (str): Nome da coluna alvo.
        k (float or int): Porcentagem (0-1) ou número de variáveis a selecionar.

    Returns:
        pd.DataFrame: Dataset com as variáveis selecionadas e a coluna alvo.
    """
    # Se a coluna alvo for categórica, usa f_classif; caso contrário, usa f_regression
    if data[target_column].dtype == 'object':
        data[target_column] = LabelEncoder().fit_transform(data[target_column])
        score_func = f_classif
    else:
        score_func = f_regression

    # Separar variáveis independentes e dependente
    X = data.drop(columns=[target_column])
    y = data[target_column]

    # Calcular o valor de k com base na porcentagem
    if isinstance(k, float) and 0 < k <= 1:
        k = max(1, math.floor(k * X.shape[1]))

    print(f"Selecionando as top {k} variáveis...")

    # Aplicar SelectKBest
    selector = SelectKBest(score_func=score_func, k=k)
    X_new = selector.fit_transform(X, y)

    # Identificar colunas selecionadas
    selected_columns = X.columns[selector.get_support()]

    print(f"Variáveis selecionadas: {list(selected_columns)}")

    # Reconstruir o DataFrame com as variáveis selecionadas e a coluna alvo
    new_data = pd.DataFrame(X_new, columns=selected_columns)
    new_data[target_column] = y.values

    return new_data


def process_all_subfolders(input_root, output_root, k):
    """
    Processa todas as subpastas do diretório de entrada, aplica SelectKBest nos arquivos
    e salva a saída na estrutura correspondente do diretório de saída.

    Args:
        input_root (str): Caminho do diretório raiz de entrada.
        output_root (str): Caminho do diretório raiz de saída.
        k (float or int): Porcentagem ou número de variáveis a serem selecionadas.
    """
    for subdir, _, files in os.walk(input_root):
        # Mantém a mesma estrutura de subpastas
        relative_path = os.path.relpath(subdir, input_root)
        output_subdir = os.path.join(output_root, relative_path)
        os.makedirs(output_subdir, exist_ok=True)

        for filename in files:
            if filename.endswith(".txt"):
                input_path = os.path.join(subdir, filename)
                output_path = os.path.join(output_subdir, filename)

                print(f"Processando arquivo: {input_path}")
                try:
                    data = pd.read_csv(input_path, delimiter=",", skipinitialspace=True)
                    target_column = data.columns[-1]  # Assume que a última coluna é a coluna alvo

                    # Aplicar SelectKBest
                    new_data = apply_selectkbest(data, target_column, k)

                    # Salvar o novo dataset
                    new_data.to_csv(output_path, sep=",", index=False)
                    print(f"Arquivo processado e salvo em: {output_path}")
                except Exception as e:
                    print(f"Erro ao processar {filename}: {e}")


# Diretórios de entrada e saída
input_root_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis"
output_root_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50"

# Aplicar SelectKBest nos arquivos
top_percentage = 0.50  # 50% das variáveis
process_all_subfolders(input_root_directory, output_root_directory, k=top_percentage)
# Out:
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_china.txt
# Selecionando as top 11 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_UFP', 'Duration', 'N_effort', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\2-GAN-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_cocomo81.txt
# Selecionando as top 10 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'turn', 'pcap', 'modp', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\2-GAN-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_desharnais.txt
# Selecionando as top 5 variáveis...
# Variáveis selecionadas: ['TeamExp', 'Transactions', 'Entities', 'PointsAdjust', 'Envergure']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\2-GAN-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_maxwell.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'app', 'har', 'nlan', 't07', 't08', 't09', 't10', 't11', 't14', 't15', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\2-GAN-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\3-GAN-50\tratamento_china.txt
# Selecionando as top 13 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'Duration', 'N_effort', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_4', 'Generated_Var_6']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\3-GAN-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\3-GAN-50\tratamento_cocomo81.txt
# Selecionando as top 12 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'modp', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\3-GAN-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\3-GAN-50\tratamento_desharnais.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['TeamExp', 'Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'Generated_Var_1']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\3-GAN-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\3-GAN-50\tratamento_maxwell.txt
# Selecionando as top 18 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'app', 'nlan', 't07', 't11', 't14', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\3-GAN-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\4-GAN-75\tratamento_china.txt
# Selecionando as top 16 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'Duration', 'N_effort', 'Generated_Var_2', 'Generated_Var_5', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_12', 'Generated_Var_13']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\4-GAN-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\4-GAN-75\tratamento_cocomo81.txt
# Selecionando as top 14 variáveis...
# Variáveis selecionadas: ['data', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\4-GAN-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\4-GAN-75\tratamento_desharnais.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['TeamExp', 'Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'Generated_Var_2', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\4-GAN-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\4-GAN-75\tratamento_maxwell.txt
# Selecionando as top 21 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't07', 't11', 't14', 'Generated_Var_1', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12', 'Generated_Var_13', 'Generated_Var_14', 'Generated_Var_15', 'Generated_Var_16', 'Generated_Var_17', 'Generated_Var_18']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\4-GAN-75\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_china.txt
# Selecionando as top 11 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Added', 'N_effort', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_Added', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\5-MIMIC-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_cocomo81.txt
# Selecionando as top 10 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'turn', 'pcap', 'modp', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\5-MIMIC-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_desharnais.txt
# Selecionando as top 4 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'MI_PointsAdjust_Entities']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\5-MIMIC-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_maxwell.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'app', 'nlan', 't07', 't10', 't11', 't14', 't15', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\5-MIMIC-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_china.txt
# Selecionando as top 13 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'File', 'Added', 'N_effort', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_Added', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_PDR_UFP', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_Enquiry', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\6-MIMIC-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_cocomo81.txt
# Selecionando as top 12 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'modp', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn', 'MI_loc_pcap', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\6-MIMIC-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_desharnais.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['Transactions', 'PointsAdjust', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Language', 'MI_PointsAdjust_Envergure', 'MI_Entities_Language']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\6-MIMIC-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_maxwell.txt
# Selecionando as top 18 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'nlan', 't07', 't11', 't14', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_size_D_t14', 'MI_size_D_t03', 'MI_size_D_t10', 'MI_size_D_app', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\6-MIMIC-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_china.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['AFP', 'File', 'Added', 'N_effort', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_Added', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_PDR_UFP', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_Enquiry', 'MI_N_effort_Duration', 'MI_N_effort_File', 'MI_N_effort_Output', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\7-MIMIC-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_cocomo81.txt
# Selecionando as top 14 variáveis...
# Variáveis selecionadas: ['data', 'modp', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn', 'MI_loc_pcap', 'MI_loc_rely', 'MI_loc_virt', 'MI_loc_vexp', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\7-MIMIC-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_desharnais.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['Transactions', 'PointsAdjust', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Language', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_ManagerExp']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\7-MIMIC-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_maxwell.txt
# Selecionando as top 21 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 't07', 't11', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_size_D_t14', 'MI_size_D_t03', 'MI_size_D_t10', 'MI_size_D_app', 'MI_size_D_t15', 'MI_size_D_t12', 'MI_size_D_har', 'MI_size_D_ifc', 'MI_size_D_dba', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\50\7-MIMIC-75\tratamento_maxwell.txt

# %%
import os
import pandas as pd
import math
from sklearn.feature_selection import SelectKBest, f_classif, f_regression
from sklearn.preprocessing import LabelEncoder


def apply_selectkbest(data, target_column, k):
    """
    Aplica SelectKBest para selecionar as melhores variáveis em relação à coluna alvo.

    Args:
        data (pd.DataFrame): Dataset original.
        target_column (str): Nome da coluna alvo.
        k (float or int): Porcentagem (0-1) ou número de variáveis a selecionar.

    Returns:
        pd.DataFrame: Dataset com as variáveis selecionadas e a coluna alvo.
    """
    # Se a coluna alvo for categórica, usa f_classif; caso contrário, usa f_regression
    if data[target_column].dtype == 'object':
        data[target_column] = LabelEncoder().fit_transform(data[target_column])
        score_func = f_classif
    else:
        score_func = f_regression

    # Separar variáveis independentes e dependente
    X = data.drop(columns=[target_column])
    y = data[target_column]

    # Calcular o valor de k com base na porcentagem
    if isinstance(k, float) and 0 < k <= 1:
        k = max(1, math.floor(k * X.shape[1]))

    print(f"Selecionando as top {k} variáveis...")

    # Aplicar SelectKBest
    selector = SelectKBest(score_func=score_func, k=k)
    X_new = selector.fit_transform(X, y)

    # Identificar colunas selecionadas
    selected_columns = X.columns[selector.get_support()]

    print(f"Variáveis selecionadas: {list(selected_columns)}")

    # Reconstruir o DataFrame com as variáveis selecionadas e a coluna alvo
    new_data = pd.DataFrame(X_new, columns=selected_columns)
    new_data[target_column] = y.values

    return new_data


def process_all_subfolders(input_root, output_root, k):
    """
    Processa todas as subpastas do diretório de entrada, aplica SelectKBest nos arquivos
    e salva a saída na estrutura correspondente do diretório de saída.

    Args:
        input_root (str): Caminho do diretório raiz de entrada.
        output_root (str): Caminho do diretório raiz de saída.
        k (float or int): Porcentagem ou número de variáveis a serem selecionadas.
    """
    for subdir, _, files in os.walk(input_root):
        # Mantém a mesma estrutura de subpastas
        relative_path = os.path.relpath(subdir, input_root)
        output_subdir = os.path.join(output_root, relative_path)
        os.makedirs(output_subdir, exist_ok=True)

        for filename in files:
            if filename.endswith(".txt"):
                input_path = os.path.join(subdir, filename)
                output_path = os.path.join(output_subdir, filename)

                print(f"Processando arquivo: {input_path}")
                try:
                    data = pd.read_csv(input_path, delimiter=",", skipinitialspace=True)
                    target_column = data.columns[-1]  # Assume que a última coluna é a coluna alvo

                    # Aplicar SelectKBest
                    new_data = apply_selectkbest(data, target_column, k)

                    # Salvar o novo dataset
                    new_data.to_csv(output_path, sep=",", index=False)
                    print(f"Arquivo processado e salvo em: {output_path}")
                except Exception as e:
                    print(f"Erro ao processar {filename}: {e}")


# Diretórios de entrada e saída
input_root_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis"
output_root_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75"

# Aplicar SelectKBest nos arquivos
top_percentage = 0.75  # 75% das variáveis
process_all_subfolders(input_root_directory, output_root_directory, k=top_percentage)
# Out:
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_china.txt
# Selecionando as top 16 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_AFP', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Resource', 'Duration', 'N_effort', 'Generated_Var_2', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\2-GAN-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_cocomo81.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'vexp', 'lexp', 'modp', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\2-GAN-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_desharnais.txt
# Selecionando as top 7 variáveis...
# Variáveis selecionadas: ['TeamExp', 'Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'Generated_Var_1', 'Generated_Var_2']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\2-GAN-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\2-GAN-25\tratamento_maxwell.txt
# Selecionando as top 22 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'app', 'har', 'ifc', 'nlan', 't01', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_6']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\2-GAN-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\3-GAN-50\tratamento_china.txt
# Selecionando as top 20 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_AFP', 'PDR_UFP', 'NPDR_AFP', 'NPDU_UFP', 'Resource', 'Duration', 'N_effort', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\3-GAN-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\3-GAN-50\tratamento_cocomo81.txt
# Selecionando as top 18 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'lexp', 'modp', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\3-GAN-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\3-GAN-50\tratamento_desharnais.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['TeamExp', 'ManagerExp', 'Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\3-GAN-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\3-GAN-50\tratamento_maxwell.txt
# Selecionando as top 27 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'app', 'har', 'nlan', 't01', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\3-GAN-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\4-GAN-75\tratamento_china.txt
# Selecionando as top 24 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_AFP', 'PDR_UFP', 'NPDU_UFP', 'Resource', 'Duration', 'N_effort', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12', 'Generated_Var_13']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\4-GAN-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\4-GAN-75\tratamento_cocomo81.txt
# Selecionando as top 21 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'modp', 'loc', 'Generated_Var_1', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_8', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\4-GAN-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\4-GAN-75\tratamento_desharnais.txt
# Selecionando as top 10 variáveis...
# Variáveis selecionadas: ['TeamExp', 'ManagerExp', 'Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'Generated_Var_2', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_6']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\4-GAN-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\4-GAN-75\tratamento_maxwell.txt
# Selecionando as top 31 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'app', 'har', 'nlan', 't01', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'Generated_Var_1', 'Generated_Var_3', 'Generated_Var_4', 'Generated_Var_5', 'Generated_Var_6', 'Generated_Var_7', 'Generated_Var_9', 'Generated_Var_10', 'Generated_Var_11', 'Generated_Var_12', 'Generated_Var_13', 'Generated_Var_14', 'Generated_Var_15', 'Generated_Var_16', 'Generated_Var_17', 'Generated_Var_18']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\4-GAN-75\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_china.txt
# Selecionando as top 16 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_UFP', 'NPDU_UFP', 'Resource', 'Duration', 'N_effort', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_Added', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\5-MIMIC-25\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_cocomo81.txt
# Selecionando as top 15 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'vexp', 'lexp', 'modp', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\5-MIMIC-25\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_desharnais.txt
# Selecionando as top 6 variáveis...
# Variáveis selecionadas: ['TeamExp', 'Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'MI_PointsAdjust_Entities']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\5-MIMIC-25\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\5-MIMIC-25\tratamento_maxwell.txt
# Selecionando as top 22 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'app', 'har', 'nlan', 't01', 't03', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\5-MIMIC-25\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_china.txt
# Selecionando as top 20 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_UFP', 'Resource', 'Duration', 'N_effort', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_Added', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Input', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_Enquiry', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\6-MIMIC-50\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_cocomo81.txt
# Selecionando as top 18 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'lexp', 'modp', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn', 'MI_loc_pcap', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\6-MIMIC-50\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_desharnais.txt
# Selecionando as top 9 variáveis...
# Variáveis selecionadas: ['TeamExp', 'Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Language', 'MI_PointsAdjust_Envergure', 'MI_Entities_Language']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\6-MIMIC-50\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\6-MIMIC-50\tratamento_maxwell.txt
# Selecionando as top 27 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'app', 'har', 'nlan', 't01', 't07', 't08', 't09', 't10', 't11', 't12', 't13', 't14', 't15', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_size_D_t14', 'MI_size_D_t03', 'MI_size_D_t10', 'MI_size_D_app', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\6-MIMIC-50\tratamento_maxwell.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_china.txt
# Selecionando as top 23 variáveis...
# Variáveis selecionadas: ['AFP', 'Input', 'Output', 'Enquiry', 'File', 'Interface', 'Added', 'PDR_UFP', 'Resource', 'Duration', 'N_effort', 'MI_N_effort_AFP', 'MI_N_effort_PDR_AFP', 'MI_N_effort_Added', 'MI_N_effort_NPDU_UFP', 'MI_N_effort_PDR_UFP', 'MI_N_effort_Input', 'MI_N_effort_NPDR_AFP', 'MI_N_effort_Enquiry', 'MI_N_effort_Duration', 'MI_N_effort_File', 'MI_N_effort_Output', 'MI_AFP_PDR_AFP']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\7-MIMIC-75\tratamento_china.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_cocomo81.txt
# Selecionando as top 21 variáveis...
# Variáveis selecionadas: ['rely', 'data', 'time', 'stor', 'turn', 'acap', 'pcap', 'modp', 'loc', 'MI_loc_aexp', 'MI_loc_data', 'MI_loc_stor', 'MI_loc_time', 'MI_loc_cplx', 'MI_loc_turn', 'MI_loc_pcap', 'MI_loc_rely', 'MI_loc_virt', 'MI_loc_acap', 'MI_loc_vexp', 'MI_aexp_data']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\7-MIMIC-75\tratamento_cocomo81.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_desharnais.txt
# Selecionando as top 10 variáveis...
# Variáveis selecionadas: ['Transactions', 'Entities', 'PointsAdjust', 'Envergure', 'MI_PointsAdjust_Entities', 'MI_PointsAdjust_Language', 'MI_PointsAdjust_Envergure', 'MI_PointsAdjust_Transactions', 'MI_PointsAdjust_ManagerExp', 'MI_Entities_Language']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\7-MIMIC-75\tratamento_desharnais.txt
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-geracao-variaveis\7-MIMIC-75\tratamento_maxwell.txt
# Selecionando as top 31 variáveis...
# Variáveis selecionadas: ['size_D', 'duration_D', 'app', 'har', 'nlan', 't01', 't07', 't08', 't09', 't10', 't11', 't14', 't15', 'MI_size_D_duration_D', 'MI_size_D_t07', 'MI_size_D_t09', 'MI_size_D_t11', 'MI_size_D_nlan', 'MI_size_D_t02', 'MI_size_D_t08', 'MI_size_D_t14', 'MI_size_D_t03', 'MI_size_D_t10', 'MI_size_D_app', 'MI_size_D_t15', 'MI_size_D_t12', 'MI_size_D_telonuse', 'MI_size_D_har', 'MI_size_D_ifc', 'MI_size_D_dba', 'MI_duration_D_t07']
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-escolha-variaveis\selectKbest\2-geracao\75\7-MIMIC-75\tratamento_maxwell.txt
