# %% [markdown]
# # GAN (25%)

# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

def apply_min_max_normalization(data):
    """
    Aplica normalização Min-Max nas colunas numéricas do DataFrame.

    Args:
        data (pd.DataFrame): DataFrame a ser normalizado.

    Returns:
        pd.DataFrame: DataFrame com colunas normalizadas.
    """
    numeric_columns = data.select_dtypes(include=[np.number]).columns

    for col in numeric_columns:
        col_min = data[col].min()
        col_max = data[col].max()

        if col_max != col_min:  # Evita divisão por zero
            data[col] = (data[col] - col_min) / (col_max - col_min)
        else:
            data[col] = 0  # Se todos os valores forem iguais, normaliza para 0

    return data

def apply_gan_to_generate_variables(file_path, percentage_generated_features=0.25, num_epochs=100, batch_size=32, learning_rate=0.001):
    print(f"Lendo arquivo de entrada: {file_path}...")
    data = pd.read_csv(file_path, delimiter=",", skipinitialspace=True)
    print("Arquivo carregado com sucesso.")

    print("Convertendo os dados para tensores do PyTorch...")
    data_tensor = torch.tensor(data.values, dtype=torch.float32)

    input_dim = data.shape[1]
    num_generated_features = max(1, int(input_dim * percentage_generated_features))  # Calcular a quantidade de variáveis a serem geradas
    print(f"A base de dados contém {input_dim} variáveis de entrada. Gerando {num_generated_features} novas variáveis.")

    class Generator(nn.Module):
        def __init__(self, input_dim, output_dim):
            super(Generator, self).__init__()
            self.model = nn.Sequential(
                nn.Linear(input_dim, 64),
                nn.ReLU(),
                nn.Linear(64, 64),
                nn.ReLU(),
                nn.Linear(64, output_dim)
            )
        
        def forward(self, x):
            return self.model(x)
    
    class Discriminator(nn.Module):
        def __init__(self, input_dim):
            super(Discriminator, self).__init__()
            self.model = nn.Sequential(
                nn.Linear(input_dim, 64),
                nn.LeakyReLU(0.2),
                nn.Linear(64, 64),
                nn.LeakyReLU(0.2),
                nn.Linear(64, 1),
                nn.Sigmoid()
            )
        
        def forward(self, x):
            return self.model(x)
    
    print("Inicializando modelos Generator e Discriminator...")
    generator = Generator(input_dim, num_generated_features)
    discriminator = Discriminator(input_dim + num_generated_features)

    criterion = nn.BCELoss()
    optimizer_G = torch.optim.Adam(generator.parameters(), lr=learning_rate)
    optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=learning_rate)

    dataset = TensorDataset(data_tensor)
    data_loader = DataLoader(dataset, batch_size=min(batch_size, len(dataset)), shuffle=True)

    print("Iniciando o treinamento da GAN...")
    for epoch in range(num_epochs):
        for batch in data_loader:
            real_data = batch[0]
            batch_size_actual = real_data.size(0)

            # Labels reais e falsas
            real_labels = torch.ones((batch_size_actual, 1))
            fake_labels = torch.zeros((batch_size_actual, 1))

            # Treinar o discriminador
            generated_data = generator(real_data)
            fake_data = torch.cat((real_data, generated_data), dim=1)
            real_data_extended = torch.cat((real_data, torch.zeros((batch_size_actual, num_generated_features))), dim=1)
            
            discriminator_real_loss = criterion(discriminator(real_data_extended), real_labels)
            discriminator_fake_loss = criterion(discriminator(fake_data.detach()), fake_labels)
            discriminator_loss = discriminator_real_loss + discriminator_fake_loss

            optimizer_D.zero_grad()
            discriminator_loss.backward()
            optimizer_D.step()

            # Treinar o gerador
            fake_data = torch.cat((real_data, generator(real_data)), dim=1)
            generator_loss = criterion(discriminator(fake_data), real_labels)

            optimizer_G.zero_grad()
            generator_loss.backward()
            optimizer_G.step()

        if (epoch + 1) % 10 == 0:
            print(f"Época [{epoch+1}/{num_epochs}] - Perda Discriminador: {discriminator_loss.item():.4f}, Perda Gerador: {generator_loss.item():.4f}")

    print("Treinamento concluído. Gerando novas variáveis...")
    with torch.no_grad():
        new_variables = generator(data_tensor).numpy()

    for i in range(num_generated_features):
        data[f"Generated_Var_{i+1}"] = new_variables[:, i]

    # Aplicar normalização Min-Max
    data = apply_min_max_normalization(data)

    # Reorganizar as colunas para garantir que a coluna alvo seja a última
    target_column = data.columns[-(num_generated_features + 1)]  # Identifica a coluna alvo original
    columns = [col for col in data.columns if col != target_column] + [target_column]
    data = data[columns]

    print("Novas variáveis adicionadas e colunas reorganizadas com sucesso.")
    return data

def process_and_save_files(input_dir, output_dir, percentage_generated_features=0.25, num_epochs=100, batch_size=32, learning_rate=0.001):
    print(f"Verificando diretório de saída: {output_dir}...")
    os.makedirs(output_dir, exist_ok=True)
    print("Diretório de saída pronto.")

    for filename in os.listdir(input_dir):
        if filename.endswith(".txt"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)
            
            print(f"\nProcessando arquivo: {input_path}")
            try:
                processed_data = apply_gan_to_generate_variables(
                    file_path=input_path,
                    percentage_generated_features=percentage_generated_features,
                    num_epochs=num_epochs,
                    batch_size=batch_size,
                    learning_rate=learning_rate
                )
                processed_data.to_csv(output_path, sep=",", index=False)
                print(f"Arquivo processado e salvo em: {output_path}")
            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

# Diretórios de entrada e saída
input_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado"
output_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-GAN-25"

# Processar arquivos
process_and_save_files(input_directory, output_directory, percentage_generated_features=0.25, num_epochs=100)
# Out:
# Verificando diretório de saída: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-GAN-25...
# Diretório de saída pronto.
#
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_china.txt
# Lendo arquivo de entrada: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_china.txt...
# Arquivo carregado com sucesso.
# Convertendo os dados para tensores do PyTorch...
# A base de dados contém 19 variáveis de entrada. Gerando 4 novas variáveis.
# Inicializando modelos Generator e Discriminator...
# Iniciando o treinamento da GAN...
# Época [10/100] - Perda Discriminador: 1.3062, Perda Gerador: 0.8296
# Época [20/100] - Perda Discriminador: 1.5507, Perda Gerador: 0.4734
# Época [30/100] - Perda Discriminador: 1.4213, Perda Gerador: 0.7602
# Época [40/100] - Perda Discriminador: 1.4417, Perda Gerador: 0.5877
# Época [50/100] - Perda Discriminador: 1.3073, Perda Gerador: 0.9697
# Época [60/100] - Perda Discriminador: 1.3988, Perda Gerador: 0.6799
# Época [70/100] - Perda Discriminador: 1.2998, Perda Gerador: 0.7294
# Época [80/100] - Perda Discriminador: 1.4173, Perda Gerador: 0.5571
# Época [90/100] - Perda Discriminador: 1.2138, Perda Gerador: 0.9744
# Época [100/100] - Perda Discriminador: 1.4038, Perda Gerador: 0.5642
# Treinamento concluído. Gerando novas variáveis...
# Novas variáveis adicionadas e colunas reorganizadas com sucesso.
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-GAN-25\tratamento_china.txt
#
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_cocomo81.txt
# Lendo arquivo de entrada: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_cocomo81.txt...
# Arquivo carregado com sucesso.
# Convertendo os dados para tensores do PyTorch...
# A base de dados contém 17 variáveis de entrada. Gerando 4 novas variáveis.
# Inicializando modelos Generator e Discriminator...
# Iniciando o treinamento da GAN...
# Época [10/100] - Perda Discriminador: 1.3952, Perda Gerador: 0.7005
# Época [20/100] - Perda Discriminador: 1.3823, Perda Gerador: 0.6968
# Época [30/100] - Perda Discriminador: 1.3286, Perda Gerador: 0.7379
# Época [40/100] - Perda Discriminador: 1.4077, Perda Gerador: 0.6912
# Época [50/100] - Perda Discriminador: 1.4612, Perda Gerador: 0.6801
# Época [60/100] - Perda Discriminador: 1.3435, Perda Gerador: 0.7441
# Época [70/100] - Perda Discriminador: 1.3145, Perda Gerador: 0.7665
# Época [80/100] - Perda Discriminador: 1.3884, Perda Gerador: 0.7044
# Época [90/100] - Perda Discriminador: 1.3400, Perda Gerador: 0.7458
# Época [100/100] - Perda Discriminador: 1.5035, Perda Gerador: 0.6905
# Treinamento concluído. Gerando novas variáveis...
# Novas variáveis adicionadas e colunas reorganizadas com sucesso.
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-GAN-25\tratamento_cocomo81.txt
#
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_desharnais.txt
# Lendo arquivo de entrada: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_desharnais.txt...
# Arquivo carregado com sucesso.
# Convertendo os dados para tensores do PyTorch...
# A base de dados contém 9 variáveis de entrada. Gerando 2 novas variáveis.
# Inicializando modelos Generator e Discriminator...
# Iniciando o treinamento da GAN...
# Época [10/100] - Perda Discriminador: 1.3943, Perda Gerador: 0.6737
# Época [20/100] - Perda Discriminador: 1.3761, Perda Gerador: 0.7117
# Época [30/100] - Perda Discriminador: 1.3452, Perda Gerador: 0.7518
# Época [40/100] - Perda Discriminador: 1.4632, Perda Gerador: 0.6806
# Época [50/100] - Perda Discriminador: 1.2912, Perda Gerador: 0.8103
# Época [60/100] - Perda Discriminador: 1.2756, Perda Gerador: 0.7698
# Época [70/100] - Perda Discriminador: 1.6768, Perda Gerador: 0.5808
# Época [80/100] - Perda Discriminador: 1.1498, Perda Gerador: 1.0665
# Época [90/100] - Perda Discriminador: 1.2071, Perda Gerador: 0.8107
# Época [100/100] - Perda Discriminador: 1.5336, Perda Gerador: 0.4727
# Treinamento concluído. Gerando novas variáveis...
# Novas variáveis adicionadas e colunas reorganizadas com sucesso.
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-GAN-25\tratamento_desharnais.txt
#
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_maxwell.txt
# Lendo arquivo de entrada: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_maxwell.txt...
# Arquivo carregado com sucesso.
# Convertendo os dados para tensores do PyTorch...
# A base de dados contém 25 variáveis de entrada. Gerando 6 novas variáveis.
# Inicializando modelos Generator e Discriminator...
# Iniciando o treinamento da GAN...
# Época [10/100] - Perda Discriminador: 1.3837, Perda Gerador: 0.6937
# Época [20/100] - Perda Discriminador: 1.3926, Perda Gerador: 0.6950
# Época [30/100] - Perda Discriminador: 1.3859, Perda Gerador: 0.7037
# Época [40/100] - Perda Discriminador: 1.3943, Perda Gerador: 0.6899
# Época [50/100] - Perda Discriminador: 1.3109, Perda Gerador: 0.7644
# Época [60/100] - Perda Discriminador: 1.3479, Perda Gerador: 0.7437
# Época [70/100] - Perda Discriminador: 1.6152, Perda Gerador: 0.5920
# Época [80/100] - Perda Discriminador: 1.2741, Perda Gerador: 0.8598
# Época [90/100] - Perda Discriminador: 1.0147, Perda Gerador: 0.9818
# Época [100/100] - Perda Discriminador: 1.4728, Perda Gerador: 0.6661
# Treinamento concluído. Gerando novas variáveis...
# Novas variáveis adicionadas e colunas reorganizadas com sucesso.
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\2-GAN-25\tratamento_maxwell.txt

# %% [markdown]
# # GAN (50%)

# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

def apply_min_max_normalization(data):
    """
    Aplica normalização Min-Max nas colunas numéricas do DataFrame.

    Args:
        data (pd.DataFrame): DataFrame a ser normalizado.

    Returns:
        pd.DataFrame: DataFrame com colunas normalizadas.
    """
    numeric_columns = data.select_dtypes(include=[np.number]).columns

    for col in numeric_columns:
        col_min = data[col].min()
        col_max = data[col].max()

        if col_max != col_min:  # Evita divisão por zero
            data[col] = (data[col] - col_min) / (col_max - col_min)
        else:
            data[col] = 0  # Se todos os valores forem iguais, normaliza para 0

    return data

def apply_gan_to_generate_variables(file_path, percentage_generated_features=0.50, num_epochs=100, batch_size=32, learning_rate=0.001):
    print(f"Lendo arquivo de entrada: {file_path}...")
    data = pd.read_csv(file_path, delimiter=",", skipinitialspace=True)
    print("Arquivo carregado com sucesso.")

    print("Convertendo os dados para tensores do PyTorch...")
    data_tensor = torch.tensor(data.values, dtype=torch.float32)

    input_dim = data.shape[1]
    num_generated_features = max(1, int(input_dim * percentage_generated_features))  # Calcular a quantidade de variáveis a serem geradas
    print(f"A base de dados contém {input_dim} variáveis de entrada. Gerando {num_generated_features} novas variáveis.")

    class Generator(nn.Module):
        def __init__(self, input_dim, output_dim):
            super(Generator, self).__init__()
            self.model = nn.Sequential(
                nn.Linear(input_dim, 64),
                nn.ReLU(),
                nn.Linear(64, 64),
                nn.ReLU(),
                nn.Linear(64, output_dim)
            )
        
        def forward(self, x):
            return self.model(x)
    
    class Discriminator(nn.Module):
        def __init__(self, input_dim):
            super(Discriminator, self).__init__()
            self.model = nn.Sequential(
                nn.Linear(input_dim, 64),
                nn.LeakyReLU(0.2),
                nn.Linear(64, 64),
                nn.LeakyReLU(0.2),
                nn.Linear(64, 1),
                nn.Sigmoid()
            )
        
        def forward(self, x):
            return self.model(x)
    
    print("Inicializando modelos Generator e Discriminator...")
    generator = Generator(input_dim, num_generated_features)
    discriminator = Discriminator(input_dim + num_generated_features)

    criterion = nn.BCELoss()
    optimizer_G = torch.optim.Adam(generator.parameters(), lr=learning_rate)
    optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=learning_rate)

    dataset = TensorDataset(data_tensor)
    data_loader = DataLoader(dataset, batch_size=min(batch_size, len(dataset)), shuffle=True)

    print("Iniciando o treinamento da GAN...")
    for epoch in range(num_epochs):
        for batch in data_loader:
            real_data = batch[0]
            batch_size_actual = real_data.size(0)

            # Labels reais e falsas
            real_labels = torch.ones((batch_size_actual, 1))
            fake_labels = torch.zeros((batch_size_actual, 1))

            # Treinar o discriminador
            generated_data = generator(real_data)
            fake_data = torch.cat((real_data, generated_data), dim=1)
            real_data_extended = torch.cat((real_data, torch.zeros((batch_size_actual, num_generated_features))), dim=1)
            
            discriminator_real_loss = criterion(discriminator(real_data_extended), real_labels)
            discriminator_fake_loss = criterion(discriminator(fake_data.detach()), fake_labels)
            discriminator_loss = discriminator_real_loss + discriminator_fake_loss

            optimizer_D.zero_grad()
            discriminator_loss.backward()
            optimizer_D.step()

            # Treinar o gerador
            fake_data = torch.cat((real_data, generator(real_data)), dim=1)
            generator_loss = criterion(discriminator(fake_data), real_labels)

            optimizer_G.zero_grad()
            generator_loss.backward()
            optimizer_G.step()

        if (epoch + 1) % 10 == 0:
            print(f"Época [{epoch+1}/{num_epochs}] - Perda Discriminador: {discriminator_loss.item():.4f}, Perda Gerador: {generator_loss.item():.4f}")

    print("Treinamento concluído. Gerando novas variáveis...")
    with torch.no_grad():
        new_variables = generator(data_tensor).numpy()

    for i in range(num_generated_features):
        data[f"Generated_Var_{i+1}"] = new_variables[:, i]

    # Aplicar normalização Min-Max
    data = apply_min_max_normalization(data)

    # Reorganizar as colunas para garantir que a coluna alvo seja a última
    target_column = data.columns[-(num_generated_features + 1)]  # Identifica a coluna alvo original
    columns = [col for col in data.columns if col != target_column] + [target_column]
    data = data[columns]

    print("Novas variáveis adicionadas e colunas reorganizadas com sucesso.")
    return data

def process_and_save_files(input_dir, output_dir, percentage_generated_features=0.50, num_epochs=100, batch_size=32, learning_rate=0.001):
    print(f"Verificando diretório de saída: {output_dir}...")
    os.makedirs(output_dir, exist_ok=True)
    print("Diretório de saída pronto.")

    for filename in os.listdir(input_dir):
        if filename.endswith(".txt"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)
            
            print(f"\nProcessando arquivo: {input_path}")
            try:
                processed_data = apply_gan_to_generate_variables(
                    file_path=input_path,
                    percentage_generated_features=percentage_generated_features,
                    num_epochs=num_epochs,
                    batch_size=batch_size,
                    learning_rate=learning_rate
                )
                processed_data.to_csv(output_path, sep=",", index=False)
                print(f"Arquivo processado e salvo em: {output_path}")
            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

# Diretórios de entrada e saída
input_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado"
output_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-GAN-50"

# Processar arquivos
process_and_save_files(input_directory, output_directory, percentage_generated_features=0.50, num_epochs=100)
# Out:
# Verificando diretório de saída: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-GAN-50...
# Diretório de saída pronto.
#
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_china.txt
# Lendo arquivo de entrada: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_china.txt...
# Arquivo carregado com sucesso.
# Convertendo os dados para tensores do PyTorch...
# A base de dados contém 19 variáveis de entrada. Gerando 9 novas variáveis.
# Inicializando modelos Generator e Discriminator...
# Iniciando o treinamento da GAN...
# Época [10/100] - Perda Discriminador: 1.2927, Perda Gerador: 0.8095
# Época [20/100] - Perda Discriminador: 1.3199, Perda Gerador: 0.7969
# Época [30/100] - Perda Discriminador: 1.2698, Perda Gerador: 0.7345
# Época [40/100] - Perda Discriminador: 1.4261, Perda Gerador: 0.5597
# Época [50/100] - Perda Discriminador: 1.3730, Perda Gerador: 0.7887
# Época [60/100] - Perda Discriminador: 1.3481, Perda Gerador: 0.9039
# Época [70/100] - Perda Discriminador: 1.2597, Perda Gerador: 0.9393
# Época [80/100] - Perda Discriminador: 1.4307, Perda Gerador: 0.5726
# Época [90/100] - Perda Discriminador: 1.2820, Perda Gerador: 0.7513
# Época [100/100] - Perda Discriminador: 1.2180, Perda Gerador: 0.8507
# Treinamento concluído. Gerando novas variáveis...
# Novas variáveis adicionadas e colunas reorganizadas com sucesso.
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-GAN-50\tratamento_china.txt
#
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_cocomo81.txt
# Lendo arquivo de entrada: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_cocomo81.txt...
# Arquivo carregado com sucesso.
# Convertendo os dados para tensores do PyTorch...
# A base de dados contém 17 variáveis de entrada. Gerando 8 novas variáveis.
# Inicializando modelos Generator e Discriminator...
# Iniciando o treinamento da GAN...
# Época [10/100] - Perda Discriminador: 1.3890, Perda Gerador: 0.6937
# Época [20/100] - Perda Discriminador: 1.3933, Perda Gerador: 0.6984
# Época [30/100] - Perda Discriminador: 1.3678, Perda Gerador: 0.7035
# Época [40/100] - Perda Discriminador: 1.3834, Perda Gerador: 0.7025
# Época [50/100] - Perda Discriminador: 1.2829, Perda Gerador: 0.7783
# Época [60/100] - Perda Discriminador: 1.3551, Perda Gerador: 0.7448
# Época [70/100] - Perda Discriminador: 1.5318, Perda Gerador: 0.7170
# Época [80/100] - Perda Discriminador: 0.7722, Perda Gerador: 1.2614
# Época [90/100] - Perda Discriminador: 1.2728, Perda Gerador: 0.8158
# Época [100/100] - Perda Discriminador: 2.8005, Perda Gerador: 0.2874
# Treinamento concluído. Gerando novas variáveis...
# Novas variáveis adicionadas e colunas reorganizadas com sucesso.
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-GAN-50\tratamento_cocomo81.txt
#
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_desharnais.txt
# Lendo arquivo de entrada: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_desharnais.txt...
# Arquivo carregado com sucesso.
# Convertendo os dados para tensores do PyTorch...
# A base de dados contém 9 variáveis de entrada. Gerando 4 novas variáveis.
# Inicializando modelos Generator e Discriminator...
# Iniciando o treinamento da GAN...
# Época [10/100] - Perda Discriminador: 1.3784, Perda Gerador: 0.7091
# Época [20/100] - Perda Discriminador: 1.3987, Perda Gerador: 0.6742
# Época [30/100] - Perda Discriminador: 1.4243, Perda Gerador: 0.7171
# Época [40/100] - Perda Discriminador: 1.2638, Perda Gerador: 0.7863
# Época [50/100] - Perda Discriminador: 1.4853, Perda Gerador: 0.6995
# Época [60/100] - Perda Discriminador: 1.2402, Perda Gerador: 0.8101
# Época [70/100] - Perda Discriminador: 1.4281, Perda Gerador: 0.7255
# Época [80/100] - Perda Discriminador: 1.3330, Perda Gerador: 0.9547
# Época [90/100] - Perda Discriminador: 1.1987, Perda Gerador: 0.8521
# Época [100/100] - Perda Discriminador: 1.2958, Perda Gerador: 0.8234
# Treinamento concluído. Gerando novas variáveis...
# Novas variáveis adicionadas e colunas reorganizadas com sucesso.
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-GAN-50\tratamento_desharnais.txt
#
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_maxwell.txt
# Lendo arquivo de entrada: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_maxwell.txt...
# Arquivo carregado com sucesso.
# Convertendo os dados para tensores do PyTorch...
# A base de dados contém 25 variáveis de entrada. Gerando 12 novas variáveis.
# Inicializando modelos Generator e Discriminator...
# Iniciando o treinamento da GAN...
# Época [10/100] - Perda Discriminador: 1.3705, Perda Gerador: 0.7168
# Época [20/100] - Perda Discriminador: 1.4022, Perda Gerador: 0.6962
# Época [30/100] - Perda Discriminador: 1.4513, Perda Gerador: 0.7028
# Época [40/100] - Perda Discriminador: 1.2416, Perda Gerador: 0.8438
# Época [50/100] - Perda Discriminador: 1.3934, Perda Gerador: 0.7147
# Época [60/100] - Perda Discriminador: 1.4932, Perda Gerador: 0.6323
# Época [70/100] - Perda Discriminador: 1.0610, Perda Gerador: 0.9537
# Época [80/100] - Perda Discriminador: 1.6326, Perda Gerador: 0.6175
# Época [90/100] - Perda Discriminador: 1.4129, Perda Gerador: 0.7465
# Época [100/100] - Perda Discriminador: 1.0790, Perda Gerador: 0.9307
# Treinamento concluído. Gerando novas variáveis...
# Novas variáveis adicionadas e colunas reorganizadas com sucesso.
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\3-GAN-50\tratamento_maxwell.txt

# %% [markdown]
# # GAN (75%)

# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

def apply_min_max_normalization(data):
    """
    Aplica normalização Min-Max nas colunas numéricas do DataFrame.

    Args:
        data (pd.DataFrame): DataFrame a ser normalizado.

    Returns:
        pd.DataFrame: DataFrame com colunas normalizadas.
    """
    numeric_columns = data.select_dtypes(include=[np.number]).columns

    for col in numeric_columns:
        col_min = data[col].min()
        col_max = data[col].max()

        if col_max != col_min:  # Evita divisão por zero
            data[col] = (data[col] - col_min) / (col_max - col_min)
        else:
            data[col] = 0  # Se todos os valores forem iguais, normaliza para 0

    return data

def apply_gan_to_generate_variables(file_path, percentage_generated_features=0.75, num_epochs=100, batch_size=32, learning_rate=0.001):
    print(f"Lendo arquivo de entrada: {file_path}...")
    data = pd.read_csv(file_path, delimiter=",", skipinitialspace=True)
    print("Arquivo carregado com sucesso.")

    print("Convertendo os dados para tensores do PyTorch...")
    data_tensor = torch.tensor(data.values, dtype=torch.float32)

    input_dim = data.shape[1]
    num_generated_features = max(1, int(input_dim * percentage_generated_features))  # Calcular a quantidade de variáveis a serem geradas
    print(f"A base de dados contém {input_dim} variáveis de entrada. Gerando {num_generated_features} novas variáveis.")

    class Generator(nn.Module):
        def __init__(self, input_dim, output_dim):
            super(Generator, self).__init__()
            self.model = nn.Sequential(
                nn.Linear(input_dim, 64),
                nn.ReLU(),
                nn.Linear(64, 64),
                nn.ReLU(),
                nn.Linear(64, output_dim)
            )
        
        def forward(self, x):
            return self.model(x)
    
    class Discriminator(nn.Module):
        def __init__(self, input_dim):
            super(Discriminator, self).__init__()
            self.model = nn.Sequential(
                nn.Linear(input_dim, 64),
                nn.LeakyReLU(0.2),
                nn.Linear(64, 64),
                nn.LeakyReLU(0.2),
                nn.Linear(64, 1),
                nn.Sigmoid()
            )
        
        def forward(self, x):
            return self.model(x)
    
    print("Inicializando modelos Generator e Discriminator...")
    generator = Generator(input_dim, num_generated_features)
    discriminator = Discriminator(input_dim + num_generated_features)

    criterion = nn.BCELoss()
    optimizer_G = torch.optim.Adam(generator.parameters(), lr=learning_rate)
    optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=learning_rate)

    dataset = TensorDataset(data_tensor)
    data_loader = DataLoader(dataset, batch_size=min(batch_size, len(dataset)), shuffle=True)

    print("Iniciando o treinamento da GAN...")
    for epoch in range(num_epochs):
        for batch in data_loader:
            real_data = batch[0]
            batch_size_actual = real_data.size(0)

            # Labels reais e falsas
            real_labels = torch.ones((batch_size_actual, 1))
            fake_labels = torch.zeros((batch_size_actual, 1))

            # Treinar o discriminador
            generated_data = generator(real_data)
            fake_data = torch.cat((real_data, generated_data), dim=1)
            real_data_extended = torch.cat((real_data, torch.zeros((batch_size_actual, num_generated_features))), dim=1)
            
            discriminator_real_loss = criterion(discriminator(real_data_extended), real_labels)
            discriminator_fake_loss = criterion(discriminator(fake_data.detach()), fake_labels)
            discriminator_loss = discriminator_real_loss + discriminator_fake_loss

            optimizer_D.zero_grad()
            discriminator_loss.backward()
            optimizer_D.step()

            # Treinar o gerador
            fake_data = torch.cat((real_data, generator(real_data)), dim=1)
            generator_loss = criterion(discriminator(fake_data), real_labels)

            optimizer_G.zero_grad()
            generator_loss.backward()
            optimizer_G.step()

        if (epoch + 1) % 10 == 0:
            print(f"Época [{epoch+1}/{num_epochs}] - Perda Discriminador: {discriminator_loss.item():.4f}, Perda Gerador: {generator_loss.item():.4f}")

    print("Treinamento concluído. Gerando novas variáveis...")
    with torch.no_grad():
        new_variables = generator(data_tensor).numpy()

    for i in range(num_generated_features):
        data[f"Generated_Var_{i+1}"] = new_variables[:, i]

    # Aplicar normalização Min-Max
    data = apply_min_max_normalization(data)

    # Reorganizar as colunas para garantir que a coluna alvo seja a última
    target_column = data.columns[-(num_generated_features + 1)]  # Identifica a coluna alvo original
    columns = [col for col in data.columns if col != target_column] + [target_column]
    data = data[columns]

    print("Novas variáveis adicionadas e colunas reorganizadas com sucesso.")
    return data

def process_and_save_files(input_dir, output_dir, percentage_generated_features=0.75, num_epochs=100, batch_size=32, learning_rate=0.001):
    print(f"Verificando diretório de saída: {output_dir}...")
    os.makedirs(output_dir, exist_ok=True)
    print("Diretório de saída pronto.")

    for filename in os.listdir(input_dir):
        if filename.endswith(".txt"):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)
            
            print(f"\nProcessando arquivo: {input_path}")
            try:
                processed_data = apply_gan_to_generate_variables(
                    file_path=input_path,
                    percentage_generated_features=percentage_generated_features,
                    num_epochs=num_epochs,
                    batch_size=batch_size,
                    learning_rate=learning_rate
                )
                processed_data.to_csv(output_path, sep=",", index=False)
                print(f"Arquivo processado e salvo em: {output_path}")
            except Exception as e:
                print(f"Erro ao processar {filename}: {e}")

# Diretórios de entrada e saída
input_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado"
output_directory = r"C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\4-GAN-75"

# Processar arquivos
process_and_save_files(input_directory, output_directory, percentage_generated_features=0.75, num_epochs=100)
# Out:
# Verificando diretório de saída: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\4-GAN-75...
# Diretório de saída pronto.
#
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_china.txt
# Lendo arquivo de entrada: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_china.txt...
# Arquivo carregado com sucesso.
# Convertendo os dados para tensores do PyTorch...
# A base de dados contém 19 variáveis de entrada. Gerando 14 novas variáveis.
# Inicializando modelos Generator e Discriminator...
# Iniciando o treinamento da GAN...
# Época [10/100] - Perda Discriminador: 1.2491, Perda Gerador: 0.9413
# Época [20/100] - Perda Discriminador: 1.1547, Perda Gerador: 1.0692
# Época [30/100] - Perda Discriminador: 1.4341, Perda Gerador: 0.6452
# Época [40/100] - Perda Discriminador: 1.4974, Perda Gerador: 0.5996
# Época [50/100] - Perda Discriminador: 1.2098, Perda Gerador: 0.8752
# Época [60/100] - Perda Discriminador: 1.3786, Perda Gerador: 0.7004
# Época [70/100] - Perda Discriminador: 1.1411, Perda Gerador: 0.8925
# Época [80/100] - Perda Discriminador: 1.8304, Perda Gerador: 0.5163
# Época [90/100] - Perda Discriminador: 1.4027, Perda Gerador: 0.7352
# Época [100/100] - Perda Discriminador: 1.7401, Perda Gerador: 0.5078
# Treinamento concluído. Gerando novas variáveis...
# Novas variáveis adicionadas e colunas reorganizadas com sucesso.
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\4-GAN-75\tratamento_china.txt
#
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_cocomo81.txt
# Lendo arquivo de entrada: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_cocomo81.txt...
# Arquivo carregado com sucesso.
# Convertendo os dados para tensores do PyTorch...
# A base de dados contém 17 variáveis de entrada. Gerando 12 novas variáveis.
# Inicializando modelos Generator e Discriminator...
# Iniciando o treinamento da GAN...
# Época [10/100] - Perda Discriminador: 1.3897, Perda Gerador: 0.6793
# Época [20/100] - Perda Discriminador: 1.3711, Perda Gerador: 0.7118
# Época [30/100] - Perda Discriminador: 1.3557, Perda Gerador: 0.7188
# Época [40/100] - Perda Discriminador: 1.4399, Perda Gerador: 0.7106
# Época [50/100] - Perda Discriminador: 1.3916, Perda Gerador: 0.7425
# Época [60/100] - Perda Discriminador: 1.2821, Perda Gerador: 0.7903
# Época [70/100] - Perda Discriminador: 1.2418, Perda Gerador: 0.8136
# Época [80/100] - Perda Discriminador: 1.3489, Perda Gerador: 0.7762
# Época [90/100] - Perda Discriminador: 1.6408, Perda Gerador: 0.5929
# Época [100/100] - Perda Discriminador: 1.4102, Perda Gerador: 0.7894
# Treinamento concluído. Gerando novas variáveis...
# Novas variáveis adicionadas e colunas reorganizadas com sucesso.
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\4-GAN-75\tratamento_cocomo81.txt
#
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_desharnais.txt
# Lendo arquivo de entrada: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_desharnais.txt...
# Arquivo carregado com sucesso.
# Convertendo os dados para tensores do PyTorch...
# A base de dados contém 9 variáveis de entrada. Gerando 6 novas variáveis.
# Inicializando modelos Generator e Discriminator...
# Iniciando o treinamento da GAN...
# Época [10/100] - Perda Discriminador: 1.3805, Perda Gerador: 0.6845
# Época [20/100] - Perda Discriminador: 1.4258, Perda Gerador: 0.6755
# Época [30/100] - Perda Discriminador: 1.3376, Perda Gerador: 0.7539
# Época [40/100] - Perda Discriminador: 1.4234, Perda Gerador: 0.7065
# Época [50/100] - Perda Discriminador: 1.2477, Perda Gerador: 0.8913
# Época [60/100] - Perda Discriminador: 1.2849, Perda Gerador: 0.7881
# Época [70/100] - Perda Discriminador: 1.5891, Perda Gerador: 0.5684
# Época [80/100] - Perda Discriminador: 1.2235, Perda Gerador: 1.0220
# Época [90/100] - Perda Discriminador: 1.2130, Perda Gerador: 0.8546
# Época [100/100] - Perda Discriminador: 1.5304, Perda Gerador: 0.4749
# Treinamento concluído. Gerando novas variáveis...
# Novas variáveis adicionadas e colunas reorganizadas com sucesso.
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\4-GAN-75\tratamento_desharnais.txt
#
# Processando arquivo: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_maxwell.txt
# Lendo arquivo de entrada: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\1-tratamento-target-encoding-normalizado\tratamento_maxwell.txt...
# Arquivo carregado com sucesso.
# Convertendo os dados para tensores do PyTorch...
# A base de dados contém 25 variáveis de entrada. Gerando 18 novas variáveis.
# Inicializando modelos Generator e Discriminator...
# Iniciando o treinamento da GAN...
# Época [10/100] - Perda Discriminador: 1.4146, Perda Gerador: 0.6716
# Época [20/100] - Perda Discriminador: 1.3496, Perda Gerador: 0.7637
# Época [30/100] - Perda Discriminador: 1.3462, Perda Gerador: 0.7242
# Época [40/100] - Perda Discriminador: 1.4483, Perda Gerador: 0.7005
# Época [50/100] - Perda Discriminador: 1.2552, Perda Gerador: 0.8370
# Época [60/100] - Perda Discriminador: 1.3369, Perda Gerador: 0.7730
# Época [70/100] - Perda Discriminador: 1.3253, Perda Gerador: 0.7930
# Época [80/100] - Perda Discriminador: 1.3286, Perda Gerador: 0.7562
# Época [90/100] - Perda Discriminador: 1.6211, Perda Gerador: 0.5931
# Época [100/100] - Perda Discriminador: 1.5375, Perda Gerador: 0.7428
# Treinamento concluído. Gerando novas variáveis...
# Novas variáveis adicionadas e colunas reorganizadas com sucesso.
# Arquivo processado e salvo em: C:\Users\CALEO\OneDrive - Hexagon\Documents\GitHub\Software_effort_estimation\proposal\abordagem\saida\4-GAN-75\tratamento_maxwell.txt
